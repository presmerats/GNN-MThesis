# %% [markdown]
# # GCN in a transductive setting for Node betweenness
# This notebook shows how a GCN/GraphSAGE model is trained to compute Node betweenness centrality on different graphs

# %% [markdown]
# # 1. Codebase

# %%
# %load_ext autoreload
# %autoreload 2
from torch.nn import *
from TFM_node_betweenness_models import MyNet,Net1,Net2,Net3,Net4,Net5,Net6
from TFM_node_betweenness_training import *
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-64645acef122>", line 4, in <module>
#     from TFM_node_betweenness_models import MyNet,Net1,Net2,Net3,Net4,Net5,Net6
#   File "/media/disk/home/pau/Projectes/GNN-MThesis/src/girvan-newman/TFM_node_betweenness_models.py", line 3, in <module>
#     from torch_geometric.nn import GCNConv
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/torch_geometric/__init__.py", line 2, in <module>
#     import torch_geometric.nn
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/torch_geometric/nn/__init__.py", line 9, in <module>
#     from .models import *  # noqa
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/torch_geometric/nn/models/__init__.py", line 2, in <module>
#     from .node2vec import Node2Vec
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/torch_geometric/nn/models/node2vec.py", line 3, in <module>
#     from sklearn.linear_model import LogisticRegression
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/sklearn/linear_model/__init__.py", line 12, in <module>
#     from .base import LinearRegression
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/sklearn/linear_model/base.py", line 39, in <module>
#     from ..preprocessing.data import normalize as f_normalize
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/sklearn/preprocessing/__init__.py", line 6, in <module>
#     from ._function_transformer import FunctionTransformer
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/sklearn/preprocessing/_function_transformer.py", line 5, in <module>
#     from ..utils.testing import assert_allclose_dense_sparse
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/sklearn/utils/testing.py", line 26, in <module>
#     import scipy.io
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/io/__init__.py", line 97, in <module>
#     from .matlab import loadmat, savemat, whosmat, byteordercodes
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/io/matlab/__init__.py", line 13, in <module>
#     from .mio import loadmat, savemat, whosmat
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/io/matlab/mio.py", line 10, in <module>
#     from .miobase import get_matfile_version, docfiller
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/io/matlab/miobase.py", line 22, in <module>
#     from scipy.misc import doccer
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/misc/__init__.py", line 68, in <module>
#     from scipy.interpolate._pade import pade as _pade
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/interpolate/__init__.py", line 175, in <module>
#     from .interpolate import *
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/scipy/interpolate/interpolate.py", line 32, in <module>
#     from .interpnd import _ndim_coords_from_arrays
#   File "<frozen importlib._bootstrap>", line 416, in parent
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/inspect.py", line 1488, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/inspect.py", line 1450, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/pau/.pyenv/versions/3.6.7/envs/gnn-pytorch/lib/python3.6/site-packages/IPython/core/ultratb.py", line 179, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/tokenize.py", line 454, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/tokenize.py", line 423, in detect_encoding
#     first = read_or_stop()
#   File "/home/pau/.pyenv/versions/3.6.7/lib/python3.6/tokenize.py", line 381, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %% [markdown]
# # 2. Selected graphs for HP search
#
# Graphs with higher number of node betweenness.

# %%
dname='../datasets/precomputed-pytorchg-betweenness/KarateClub_ALLmerged___nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
experimentBlock_new(dname, res_dict, visualize=True)
reporting(res_dict)
# Out:
# Analysis of vis_../datasets/precomputed-pytorchg-betweenness/KarateClub_ALLmerged___nd.pickle Dataset-----------------------------------
# number of graphs in the dataset:  6
# num classes:  1
# num features:  1
# <class 'torch_geometric.data.data.Data'>
#
# Draw
# 0.43763527274131775
# tensor(0.4376)
#                 GTavg     GTmax GTmin   PREDavg   PREDmax   PREDmin  \
# Net1-d1=20  0.0279611  0.304075     0 -0.422492 -0.290203 -0.698948
#
#            batch_size                    dataset epochs hyperparams  nrmse  \
# Net1-d1=20         32  KarateClub_ALLmerged___nd      2       d1=20  2.237
#
#             seed   time
# Net1-d1=20  None  0.735

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
experimentBlock_new(dname, res_dict, visualize=True)
reporting(res_dict)
# Out:
# Analysis of vis_../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle Dataset-----------------------------------
# number of graphs in the dataset:  3
# num classes:  1
# num features:  1
# <class 'torch_geometric.data.data.Data'>
#
# Draw
# 0.43763527274131775
# tensor(0.4376)
#                 GTavg     GTmax GTmin     PREDavg     PREDmax     PREDmin  \
# Net1-d1=20  0.0602783  0.437635     0  0.00496663  0.00889292  0.00103991
#
#            batch_size          dataset epochs hyperparams  nrmse  seed   time
# Net1-d1=20         32  KarateClub_1_nd     20       d1=20  0.583  None  0.065

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_30_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
experimentBlock_new(dname, res_dict, visualize=True)
reporting(res_dict)
# Out:
# Analysis of vis_../datasets/precomputed-pytorchg-betweenness_old/ws_30_3_0_1_nb.pickle Dataset-----------------------------------
# number of graphs in the dataset:  3
# num classes:  1
# num features:  1
# <class 'torch_geometric.data.data.Data'>
#
# Draw
# 0.37931033968925476
# tensor(0.3793)
#                GTavg     GTmax GTmin   PREDavg  PREDmax   PREDmin batch_size  \
# Net1-d1=20  0.233169  0.628079     0  0.199885  0.21618  0.188289         32
#
#                    dataset epochs hyperparams  nrmse  seed   time
# Net1-d1=20  ws_30_3_0_1_nb     20       d1=20  0.874  None  0.063

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
experimentBlock_new(dname, res_dict, visualize=True)
reporting(res_dict)
# Out:
# Analysis of vis_../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle Dataset-----------------------------------
# number of graphs in the dataset:  3
# num classes:  1
# num features:  1
# <class 'torch_geometric.data.data.Data'>
#
# Draw
# 0.1631622314453125
# tensor(0.1632)
#                GTavg     GTmax GTmin   PREDavg   PREDmax   PREDmin batch_size  \
# Net1-d1=20  0.108383  0.311688     0  0.118227  0.132545  0.104867         32
#
#                     dataset epochs hyperparams  nrmse  seed   time
# Net1-d1=20  ws_100_3_0_1_nb     20       d1=20  0.894  None  0.063

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old//ws_1000_10_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
experimentBlock_new(dname, res_dict, visualize=True)
reporting(res_dict)
# Out:
# Analysis of vis_../datasets/precomputed-pytorchg-betweenness_old//ws_1000_10_0_1_nb.pickle Dataset-----------------------------------
# number of graphs in the dataset:  3
# num classes:  1
# num features:  1
# <class 'torch_geometric.data.data.Data'>
#
# Draw
# -->too big to draw! Slicing first 300 nodes..
# [('17', '12'), ('17', '13'), ('17', '14'), ('17', '15'), ('17', '18'), ('17', '19'), ('17', '20'), ('17', '21'), ('17', '22'), ('8', '3'), ('8', '4'), ('8', '5'), ('8', '6'), ('8', '7'), ('8', '9'), ('8', '10'), ('8', '11'), ('8', '12'), ('8', '13'), ('886', '5'), ('998', '0'), ('998', '1'), ('998', '2'), ('998', '3'), ('998', '995'), ('998', '996'), ('998', '997'), ('998', '999'), ('15', '10'), ('15', '11'), ('15', '12'), ('15', '13'), ('15', '14'), ('15', '16'), ('15', '18'), ('15', '19'), ('15', '20'), ('24', '19'), ('24', '20'), ('24', '21'), ('24', '22'), ('24', '23'), ('24', '26'), ('25', '20'), ('25', '21'), ('25', '22'), ('25', '23'), ('25', '26'), ('26', '21'), ('26', '22'), ('26', '23'), ('18', '13'), ('18', '14'), ('18', '16'), ('18', '19'), ('18', '21'), ('18', '22'), ('18', '591'), ('18', '735'), ('908', '19'), ('997', '0'), ('997', '1'), ('997', '2'), ('997', '995'), ('997', '996'), ('997', '999'), ('544', '16'), ('1', '0'), ('1', '2'), ('1', '3'), ('1', '999'), ('1', '4'), ('1', '5'), ('1', '6'), ('1', '996'), ('2', '0'), ('2', '3'), ('2', '4'), ('2', '5'), ('2', '999'), ('2', '6'), ('2', '7'), ('2', '266'), ('22', '19'), ('22', '20'), ('22', '23'), ('4', '0'), ('4', '3'), ('4', '5'), ('4', '6'), ('4', '7'), ('4', '9'), ('4', '999'), ('11', '6'), ('11', '7'), ('11', '9'), ('11', '10'), ('11', '13'), ('11', '14'), ('11', '16'), ('11', '702'), ('961', '5'), ('6', '3'), ('6', '7'), ('6', '9'), ('6', '10'), ('3', '0'), ('3', '5'), ('3', '7'), ('3', '999'), ('728', '7'), ('991', '21'), ('991', '995'), ('991', '996'), ('21', '16'), ('21', '19'), ('21', '20'), ('21', '23'), ('13', '9'), ('13', '10'), ('13', '12'), ('13', '14'), ('13', '16'), ('93', '16'), ('5', '0'), ('5', '7'), ('5', '9'), ('5', '10'), ('20', '16'), ('20', '19'), ('20', '23'), ('10', '7'), ('10', '9'), ('10', '12'), ('10', '14'), ('996', '0'), ('996', '995'), ('996', '999'), ('433', '12'), ('995', '0'), ('995', '999'), ('16', '14'), ('16', '19'), ('7', '9'), ('246', '12'), ('9', '12'), ('9', '14'), ('14', '12'), ('14', '19'), ('23', '19')]
#                  GTavg      GTmax       GTmin    PREDavg    PREDmax  \
# Net1-d1=20  0.00342422  0.0197996  0.00022753  0.0339192  0.0369344
#
#               PREDmin batch_size            dataset epochs hyperparams nrmse  \
# Net1-d1=20  0.0309566         32  ws_1000_10_0_1_nb     20       d1=20  0.81
#
#             seed   time
# Net1-d1=20  None  0.118

# %% [markdown]
# # 3. Training setup options

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
visualize=True
basic_training({
        # model params
        'class': Net1,
        'd1': 20,
        # now training params
        'dataset_name': dname,
        'epochs': 20,
        'batch_size': 32,
        'seed': None,
        },
        res_dict,
        visualize
        )
reporting(res_dict)
# Out:
# Analysis of vis_../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle Dataset-----------------------------------
# number of graphs in the dataset:  3
# num classes:  1
# num features:  1
# <class 'torch_geometric.data.data.Data'>
#
# Draw
# 0.1631622314453125
# tensor(0.1632)
#                GTavg     GTmax GTmin   PREDavg   PREDmax    PREDmin  \
# Net1-d1=20  0.102811  0.374665     0  0.103983  0.119288  0.0868959
#
#            batch_size          dataset epochs hyperparams  nrmse  seed   time
# Net1-d1=20         32  ws_100_3_0_1_nb     20       d1=20  0.916  None  0.064

# %% [markdown]
# # 6. analysis of seed and similar structure splits

# %%
# %load_ext autoreload
# %autoreload 2
from torch.nn import *
from TFM_node_betweenness_models import MyNet,Net1,Net2,Net3,Net4,Net5,Net6,Net7,Net8
from TFM_node_betweenness_training import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def trainingExplosion2(dname, res_dict):

    training_dicts =[]
    for model in [Net7]:
        for d1 in [15]:
            for d2 in [50]:
                for d3 in [20]:
                    for d4 in [20]:
                        for num_layers in [4]:
                            for epochs in [80]:
                                for K in [20]:
                                    for seed in range(100):
                                        training_dicts.append(

                                            {
                                            # model params
                                            'class': model,
                                            'd1': d1,
                                            'd2': d2,
                                            'd3': d3,
                                            'd4': d4,
                                            'dK': K,
                                            'num_layers': num_layers,
                                            # now training params
                                            'dataset_name': dname,
                                            'epochs': epochs,
                                            'batch_size': 8,
                                            'seed': seed,
                                            }
                                            )

    for td in training_dicts:
        basic_analysis(
        td,
        res_dict,
        False
        )

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
#print(res_dict)
vals = list(res_dict['tables'].values())
keys = list(res_dict['tables'].keys())
keys.sort(key=lambda x: res_dict['tables'][x])
for k in keys:
    print(k, res_dict['tables'][k])

# 16,6 are the best splits
# Out:
# 57 0.01436483021825552
# 26 0.014485596679151058
# 12 0.015308505855500698
# 85 0.015313711948692799
# 24 0.015467160381376743
# 2 0.015505591407418251
# 83 0.01557868905365467
# 99 0.015856381505727768
# 66 0.015908224508166313
# 3 0.01604953221976757
# 54 0.01618463359773159
# 25 0.016371626406908035
# 75 0.016377802938222885
# 72 0.016406269744038582
# 16 0.01645904965698719
# 58 0.01648377813398838
# 41 0.016728850081562996
# 18 0.016881469637155533
# 34 0.017280258238315582
# 32 0.017739566043019295
# 94 0.01775316894054413
# 70 0.01823059841990471
# 29 0.0184188112616539
# 53 0.018541166558861732
# 52 0.01861947774887085
# 28 0.019316410645842552
# 93 0.019321853294968605
# 20 0.019980069249868393
# 76 0.02041449025273323
# 1 0.020417751744389534
# 0 0.02071317471563816
# 61 0.02075241319835186
# 77 0.020994462072849274
# 87 0.02117902971804142
# 88 0.02122482843697071
# 40 0.02129983901977539
# 21 0.021756181493401527
# 33 0.02232903428375721
# 65 0.02257883921265602
# 39 0.022595010697841644
# 92 0.022658808156847954
# 27 0.022696837782859802
# 30 0.022826936095952988
# 6 0.023094573989510536
# 64 0.023671569302678108
# 97 0.023974234238266945
# 19 0.024190247058868408
# 63 0.024197911843657494
# 74 0.02482464164495468
# 50 0.025069981813430786
# 71 0.02613130770623684
# 47 0.026877813041210175
# 37 0.02696441113948822
# 78 0.027224702760577202
# 96 0.02750910073518753
# 79 0.027547216042876244
# 59 0.02845843695104122
# 81 0.028799748048186302
# 9 0.029619846493005753
# 62 0.031146632507443428
# 90 0.03130734711885452
# 91 0.03266910836100578
# 15 0.032736990600824356
# 35 0.032785993069410324
# 46 0.033081892877817154
# 13 0.03387673199176788
# 10 0.03462051600217819
# 38 0.034892331808805466
# 14 0.03492121025919914
# 56 0.0350499264895916
# 82 0.03589532524347305
# 86 0.03598584234714508
# 68 0.03633406385779381
# 5 0.03638458251953125
# 4 0.0367453433573246
# 8 0.039566028863191605
# 95 0.04003053531050682
# 67 0.04064572975039482
# 89 0.041945453733205795
# 55 0.04203581437468529
# 44 0.043428488075733185
# 48 0.04540087655186653
# 31 0.04608965292572975
# 23 0.047577667981386185
# 11 0.04764125868678093
# 51 0.048020802438259125
# 7 0.049157656729221344
# 42 0.05022574961185455
# 36 0.05211491510272026
# 80 0.052190423011779785
# 98 0.053346093744039536
# 60 0.05429195612668991
# 22 0.05483699589967728
# 45 0.05499296262860298
# 84 0.055395763367414474
# 49 0.06369639188051224
# 69 0.06488361209630966
# 17 0.0653797835111618
# 43 0.0682438313961029
# 73 0.0801151692867279

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
#print(res_dict)
vals = list(res_dict['tables'].values())
keys = list(res_dict['tables'].keys())
keys.sort(key=lambda x: res_dict['tables'][x])
for k in keys:
    print(k, res_dict['tables'][k])

# 16,6 are the best splits
# Out:
# 37 0.03821680694818497
# 15 0.03827793896198273
# 19 0.03831096738576889
# 55 0.03832979127764702
# 65 0.0383700467646122
# 26 0.038440022617578506
# 45 0.038529977202415466
# 1 0.03865435719490051
# 51 0.03868187218904495
# 78 0.03881935402750969
# 0 0.03884495422244072
# 97 0.03905836120247841
# 44 0.03914478048682213
# 6 0.039166875183582306
# 64 0.03916997089982033
# 72 0.03929524123668671
# 98 0.03933646157383919
# 77 0.039401520043611526
# 79 0.03941504284739494
# 62 0.03944862261414528
# 90 0.03948826715350151
# 24 0.03953607752919197
# 83 0.039620038121938705
# 40 0.0396311953663826
# 94 0.03967459127306938
# 12 0.039675045758485794
# 99 0.039727553725242615
# 54 0.039822567254304886
# 32 0.04001258313655853
# 86 0.04038924351334572
# 33 0.04075773060321808
# 7 0.04086064547300339
# 81 0.04100732505321503
# 36 0.04107917845249176
# 52 0.04112214967608452
# 53 0.04124889150261879
# 43 0.04283023625612259
# 11 0.04283617436885834
# 56 0.04379044845700264
# 61 0.04441423714160919
# 88 0.044842664152383804
# 34 0.04525986686348915
# 82 0.045513659715652466
# 63 0.04595860466361046
# 48 0.05182264745235443
# 75 0.052176572382450104
# 85 0.052239615470170975
# 50 0.054269157350063324
# 76 0.0555715449154377
# 70 0.05671587586402893
# 2 0.05690576881170273
# 30 0.057376258075237274
# 41 0.058985088020563126
# 31 0.0614013671875
# 5 0.08338937908411026
# 42 0.08356768637895584
# 23 0.08364303410053253
# 27 0.0836501345038414
# 67 0.08365894109010696
# 16 0.08367367833852768
# 28 0.0837799683213234
# 29 0.08393006771802902
# 49 0.08393760025501251
# 47 0.08394091576337814
# 3 0.08414771407842636
# 4 0.08417520672082901
# 92 0.08434383571147919
# 57 0.08447197079658508
# 20 0.0845617949962616
# 68 0.0845644399523735
# 71 0.08474820107221603
# 73 0.08477942645549774
# 46 0.08479948341846466
# 84 0.08480597287416458
# 35 0.08488906174898148
# 91 0.08530230075120926
# 8 0.08549991995096207
# 39 0.0857805460691452
# 9 0.08582958579063416
# 87 0.09998899698257446
# 58 0.1003972589969635
# 13 0.10039746016263962
# 60 0.10071887820959091
# 95 0.10098450630903244
# 21 0.10116398334503174
# 38 0.1012384295463562
# 10 0.10128352791070938
# 14 0.10137680917978287
# 89 0.10139656066894531
# 25 0.10155124217271805
# 96 0.10254580527544022
# 18 0.10271541029214859
# 22 0.10276127606630325
# 17 0.10285637527704239
# 69 0.10310408473014832
# 93 0.10423056781291962
# 66 0.12112601846456528
# 59 0.12268688529729843
# 80 0.1277388483285904
# 74 0.12783461809158325

# %% [markdown]
# # 4. training runs saved

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a = """
forward:
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        #x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        #x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                   GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  0.118581  0.374665     0
#
#                                               PREDavg  PREDmax PREDmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  2.3621  2.98898  1.5136
#
#                                               batch_size          dataset  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50          8  ws_100_3_0_1_nb
#
#                                               epochs  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50     50
#
#                                                                             hyperparams  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  d1=15_d2=50_d3=20_num_layers=4_epochs=50
#
#                                                 nrmse seed   time
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  18.899   35  1.457

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """
forward:
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        #x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                   GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  0.118581  0.374665     0
#
#                                                PREDavg  PREDmax   PREDmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  1.24927  1.60049  0.804347
#
#                                               batch_size          dataset  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50          8  ws_100_3_0_1_nb
#
#                                               epochs  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50     50
#
#                                                                             hyperparams  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  d1=15_d2=50_d3=20_num_layers=4_epochs=50
#
#                                                nrmse seed   time
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  9.569   35  1.644

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """
forward:
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                   GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  0.118581  0.374665     0
#
#                                                 PREDavg   PREDmax    PREDmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  0.208509  0.388352  0.0135015
#
#                                               batch_size          dataset  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50          8  ws_100_3_0_1_nb
#
#                                               epochs  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50     50
#
#                                                                             hyperparams  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  d1=15_d2=50_d3=20_num_layers=4_epochs=50
#
#                                                nrmse seed   time
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  1.301   35  1.662

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
forward:
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                    GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50   0.118581  0.374665     0
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=100  0.118581  0.374665     0
#
#                                                  PREDavg   PREDmax    PREDmin  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50  -0.359972 -0.183851  -0.548365
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=100  0.183681  0.304164  0.0446255
#
#                                                batch_size          dataset  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50           8  ws_100_3_0_1_nb
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=100          8  ws_100_3_0_1_nb
#
#                                                epochs  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50      50
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=100    100
#
#                                                                               hyperparams  \
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50    d1=15_d2=50_d3=20_num_layers=4_epochs=50
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=100  d1=15_d2=50_d3=20_num_layers=4_epochs=100
#
#                                                 nrmse seed   time
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=50   4.174   35  1.408
# Net7-d1=15_d2=50_d3=20_num_layers=4_epochs=100  1.179   35  3.106

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK )
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.118581  0.374665     0
#
#                                                      PREDavg  PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.375094  0.57737
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0911101          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
#
#                                                                                        hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.506   35  1.756

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK )
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.118581  0.374665     0
#
#                                                     PREDavg  PREDmax PREDmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.65206  2.18684  1.0589
#
#                                                    batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
#
#                                                                                        hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
#
#                                                      nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  12.964   35  1.697

# %%
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK )
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.118581  0.374665     0
#
#                                                      PREDavg   PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.042519  0.131545
#
#                                                      PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.034687          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
#
#                                                                                        hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.154   35  1.682

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.105246  0.311688     0
#
#                                                      PREDavg   PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.168864  0.306513
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0345129          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     80
#
#                                                                                        hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=80
#
#                                                     nrmse seed  time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.039   16  3.45

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  0.117714  0.374665     0
#
#                                                         PREDavg      PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20    -0.575428    -0.506319
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.177995     0.278812
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...     0.900667      1.15411
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80   -0.0851917   -0.0105381
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.317284     0.374255
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...    -0.186018    -0.131346
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs...    -0.236477    -0.178955
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...      2.39977      3.03935
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...   -0.0118076  -0.00491172
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    0.0967971     0.166438
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  1.29386e+07   2.4773e+07
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...      0.22061     0.245009
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...     -125.528      -85.629
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...    0.0543133    0.0710301
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...    -0.087616   -0.0662196
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  5.50549e+11  7.13873e+11
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo... -1.97462e+15 -5.70697e+14
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...      40391.4      60493.1
#
#                                                         PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20    -0.621293          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0790588          8
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...     0.660927          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80    -0.134908          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...        0.264          8
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...    -0.275861          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs...     -0.34339          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...       1.4996          8
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...   -0.0233211          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    0.0387587          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  7.96521e+06          8
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...       0.1551          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...     -158.152          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  -0.00893795          8
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...    -0.097528          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  3.68866e+11          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo... -8.74141e+15          8
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...      570.855          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs...  ws_100_3_0_1_nb    300
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    300
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...  ws_100_3_0_1_nb    300
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb    300
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  ws_100_3_0_1_nb    300
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  ws_100_3_0_1_nb    300
#
#                                                                                           hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20      d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...    d1=15_d2=50_d3=20_dK=100_num_layers=4_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80      d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...    d1=15_d2=50_d3=20_dK=100_num_layers=4_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs...     d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=300
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=300
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...   d1=15_d2=50_d3=20_dK=100_num_layers=4_epochs=300
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...   d1=15_d2=50_d3=20_dK=20_num_layers=100_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  d1=15_d2=50_d3=20_dK=100_num_layers=100_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...   d1=15_d2=50_d3=20_dK=20_num_layers=100_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  d1=15_d2=50_d3=20_dK=100_num_layers=100_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=300
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  d1=15_d2=50_d3=20_dK=20_num_layers=100_epochs=300
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...  d1=15_d2=50_d3=20_dK=100_num_layers=100_epochs...
#
#                                                           nrmse seed     time
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=20        4.969    6    0.161
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...        0.955    6    0.593
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...        5.626    6    2.739
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs=80        1.657    6    0.675
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...        1.631    6    2.963
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...        2.305    6   10.919
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=4_epochs...        2.636    6    2.413
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...       16.243    6   10.596
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=4_epoc...        1.218    6   44.014
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...        0.836    6    3.461
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  9.53408e+07    6   18.767
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...        1.089    6   79.453
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...      891.751    6   13.594
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...        0.937    6   70.283
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...         1.66    6  315.091
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  3.91432e+12    6   48.658
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=100_epo...  2.25241e+16    6  229.509
# Net7-d1=15_d2=50_d3=20_dK=100_num_layers=100_ep...       315644    6   1042.5

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
#  increasing the epochs shows down, min, up -> so normal behaviour
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
#
#                                                      PREDavg     PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.154216    0.684489
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  -1.51877 -0.00908706
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc... -0.213649    0.167513
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -12.853    0.128298
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  -2070.43    -18.4239
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -192054     -135007
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc... -0.0165595          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -3.89153          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -1.09453          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -150.852          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -9568.92          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    -234412          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     30
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     50
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     80
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb    100
#
#                                                                                          hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=30
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=50
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=80
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=100
#
#                                                           nrmse seed    time
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...        1.261    6   1.472
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...       14.478    6   3.073
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...        3.788    6    4.67
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...      271.852    6    7.92
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...      26664.2    6   11.66
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  1.36237e+06    6  15.202

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.117714  0.374665     0
#
#                                                       PREDavg   PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    819.758   1682.57
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -6535.84  -2656.36
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -1.58548  0.164523
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.0944174  0.288939
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    100.245   449.029
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.208655  0.810831
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.290706  0.872333
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  -0.701075   1.07293
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.019644  0.141416
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.111953  0.168206
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.234735  0.853074
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...     -3.565  0.164195
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.117274  0.136146
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.0863194  0.121647
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    -1.8547  0.471725
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    239.597          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -16306.8          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    -9.3614          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc... -0.0330918          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -22.3171          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.0357793          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  -0.161002          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -2.43187          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  -0.122837          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.0860491          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  0.0549846          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -23.0408          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  -0.033406          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   0.056406          8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   -13.1541          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      2
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      3
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      4
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      5
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      6
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      7
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb      8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     35
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     37
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     40
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     41
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     42
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     43
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  ws_100_3_0_1_nb     45
#
#                                                                                         hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=2
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=3
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=4
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=5
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=6
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=7
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=8
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=35
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=37
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=40
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=41
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=42
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=43
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  d1=15_d2=50_d3=20_dK=2_num_layers=100_epochs=45
#
#                                                       nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  6554.52    6  0.365
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  50876.6    6   0.51
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...     20.3    6  0.661
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    0.968    6  0.931
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...  1121.17    6   0.95
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    1.481    6  1.116
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    2.097    6  1.241
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    7.681    6  1.602
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    1.183    6  5.456
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    0.811    6   6.02
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    1.621    6  6.156
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   55.061    6   6.34
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    0.831    6  6.389
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...    0.842    6  6.749
# Net7-d1=15_d2=50_d3=20_dK=2_num_layers=100_epoc...   26.315    6   7.13

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.117714  0.374665     0
#
#                                                       PREDavg    PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5   0.731619   0.920492
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.490545  -0.352395
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.259241    0.34425
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    1.07249    1.38499
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.136735 -0.0352074
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0411797   0.135401
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0521862  0.0284381
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.108221   0.218933
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    1.15514    1.46983
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.513755   0.586884
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    1.09693     1.4221
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0112598  0.0961507
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.809606    1.03678
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0719742    0.16355
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0551531   0.043271
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0842859   0.154403
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.237976  -0.115659
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    1.01625    1.31519
#
#                                                         PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5     0.486816          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    -0.613997          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.149162          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.753198          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    -0.247152          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.0500004          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    -0.129448          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0293335          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...      0.74955          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.402822          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.722297          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.0650756          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.511038          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.000526954          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    -0.138757          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0254379          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     -0.33029          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.648252          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5  ws_100_3_0_1_nb      5
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     15
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     20
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     25
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     26
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     27
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     28
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     31
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     32
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     33
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     34
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     36
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     45
#
#                                                                                        hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=15
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=20
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=25
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=26
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=27
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=28
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=31
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=32
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=33
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=34
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=36
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=45
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=5  4.455    6  0.174
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  4.397    6  0.309
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.313    6  0.453
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  6.839    6  0.601
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.999    6  0.742
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.001    6  0.774
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.466    6    0.8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.851    6   0.83
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   7.42    6  0.893
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.921    6  0.916
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  7.016    6  0.951
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.13    6  1.024
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  4.996    6  1.155
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.898    6  1.182
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.489    6   1.35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.86    6  1.298
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.662    6  1.427
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  6.451    6  1.588

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
#
#                                                      PREDavg  PREDmax  \
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.44982  2.05181
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.415535  0.98591
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.571179  1.40433
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.36698  2.32862
#
#                                                        PREDmin batch_size  \
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.794797          8
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.00376284          8
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.0154242          8
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.502655          8
#
#                                                             dataset epochs  \
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     10
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     66
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    100
#
#                                                                                         hyperparams  \
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=10
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=66
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=100
#
#                                                     nrmse seed   time
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  9.581   57  0.724
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.515   57  2.267
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  3.676   57  3.421
# Net8-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  9.101   57  4.749

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
#
#                                                       PREDavg     PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.490726    0.658372
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.374421    0.660787
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.315041    0.573063
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.415467    0.646896
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.280156    0.537374
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.215906    0.419756
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.313948    0.594855
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.280212    0.512528
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.225269    0.440066
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.295174     0.54622
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.133791    0.328657
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.145929    0.380153
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0154773    0.212185
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0622852   0.0881889
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0257877  0.00142034
#
#                                                         PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.281704          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.120957          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0474209          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...     0.173686          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0224446          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0358964          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0398193          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0588911          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.0179951          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.000876099          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.0191796          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.0751815          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    -0.232543          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    -0.169553          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.0947495          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     42
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     47
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    200
#
#                                                                                         hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=42
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=47
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=200
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.826   57  0.307
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   2.11   57  0.891
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.769   57  1.044
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.354   57  1.148
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.571   57  1.244
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.224   57  1.517
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.775   57  1.606
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.56   57  1.681
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.254   57  1.652
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.689   57  1.685
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.993   57  1.998
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.096   57    2.6
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.336   57  3.287
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.475   57  4.851
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.228   57  6.519

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
#
#                                                       PREDavg     PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.518343    0.698183
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.443599    0.717589
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.297432    0.551079
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.358551    0.561661
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.337126    0.538418
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.271562     0.45803
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.313949    0.500465
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.283198    0.532045
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.307243    0.455163
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.251213    0.460672
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0909088    0.282091
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.335041    0.526462
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.291984    0.478839
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.17267    0.384113
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.12564    0.400638
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0546428    0.223863
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0805002    0.333714
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0945713    0.363856
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0734765     0.32173
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.103644     0.39647
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0899307    0.068032
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0396552    0.141832
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0415207 -0.00284766
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.293582          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.147472          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0602469          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.121966          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.122278          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0784021          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.117941          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0554291          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.116088          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0615537          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0654102          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.116838          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.076717          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0534622          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.113061          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.102771          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.140708          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.125002          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.152549          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.14881          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.217241          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.200785          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0851048          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     42
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     47
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     57
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     58
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     59
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     62
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     65
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     67
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     70
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     72
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    200
#
#                                                                                         hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=42
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=47
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=57
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=58
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=59
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=62
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=65
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=67
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=70
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=72
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=200
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  3.018   57  0.417
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.554   57  1.023
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.652   57  1.119
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.969   57  1.174
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.849   57  1.348
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.45   57  1.275
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.701   57  1.435
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.557   57  1.556
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.637   57  1.694
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    1.4   57  2.018
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.011   57  1.886
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.84   57  1.764
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.585   57  1.846
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.123   57  1.984
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.102   57  2.165
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.966   57  2.241
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.082   57  2.064
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.07   57  2.143
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.112   57  2.304
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.075   57  2.454
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.685   57   3.82
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.357   57  5.032
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.32   57  6.852

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net7(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 1) # one output for regression
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
#
#                                                       PREDavg    PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.542991   0.731222
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.401752   0.736386
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.282331    0.49741
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.252179   0.522999
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.383413   0.665219
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.292872   0.545073
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.254911   0.518631
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.218362   0.436595
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.222683   0.438621
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.350378   0.559555
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.299959   0.491263
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.182347   0.427644
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.317097   0.548805
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.306884   0.491723
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.294931   0.503895
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.372111   0.563157
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.193464   0.425594
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0862845   0.123913
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.129493   0.264564
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.201257   0.411925
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0546321   0.310116
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.132158   0.395597
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.222333    0.40733
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.14702   0.362437
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.10338   0.364532
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0180665   0.267624
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0324216  0.0561154
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0451496   0.106058
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.306954          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0986035          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0930097          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0210408          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.136192          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0343456          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0173363          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0354079          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0429805          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.124191          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0628589          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0541316          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0369603          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.055927          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0381193          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0814921          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0118922          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.245986          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0371714          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0373872          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.122192          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0992425          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0149553          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.057211          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.107676          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.211525          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.165642          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0265343          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     42
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     47
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     57
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     58
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     59
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     62
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     63
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     64
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     65
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     66
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     67
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     68
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     69
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     70
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     72
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    200
#
#                                                                                         hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=35
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=37
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=40
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=42
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=47
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=57
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=58
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=59
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=62
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=63
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=64
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=65
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=66
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=67
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=68
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=69
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=70
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=72
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=200
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  3.189   57  0.336
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.306   57  1.045
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.519   57  1.426
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.404   57   1.63
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.157   57   1.78
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.649   57  1.674
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.439   57  1.897
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.211   57  1.471
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.282   57  1.694
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.943   57  1.801
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.63   57  1.988
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.215   57  2.053
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.793   57  1.763
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.674   57  1.853
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.627   57   2.01
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   2.08   57  1.903
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.197   57  1.957
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.706   57  2.057
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.888   57  2.083
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.154   57  2.154
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.139   57  2.023
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.082   57  2.299
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.228   57  2.573
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.057   57  2.434
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.064   57   2.53
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.206   57  3.471
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.285   57  5.276
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.911   57  7.071

# %% [markdown]
# # 5. training executions

# %%
# %load_ext autoreload
# %autoreload 2
from torch.nn import *
from TFM_node_betweenness_models import MyNet,Net1,Net2,Net3,Net4,Net5,Net6,Net7,Net8
from TFM_node_betweenness_training import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def trainingExplosion2(dname, res_dict):
    

    

    training_dicts =[]
    for model in [Net7]:
        for d1 in [15]:
            for d2 in [50]:
                for d3 in [20]:
                    for d4 in [20]:
                        for num_layers in [4]:
                            for epochs in [10,30,45,50,55,60,62,63,64,65,66,67,68,69,70,75,100,150,200]:
                                for K in [20]:
                                    training_dicts.append(

                                        {
                                        # model params
                                        'class': model,
                                        'd1': d1,
                                        'd2': d2,
                                        'd3': d3,
                                        'd4': d4,
                                        'dK': K,
                                        'num_layers': num_layers,
                                        # now training params
                                        'dataset_name': dname,
                                        'epochs': epochs,
                                        'batch_size': 8,
                                        'seed': 57, # ws_100  57,16,12,85,24,  
                                        #'seed': 15, #KarateClub:? 37,15,19,55,65,26,45
                                        }
                                        )

    for td in training_dicts:
        basic_training(
        td,
        res_dict,
        False
        )

# %%
#analysis
dname='../datasets/precomputed-pytorchg-betweenness_old/ws_100_3_0_1_nb.pickle'
#dname='../datasets/precomputed-pytorchg-betweenness_old/KarateClub_1_nd.pickle'
res_dict={'tables':{}, 'scatterplots':{}}
trainingExplosion2(dname,res_dict)
reporting(res_dict)
a= """

epochs=100
class Net8(torch.nn.Module, MyNet):
    def __init__(self, d1=90,d2=80,d3=50,num_features=1, num_classes=1, num_layers=4,dK=10, **kwargs):
        super(Net7, self).__init__()
        self.conv1 = ChebConv(num_features, d1,K=dK,bias=False)
        self.convs = torch.nn.ModuleList()
        for i in range(num_layers - 1):
            self.convs.append(ChebConv(d1, d1,K=dK ))
        self.bn1 = nn.BatchNorm1d(d1)
        self.fc1 = nn.Linear(d1, d2)
        self.bn2 = nn.BatchNorm1d(d2)
        self.fc2 = nn.Linear(d2, d3)
        self.bn3 = nn.BatchNorm1d(d3)
        self.fc3 = nn.Linear(d3, 2) # one output for regression
        self.fc4 = nn.Linear(2,1c)
        self.num_layers = num_layers
        self.d1 = d1
        self.d2 = d2
        self.d3 = d3
        self.dK = dK

        
    def forward(self, data):
        "
            things to try:
             - GCNConv, ChebConv, GraphSage
             - K: hops
                ChebConv:
                K=1 -> 4 layers, 100 epochs better
                K=10 -> layer 4, 100 epochs better,
                k=20 -> layer 4, epochs 50 better and spread
             - relu -> remove for regression?
                relu everyvwhere -> k=20,l4,e50 spread but bad
                no relu  -> k=20,l4,e50 saturated and

                relu in each gcn layer
                +
                bn-relu-dropout in each fc layer
                = more spread, tendency up, but very bad..
             - batchnorm
             - dropout
        "
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        for conv in self.convs:
            x = conv(x, edge_index)
            #x = F.relu(x)
            x = self.bn1(x)
            #x = F.dropout(x, training=self.training)
        

        # 3 fc layers
        x = self.fc1(x)
        x = self.bn2(x)
        x = F.relu(x)
        #x = F.dropout(x, training=self.training)
        
        x = self.fc2(x)
        x = self.bn3(x)
        #x = F.relu(x)

        x = self.fc3(x)
        x = self.fc4(x)

        # output as regression target
        return x

"""
# Out:
#                                                        GTavg     GTmax GTmin  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.110167  0.311688     0
#
#                                                        PREDavg     PREDmax  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.503731    0.671631
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.415862    0.760511
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.236474     0.44307
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.377201    0.626654
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.261757    0.478857
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.184578    0.429114
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.148057    0.362589
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.141325    0.362376
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.111279    0.302955
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.0992205    0.379943
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.184173     0.39675
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.0454971    0.276354
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.0154345    0.283521
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.284159     0.45304
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.114983    0.359068
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...    0.251518    0.421164
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.053081    0.146718
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.00626415    0.136169
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.0812093  0.00712141
#
#                                                       PREDmin batch_size  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.295652          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.120749          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0457776          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   0.139084          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0353193          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0409938          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0457023          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0820318          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0887464          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.142141          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.011938          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.133537          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.153739          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.0209621          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.130922          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0098893          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   -0.20424          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch... -0.0779083          8
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  -0.135739          8
#
#                                                             dataset epochs  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     62
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     63
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     64
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     65
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     66
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     67
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     68
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     69
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     70
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb     75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  ws_100_3_0_1_nb    200
#
#                                                                                         hyperparams  \
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=10
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=30
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=45
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=50
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=55
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=60
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=62
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=63
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=64
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=65
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=66
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=67
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=68
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=69
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=70
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=75
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=100
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=150
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  d1=15_d2=50_d3=20_dK=20_num_layers=4_epochs=200
#
#                                                     nrmse seed   time
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.914   57  0.396
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   2.39   57  1.042
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.346   57  1.686
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  2.127   57  1.714
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.43   57  1.877
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.194   57  2.045
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.055   57  2.144
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.996   57  2.187
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  0.912   57  2.211
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.098   57  2.443
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.147   57  2.464
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.142   57  2.538
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.286   57  2.573
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.553   57  2.484
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.019   57  2.557
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.342   57  2.832
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.491   57  3.802
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...   1.17   57  5.596
# Net7-d1=15_d2=50_d3=20_dK=20_num_layers=4_epoch...  1.564   57  7.708
