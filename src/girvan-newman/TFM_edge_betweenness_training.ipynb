# %% [markdown]
# # 1. Codebase

# %%
from TFM_edge_betweenness_models import *
from TFM_edge_betweenness_training import *

# %%
model_list = { 'models':[] }
#for modelclass in [Net1, Net2, Net3,Net4,NetLGCN1,NetLGCN2]:
for modelclass in [NetLGCN1]:
    for d1 in [3,20,50]:
        for epochs in [2]:
            model_list['models'].append(
                {'epochs': epochs,
                'model': modelclass,
                'kwargs':{'d1': d1 }, 
                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 64},
            )

            


for modelclass in [Net1]:
    for d1 in [50,100]:
        for epochs in [300]:
            model_list['models'].append(
                {'epochs': epochs,
                'model': modelclass,
                'kwargs':{'d1': d1 }, 
                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
            )


for modelclass in [Net2, Net3]:
    for d1 in [50,100]:
    	for d2 in  [15,10]:
	        for epochs in [300]:
	            model_list['models'].append(
	                {'epochs': epochs,
	                'model': modelclass,
	                'kwargs':{'d1': d1, 'd2': d2,  }, 
	                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
	            )


for modelclass in [Net4]:
    for d1 in [50,100]:
    	for d2 in  [50,20]:
    		for d3 in [20,10]:
		        for epochs in [300]:
		            model_list['models'].append(
		                {'epochs': epochs,
		                'model': modelclass,
		                'kwargs':{'d1': d1 , 'd2': d2, 'd3': d3}, 
		                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
		            )


for modelclass in [Net5]:
    for d1 in [50,100]:
    	for d2 in  [50,20]:
    		for d3 in [20,10]:
    			for d4 in [10,5]:
			        for epochs in [300]:
			            model_list['models'].append(
			                {'epochs': epochs,
			                'model': modelclass,
			                'kwargs':{'d1': d1 , 'd2': d2, 'd3': d3, 'd4': d4}, 
			                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
			            )

# %% [markdown]
# # 2. Experiments

# %%
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']

# %%
print(dir(dataset))
# Out:
# ['__add__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_download', '_indexing', '_process', 'addEdgeNeighbors', 'collate', 'data', 'download', 'filename', 'get', 'num_classes', 'num_features', 'pre_filter', 'pre_transform', 'process', 'processed_dir', 'processed_file_names', 'processed_paths', 'raw_dir', 'raw_file_name', 'raw_file_names', 'raw_paths', 'root', 'shuffle', 'slices', 'test_mask', 'train_mask', 'transform', 'val_mask']

# %% [markdown]
# ### testing dataset

# %%
loader = DataLoader(dataset, batch_size=len(dataset), shuffle=True)
for data in loader:
    print(len(data))
    print(data.x)
    print(data.x.size())
# Out:
# 10
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])
# torch.Size([37282, 1])

# %%
          
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
#
#  total dataset nodes  37282
#
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# outside function train mask:  tensor([[7507],
#         [7510],
#         [7511],
#         [7512],
#         [7514]])
# outside function  val mask:  tensor([[0],
#         [2],
#         [3],
#         [4],
#         [6]])
# outside function test mask:  tensor([[ 1],
#         [ 5],
#         [ 7],
#         [ 8],
#         [10]])
#  dataset.train_mask.size()  torch.Size([0])
#  data.train_mask.size()  torch.Size([20878, 1])
# Kfolding:
# [tensor([19930]), tensor([19931]), tensor([19933]), tensor([19934]), tensor([19935])]
# tensor([[7507],
#         [7510],
#         [7511],
#         [7512],
#         [7514]])
#
# [tensor([7507]), tensor([7510]), tensor([7511]), tensor([7512]), tensor([7514])]
# tensor([[19930],
#         [19931],
#         [19933],
#         [19934],
#         [19935]])
#
# [tensor([7507]), tensor([7510]), tensor([7511]), tensor([7512]), tensor([7514])]
# tensor([[32287],
#         [32289],
#         [32291],
#         [32292],
#         [32293]])
#
#
#  for finaltrainig:
#  len train_mask:  20878
#  len val_mask :  5219
#  len test_mask :  11185
#
# testModel(), dataset.test_mask:  tensor([[ 1],
#         [ 5],
#         [ 7],
#         [ 8],
#         [10]])
# <class 'torch.Tensor'>
# squeezed test_mask (flattenned):  tensor([    1,     5,     7,  ..., 37279, 37280, 37281], device='cuda:0')
#
# testModels() data batch
# data.test_mask tensor([    1,     5,     7,  ..., 37279, 37280, 37281], device='cuda:0')
# data.y.size()  torch.Size([37282])
# t.size()  torch.Size([11185])
# t.mean()  tensor(2.9506e-07, device='cuda:0')
# pred.size()  torch.Size([37282, 1])
#  y.size() before torch.cat  torch.Size([0, 1])
# y.size() finally torch.Size([11185, 1])
#
#
#  errors()::------------------------
# t tensor([5.3368e-08, 8.6383e-08, 3.6918e-08,  ..., 4.2117e-07, 2.7041e-07,
#         3.1042e-07])
#  t.mean  tensor(2.9506e-07)
#  t.size()  torch.Size([11185])
#  errors(), num_samples:  11185
#  t_sum:  0.003299045318271965
#  t_tavg_sum 3.5824365071657205e-09
# 11185
# sample_variance  3.203179995677504e-13
# normalizer  5.659664297180093e-07
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.0002837087376974523
# 8.049065058912674e-08
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.0003307747538201511
# 1.8990258610074306e-07
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.00021489188657142222
# 2.3608111021644618e-07
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.0002792475570458919
# 3.140603048734647e-07
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.0008439760422334075
# 1.0263558642975568e-06
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.0002882629632949829
# 1.1094514000831168e-06
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.00021733091853093356
# 1.1566841280341578e-06
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.00021064747124910355
# 1.2010564844899818e-06
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.00031814214889891446
# 1.302270909775416e-06
#  t2.size()  torch.Size([1118])  y2.size()  torch.Size([1118])
# thesum.size()  torch.Size([])
# thesum.item()  0.0003120638430118561
# 1.3996547494343758e-06
# rmse.sqrt():  1.1186454663667022e-05
# nrmse:  19.765226480377347
#  endtime 1555339290.7756157  start 1555338177.9040508  endtime - start  1112.8715648651123  total time  1112.872
# NetLGCN1-d1=3  epochs=2 TUDataset_ENZYMES_ALLmerged___eb rmse=0.0 nrmse=19.765 time=1112.872 negatives?False

# %%
reporting(res_dict)

# %% [markdown]
# ### Training each type of model

# %%
model_list = { 'models':[] }
#for modelclass in [Net1, Net2, Net3,Net4,NetLGCN1,NetLGCN2]:
for modelclass in [NetLGCN1]:
    for d1 in [3,20,50]:
        for epochs in [2]:
            model_list['models'].append(
                {'epochs': epochs,
                'model': modelclass,
                'kwargs':{'d1': d1 }, 
                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 64},
            )
            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
#
#  total dataset nodes  37282
#
# <class 'torch.Tensor'>
# NetLGCN1-d1=3  epochs=2 TUDataset_ENZYMES_ALLmerged___eb rmse=29.995 nrmse=52200098.743 time=9.049 negatives?False
#                                         dataset epochs hyperparams neg vals  \
# NetLGCN1-d1=3  TUDataset_ENZYMES_ALLmerged___eb      2                False
#
#                      nrmse    rmse std   time
# NetLGCN1-d1=3  5.22001e+07  29.995   0  9.049

# %%
model_list = { 'models':[] }
for modelclass in [Net1]:
    for d1 in [50,100]:
        for epochs in [300]:
            model_list['models'].append(
                {'epochs': epochs,
                'model': modelclass,
                'kwargs':{'d1': d1 }, 
                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
            )
            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
#
#  total dataset nodes  37282
#
# <class 'torch.Tensor'>
# Net1-d1=50  epochs=300 TUDataset_ENZYMES_ALLmerged___eb rmse=12.151 nrmse=21675375.738 time=39.636 negatives?False
#                                      dataset epochs hyperparams neg vals  \
# Net1-d1=50  TUDataset_ENZYMES_ALLmerged___eb    300                False
#
#                   nrmse    rmse std    time
# Net1-d1=50  2.16754e+07  12.151   0  39.636

# %%
model_list = { 'models':[] }
for modelclass in [Net2, Net3]:
    for d1 in [50,100]:
    	for d2 in  [15,10]:
	        for epochs in [300]:
	            model_list['models'].append(
	                {'epochs': epochs,
	                'model': modelclass,
	                'kwargs':{'d1': d1, 'd2': d2,  }, 
	                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
	            )
            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
#
#  total dataset nodes  37282
#
# <class 'torch.Tensor'>
# Net2-d1=50_d2=15  epochs=300 TUDataset_ENZYMES_ALLmerged___eb rmse=2.678 nrmse=4754317.536 time=376.629 negatives?False
#                                            dataset epochs hyperparams  \
# Net2-d1=50_d2=15  TUDataset_ENZYMES_ALLmerged___eb    300
#
#                  neg vals        nrmse   rmse std     time
# Net2-d1=50_d2=15    False  4.75432e+06  2.678   0  376.629

# %%
model_list = { 'models':[] }
for modelclass in [Net4]:
    for d1 in [50,100]:
    	for d2 in  [50,20]:
    		for d3 in [20,10]:
		        for epochs in [300]:
		            model_list['models'].append(
		                {'epochs': epochs,
		                'model': modelclass,
		                'kwargs':{'d1': d1 , 'd2': d2, 'd3': d3}, 
		                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
		            )

            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
#
#  total dataset nodes  37282
#
# <class 'torch.Tensor'>
# Net4-d1=50_d2=50_d3=20  epochs=300 TUDataset_ENZYMES_ALLmerged___eb rmse=5.483 nrmse=9599915.32 time=210.379 negatives?False
#                                                  dataset epochs hyperparams  \
# Net4-d1=50_d2=50_d3=20  TUDataset_ENZYMES_ALLmerged___eb    300
#
#                        neg vals        nrmse   rmse std     time
# Net4-d1=50_d2=50_d3=20    False  9.59992e+06  5.483   0  210.379

# %%
model_list = { 'models':[] }
for modelclass in [Net5]:
    for d1 in [50,100]:
    	for d2 in  [50,20]:
    		for d3 in [20,10]:
    			for d4 in [10,5]:
			        for epochs in [300]:
			            model_list['models'].append(
			                {'epochs': epochs,
			                'model': modelclass,
			                'kwargs':{'d1': d1 , 'd2': d2, 'd3': d3, 'd4': d4}, 
			                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
			            )
            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_ALLmerged___eb.pickle']
#
#  total dataset nodes  37282
#
# <class 'torch.Tensor'>
# Net5-d1=50_d2=50_d3=20_d4=10  epochs=300 TUDataset_ENZYMES_ALLmerged___eb rmse=12.088 nrmse=21476105.687 time=429.706 negatives?False
#                                                        dataset epochs  \
# Net5-d1=50_d2=50_d3=20_d4=10  TUDataset_ENZYMES_ALLmerged___eb    300
#
#                              hyperparams neg vals        nrmse    rmse std  \
# Net5-d1=50_d2=50_d3=20_d4=10                False  2.14761e+07  12.088   0
#
#                                  time
# Net5-d1=50_d2=50_d3=20_d4=10  429.706

# %%
model_list = { 'models':[] }
for modelclass in [Net4]:
    for d1 in [50,100]:
    	for d2 in  [50,20]:
    		for d3 in [20,10]:
		        for epochs in [300]:
		            model_list['models'].append(
		                {'epochs': epochs,
		                'model': modelclass,
		                'kwargs':{'d1': d1 , 'd2': d2, 'd3': d3}, 
		                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
		            )

            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# Processing...
#  MyOwnDataset2: process()
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle']
# ['__call__', '__class__', '__contains__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'apply', 'cat_dim', 'clone', 'contains_isolated_nodes', 'contains_self_loops', 'contiguous', 'edge_attr', 'edge_index', 'from_dict', 'is_coalesced', 'is_directed', 'is_undirected', 'keys', 'num_edges', 'num_features', 'num_nodes', 'pos', 'test', 'test_mask', 'to', 'train', 'train_mask', 'val', 'val_mask', 'x', 'y']
# Finished reading dataset
#
# After pre filter-transform,  1
# Done!
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle']
#
#  total dataset nodes  613184
#
# <class 'torch.Tensor'>
# Net4-d1=50_d2=50_d3=20  epochs=300 PPI_ALLseparatedbetwns___eb rmse=21.668 nrmse=149123.731 time=3196.42 negatives?False
#                                             dataset epochs hyperparams  \
# Net4-d1=50_d2=50_d3=20  PPI_ALLseparatedbetwns___eb    300
#
#                        neg vals   nrmse    rmse std     time
# Net4-d1=50_d2=50_d3=20    False  149124  21.668   0  3196.42

# %%
model_list = { 'models':[] }
for modelclass in [Net4]:
    for d1 in [50,100]:
    	for d2 in  [50,20]:
    		for d3 in [20,10]:
		        for epochs in [800,1000,2000]:
		            model_list['models'].append(
		                {'epochs': epochs,
		                'model': modelclass,
		                'kwargs':{'d1': d1 , 'd2': d2, 'd3': d3}, 
		                'learning_rate': 0.01, 'weight_decay':5e-4, 'batch_size': 32},
		            )

            
res_dict={'tables':{}, 'scatterplots':{}}
dname='../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle'
dataset = loadDataset(collection='MyOwnDataset2',name=dname)

#print(dir(dataset))
print("\n total dataset nodes ",len(dataset.data.y),"\n")
modelSelection(dataset, model_list,res_dict)
            
reporting(res_dict)
# Out:
# Not implemented. Missing folders with graph files in txt for Nx format, for each program to be included in the dataset
# self.processed_paths ['data/MyOwnDataset2/processed/myowndataset2.pt']
# self.root data/MyOwnDataset2
# self.raw_dir data/MyOwnDataset2/raw
# self.raw_file_names ['../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle']
# self.raw_paths ['data/MyOwnDataset2/raw/../datasets/precomputed-pytorchg-betweenness/PPI_ALLseparatedbetwns___eb.pickle']
#
#  total dataset nodes  613184
#
# <class 'torch.Tensor'>
# Net4-d1=50_d2=50_d3=20  epochs=800 PPI_ALLseparatedbetwns___eb rmse=3.224 nrmse=22332.609 time=37247.541 negatives?False
#                                             dataset epochs hyperparams  \
# Net4-d1=50_d2=50_d3=20  PPI_ALLseparatedbetwns___eb    800
#
#                        neg vals    nrmse   rmse std       time
# Net4-d1=50_d2=50_d3=20    False  22332.6  3.224   0  37247.541

# %% [markdown]
# # 3. Experiments (old version)

# %%
def experimentBlock(dname, res_dict):
    global Net
    
    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net1(d1=20, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net1(d1=50, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net1(d1=100, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net2(d1=100,d2=15, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net2(d1=50,d2=15, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net2(d1=20,d2=10, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net3(d1=50,d2=10, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net4(d1=80,d2=40,d3=10, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=Net5(d1=100,d2=50,d3=20,d4=5, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net
    
    return

    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=NetLGCN1(d1=100, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net
    
    dataset = loadDataset(
        collection='MyOwnDataset2', 
        name=dname)
    Net=NetLGCN2(d1=100,d2=30, num_features=dataset.num_features, num_classes=dataset.num_classes)
    trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    del Net
    
    #dataset = loadDataset(
    #    collection='MyOwnDataset2', 
    #    name=dname)
    #Net=NetLGCN3(d1=100,d2=30, d3=15, num_features=dataset.num_features, num_classes=dataset.num_classes)
    #trainTestEval(dataset,  epochs=100, res_dict=res_dict)
    #del Net

# %%
res_dict={'tables':{}, 'scatterplots':{}}

# %%
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_ENZYMES_12_eb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# scatterplot (both rmse and nrmse)
# nrmse: mean,sd of train? of test? of all? of prediction? p12ML chap 3   sqrt(||t-Xb||^2/((N-1)Var(sd)))
# sreparatr nrmse for cora and proteins for example
# join proteins : 1 any node test train ,2 separate by grpah (inductive)
#  revisar limitacio gcn graph connex nomes?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /media/disk/home/pau/Projectes/GNN-MThesis/src/girvan-newman/TFM_edge_betweenness_training.py in loadDataset(collection, name)
#      28         # get the function corresponding to collection
# ---> 29         method_to_call = getattr(themodule, collection)
#      30         if name:
#
# AttributeError: module 'torch_geometric.datasets' has no attribute 'MyOwnDataset2'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-c2db8dc630a3> in <module>
#       1 dname='../datasets/precomputed-pytorch-betweenness/TUDataset_ENZYMES_12_eb.pickle'
# ----> 2 experimentBlock(dname, res_dict)
#       3 reporting(res_dict)
#       4 # scatterplot (both rmse and nrmse)
#       5 # nrmse: mean,sd of train? of test? of all? of prediction? p12ML chap 3   sqrt(||t-Xb||^2/((N-1)Var(sd)))
#
# <ipython-input-6-daf520fa9f9c> in experimentBlock(dname, res_dict)
#       4     dataset = loadDataset(
#       5         collection='MyOwnDataset2',
# ----> 6         name=dname)
#       7     Net=Net1(d1=20, num_features=dataset.num_features, num_classes=dataset.num_classes)
#       8     trainTestEval(dataset,  epochs=100, res_dict=res_dict)
#
# /media/disk/home/pau/Projectes/GNN-MThesis/src/girvan-newman/TFM_edge_betweenness_training.py in loadDataset(collection, name)
#      40         if name:
#      41
# ---> 42             dataset = method_to_call(root='./data/'+str(collection), name=name)
#      43             dataset.filename = name
#      44             return dataset
#
# /media/disk/home/pau/Projectes/GNN-MThesis/src/girvan-newman/TFM_edge_betweenness_models.py in __init__(self, root, name, transform, pre_transform)
#     306 class MyOwnDataset2():
#     307     def __init__(self,  root, name, transform=None, pre_transform=None):
# --> 308         f = open(name, 'rb')
#     309         self.data = pickle.load(f)
#     310
#
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/precomputed-pytorch-betweenness/TUDataset_ENZYMES_12_eb.pickle'

# %%
dname='../datasets/precomputed-pytorchg-betweenness/er_5_0_45_eb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
#                                             dataset epochs  \
# Net1-d1=20                             er_5_0_45_eb    100
# Net1-d1=50                             er_5_0_45_eb    100
# Net1-d1=100                            er_5_0_45_eb    100
# Net2-d1=100_d2=15                      er_5_0_45_eb    100
# Net2-d1=50_d2=15                       er_5_0_45_eb    100
# Net2-d1=20_d2=10                       er_5_0_45_eb    100
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  er_5_0_45_eb    100
# Net4-d1=80_d2=40_d3=10                 er_5_0_45_eb    100
# Net5-d1=100_d2=50_d3=20_d4=5           er_5_0_45_eb    100
#
#                                                    hyperparams neg vals  \
# Net1-d1=20                                               d1=20    False
# Net1-d1=50                                               d1=50    False
# Net1-d1=100                                             d1=100    False
# Net2-d1=100_d2=15                                 d1=100_d2=15    False
# Net2-d1=50_d2=15                                   d1=50_d2=15    False
# Net2-d1=20_d2=10                                   d1=20_d2=10    False
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)              d1=50_d2=10    False
# Net4-d1=80_d2=40_d3=10                       d1=80_d2=40_d3=10    False
# Net5-d1=100_d2=50_d3=20_d4=5           d1=100_d2=50_d3=20_d4=5    False
#
#                                        nrmse   rmse    std   time
# Net1-d1=20                             2.491  0.125   0.05  0.106
# Net1-d1=50                             3.189  0.153  0.048    0.1
# Net1-d1=100                            7.074  0.177  0.025  0.094
# Net2-d1=100_d2=15                      2.086   0.12  0.058  0.087
# Net2-d1=50_d2=15                       3.449  0.165  0.048  0.086
# Net2-d1=20_d2=10                       3.099  0.148  0.048  0.084
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  3.131   0.15  0.048  0.091
# Net4-d1=80_d2=40_d3=10                 2.074   0.12  0.058  0.126
# Net5-d1=100_d2=50_d3=20_d4=5           3.152  0.151  0.048  0.144

# %%
dname='../datasets/precomputed-pytorchg-betweenness/TUDataset_PROTEINS_996_eb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
#                                                          dataset epochs  \
# Net1-d1=20                             TUDataset_PROTEINS_996_eb    100
# Net1-d1=50                             TUDataset_PROTEINS_996_eb    100
# Net1-d1=100                            TUDataset_PROTEINS_996_eb    100
# Net2-d1=100_d2=15                      TUDataset_PROTEINS_996_eb    100
# Net2-d1=50_d2=15                       TUDataset_PROTEINS_996_eb    100
# Net2-d1=20_d2=10                       TUDataset_PROTEINS_996_eb    100
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  TUDataset_PROTEINS_996_eb    100
# Net4-d1=80_d2=40_d3=10                 TUDataset_PROTEINS_996_eb    100
# Net5-d1=100_d2=50_d3=20_d4=5           TUDataset_PROTEINS_996_eb    100
#
#                                                    hyperparams neg vals  \
# Net1-d1=20                                               d1=20    False
# Net1-d1=50                                               d1=50    False
# Net1-d1=100                                             d1=100    False
# Net2-d1=100_d2=15                                 d1=100_d2=15    False
# Net2-d1=50_d2=15                                   d1=50_d2=15    False
# Net2-d1=20_d2=10                                   d1=20_d2=10    False
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)              d1=50_d2=10    False
# Net4-d1=80_d2=40_d3=10                       d1=80_d2=40_d3=10    False
# Net5-d1=100_d2=50_d3=20_d4=5           d1=100_d2=50_d3=20_d4=5    False
#
#                                        nrmse   rmse    std   time
# Net1-d1=20                             3.392  0.362  0.107  0.116
# Net1-d1=50                             3.296  0.353  0.107  0.107
# Net1-d1=100                            5.828  0.354  0.061    0.1
# Net2-d1=100_d2=15                      3.281  0.343  0.105  0.097
# Net2-d1=50_d2=15                       3.672  0.384  0.105  0.089
# Net2-d1=20_d2=10                       3.165  0.339  0.107  0.081
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  3.283   0.35  0.106  0.105
# Net4-d1=80_d2=40_d3=10                 3.274  0.352  0.108  0.169
# Net5-d1=100_d2=50_d3=20_d4=5           3.401  0.195  0.057  0.248

# %%
dname='../datasets/precomputed-pytorchg-betweenness/QM7b_5819_eb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-156-2913ea6f33d5> in <module>
#       1 dname='../datasets/precomputed-pytorchg-betweenness/QM7b_5819_eb.pickle'
# ----> 2 experimentBlock(dname, res_dict)
#       3 reporting(res_dict)
#
# <ipython-input-127-daf520fa9f9c> in experimentBlock(dname, res_dict)
#       6         name=dname)
#       7     Net=Net1(d1=20, num_features=dataset.num_features, num_classes=dataset.num_classes)
# ----> 8     trainTestEval(dataset,  epochs=100, res_dict=res_dict)
#       9     del Net
#      10
#
# <ipython-input-149-c9287608a304> in trainTestEval(dataset, epochs, batch_size, res_dict)
#     172         optimizer.zero_grad()
#     173         out = model(data)
# --> 174         loss = F.mse_loss(out[data.train_mask], data.y[data.train_mask])
#     175         loss.backward()
#     176         optimizer.step()
#
# RuntimeError: index 19 is out of bounds for dim with size 17

# %%
dname='../datasets/precomputed-pytorchg-betweenness/ws_30_3_0_1_nb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
#                                               dataset epochs  \
# Net1-d1=20                             ws_30_3_0_1_nb    100
# Net1-d1=50                             ws_30_3_0_1_nb    100
# Net1-d1=100                            ws_30_3_0_1_nb    100
# Net2-d1=100_d2=15                      ws_30_3_0_1_nb    100
# Net2-d1=50_d2=15                       ws_30_3_0_1_nb    100
# Net2-d1=20_d2=10                       ws_30_3_0_1_nb    100
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  ws_30_3_0_1_nb    100
# Net4-d1=80_d2=40_d3=10                 ws_30_3_0_1_nb    100
# Net5-d1=100_d2=50_d3=20_d4=5           ws_30_3_0_1_nb    100
#
#                                                    hyperparams neg vals  \
# Net1-d1=20                                               d1=20    False
# Net1-d1=50                                               d1=50    False
# Net1-d1=100                                             d1=100    False
# Net2-d1=100_d2=15                                 d1=100_d2=15    False
# Net2-d1=50_d2=15                                   d1=50_d2=15    False
# Net2-d1=20_d2=10                                   d1=20_d2=10    False
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)              d1=50_d2=10    False
# Net4-d1=80_d2=40_d3=10                       d1=80_d2=40_d3=10    False
# Net5-d1=100_d2=50_d3=20_d4=5           d1=100_d2=50_d3=20_d4=5    False
#
#                                        nrmse   rmse    std   time
# Net1-d1=20                             5.338  0.868  0.163  0.101
# Net1-d1=50                             4.736  0.804   0.17    0.1
# Net1-d1=100                            4.517  0.864  0.191  0.113
# Net2-d1=100_d2=15                      4.572  0.849  0.186  0.108
# Net2-d1=50_d2=15                       4.473  0.818  0.183    0.1
# Net2-d1=20_d2=10                       4.638  0.766  0.165  0.087
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  4.869  0.921  0.189  0.107
# Net4-d1=80_d2=40_d3=10                 4.538  0.813  0.179  0.162
# Net5-d1=100_d2=50_d3=20_d4=5           4.496  0.584   0.13  0.184

# %%
dname='../datasets/precomputed-pytorchg-betweenness/ws_1000_10_0_1_nb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)

# %%
dname='../datasets/precomputed-pytorchg-betweenness/ba_1000_5_nb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)

# %%
dname='../datasets/precomputed-pytorchg-betweenness/ba_100_5_nb.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
#                                            dataset epochs  \
# Net1-d1=20                             ba_100_5_nb    100
# Net1-d1=50                             ba_100_5_nb    100
# Net1-d1=100                            ba_100_5_nb    100
# Net2-d1=100_d2=15                      ba_100_5_nb    100
# Net2-d1=50_d2=15                       ba_100_5_nb    100
# Net2-d1=20_d2=10                       ba_100_5_nb    100
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  ba_100_5_nb    100
# Net4-d1=80_d2=40_d3=10                 ba_100_5_nb    100
# Net5-d1=100_d2=50_d3=20_d4=5           ba_100_5_nb    100
#
#                                                    hyperparams neg vals  \
# Net1-d1=20                                               d1=20    False
# Net1-d1=50                                               d1=50    False
# Net1-d1=100                                             d1=100    False
# Net2-d1=100_d2=15                                 d1=100_d2=15    False
# Net2-d1=50_d2=15                                   d1=50_d2=15    False
# Net2-d1=20_d2=10                                   d1=20_d2=10    False
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)              d1=50_d2=10    False
# Net4-d1=80_d2=40_d3=10                       d1=80_d2=40_d3=10    False
# Net5-d1=100_d2=50_d3=20_d4=5           d1=100_d2=50_d3=20_d4=5    False
#
#                                        nrmse   rmse    std   time
# Net1-d1=20                             8.425  0.174  0.021  0.124
# Net1-d1=50                             8.635  0.206  0.024  0.176
# Net1-d1=100                            9.771  0.221  0.023  0.204
# Net2-d1=100_d2=15                      8.654  0.176   0.02  0.231
# Net2-d1=50_d2=15                       8.374  0.155  0.019  0.182
# Net2-d1=20_d2=10                       8.538  0.205  0.024   0.13
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  8.598  0.152  0.018  0.205
# Net4-d1=80_d2=40_d3=10                 9.043  0.153  0.017   0.37
# Net5-d1=100_d2=50_d3=20_d4=5           8.313  0.195  0.023  0.449

# %%
dname='../datasets/precomputed-pytorchg-betweenness/Planetoid_Cora_1_nd.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-9dbc3dcc8902> in loadDataset(collection, name)
#      20         # get the function corresponding to collection
# ---> 21         method_to_call = getattr(themodule, collection)
#      22         if name:
#
# AttributeError: module 'torch_geometric.datasets' has no attribute 'MyOwnDataset2'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6f7b969d4f12> in <module>
#       1 dname='../datasets/precomputed-pytorchg-betweenness/Planetoid_Cora_1_nd.pickle'
# ----> 2 experimentBlock(dname)
#       3 reporting(res_dict)
#
# <ipython-input-14-34eeed293b47> in experimentBlock(dname)
#      11     dataset = loadDataset(
#      12         collection='MyOwnDataset2',
# ---> 13         name=dname)
#      14     Net=Net1(d1=50, num_features=dataset.num_features, num_classes=dataset.num_classes)
#      15     trainTestEval(dataset,  epochs=100, res_dict=res_dict)
#
# <ipython-input-4-9dbc3dcc8902> in loadDataset(collection, name)
#      32         if name:
#      33
# ---> 34             dataset = method_to_call(root='./data/'+str(collection), name=name)
#      35             dataset.filename = name
#      36             return dataset
#
# <ipython-input-3-c4a37c6ed738> in __init__(self, root, name, transform, pre_transform)
#      61             for node in edges_dict[edge]:
#      62                 for edge2 in edges_dict.keys():
# ---> 63                     if edge2 != edge and ( edges_dict[edge2][0] == node or edges_dict[edge2][1] == node ):
#      64                         edge_neighbors[0].append(edge)
#      65                         edge_neighbors[1].append(edge2)
#
# KeyboardInterrupt:

# %%
dname='../datasets/precomputed-pytorchg-betweenness/KarateClub_1_nd.pickle'
experimentBlock(dname, res_dict)
reporting(res_dict)
# Out:
#                                                dataset epochs  \
# Net1-d1=20                             KarateClub_1_nd    100
# Net1-d1=50                             KarateClub_1_nd    100
# Net1-d1=100                            KarateClub_1_nd    100
# Net2-d1=100_d2=15                      KarateClub_1_nd    100
# Net2-d1=50_d2=15                       KarateClub_1_nd    100
# Net2-d1=20_d2=10                       KarateClub_1_nd    100
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  KarateClub_1_nd    100
# Net4-d1=80_d2=40_d3=10                 KarateClub_1_nd    100
# Net5-d1=100_d2=50_d3=20_d4=5           KarateClub_1_nd    100
#
#                                                    hyperparams neg vals  \
# Net1-d1=20                                               d1=20    False
# Net1-d1=50                                               d1=50    False
# Net1-d1=100                                             d1=100    False
# Net2-d1=100_d2=15                                 d1=100_d2=15    False
# Net2-d1=50_d2=15                                   d1=50_d2=15    False
# Net2-d1=20_d2=10                                   d1=20_d2=10    False
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)              d1=50_d2=10    False
# Net4-d1=80_d2=40_d3=10                       d1=80_d2=40_d3=10    False
# Net5-d1=100_d2=50_d3=20_d4=5           d1=100_d2=50_d3=20_d4=5    False
#
#                                        nrmse   rmse    std   time
# Net1-d1=20                             4.786  0.527   0.11  0.115
# Net1-d1=50                             4.728   0.45  0.095  0.117
# Net1-d1=100                            4.959  0.355  0.072  0.123
# Net2-d1=100_d2=15                      4.726  0.452  0.096  0.153
# Net2-d1=50_d2=15                       5.135  0.569  0.111   0.11
# Net2-d1=20_d2=10                        4.95  0.541  0.109   0.09
# Net3-SAGEgcn(1,50)-fc(50,10)-fc(10,1)  4.982  0.546  0.109  0.121
# Net4-d1=80_d2=40_d3=10                  4.87  0.549  0.113  0.189
# Net5-d1=100_d2=50_d3=20_d4=5           4.708  0.499  0.106  0.268
