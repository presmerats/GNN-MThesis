# %% [markdown]
# # Datasets preparation (GraphSAGE TF version)
#
# This notebook:
#
# - reads graphs from the PyTorch Geometric dataset, into Networkx versions of the graphs, then computes the node betweenness centrality (and edge betweenness centrality).
# - then transforms the Networkx graph into a json graph object
# - it also creates id_map, which assign every node identifier to a consecutive integer
# - it also creates class_maps, which will save the betweeness centrality of each node
# - finally an edge version, converts graph into  node representation of vertices  and saves the edge betweenees in the class_maps

# %% [markdown]
# ## 1. Code base

# %%
import importlib
import torch
import torch_geometric
from torch_geometric.data import DataLoader
import networkx as nx
from torch_geometric.data import Data
import time
import pickle
from torch_geometric.data import InMemoryDataset
import numpy as np
import traceback

      
    
def writeAdjacencyMatrixToDisk(G, filename='temp_adjacency_matrix.txt'):
    """
        Transform to networkx dataset

        possible formats: GML, Adjacency matrix, ..
        start by Adjcency list 
             --> (ignoring edge/node features)
             --> line format: source target target2 target3 ... 
        later we can improve this...
    """
    f = open(filename,'w')
    _ni=-1
    newline = False
    theline = []
    careturn = ""
    for ei in range(G.edge_index.size()[1]):
        if int(G.edge_index[0,ei].item()) != _ni:
            newline=True
            _ni=int(G.edge_index[0,ei].item())
            
        else:
            newline=False
            
            
        ni = str(G.edge_index[0,ei].item())
        vi = str(G.edge_index[1,ei].item())
        if newline:
            f.write(''.join(theline))
            #print(''.join(theline))
            #print(" --> "+str(_ni))
            theline =[]
            theline.append(careturn+ni+" ")
            theline.append(vi+" ")
            careturn = "\n"
        else:
            theline.append(vi+" ")
        # print("({},{})".format(ni,vi))
    
    
def nx_createNxGraphInMem(G):
    """
        Transform to networkx dataset

        possible formats: GML, Adjacency matrix, ..
        start by Adjcency list 
             --> (ignoring edge/node features)
             --> line format: source target target2 target3 ... 
        later we can improve this...
    """
    g = nx.MultiGraph()
   
    for ei in range(G.edge_index.size()[1]):    
        ni = str(G.edge_index[0,ei].item())
        vi = str(G.edge_index[1,ei].item())
        g.add_edge(ni,vi)
    return g
    



def pyTorchGeometricDatasetToNx(G,suffix=0):
    """
        Alternatives:
            - to disk, to nx, then dict of betweenness
            - transform in memory
            - directly pickle a G object with the betweenness
    """
    prefix = 'temp_aj_m'
    # 1. PyTorch Geometric graph -> nx -> compute betweenness 
    #             -> PyTorch Geom with target the betweenness-------
    # Transform to networkx graph
    # write to adjacency matrix on disk
    writeAdjacencyMatrixToDisk(G, filename=prefix+str(suffix)+'.txt')

    # load into a networkx graph object
    g2 = nx.read_adjlist(prefix+str(suffix)+'.txt')
    #g2 = nx_createNxGraphInMem(G)
    
    return g2




    
def loadDataset(collection, name=None, split=None, karate=None):
    # import datasets
    themodule = importlib.import_module("torch_geometric.datasets")
    # get the function corresponding to collection
    method_to_call = getattr(themodule, collection)
    try:
        if name:
            return method_to_call(root='./data/'+str(collection), name=name)
        elif split:
            return method_to_call(root='./data/'+str(collection), split=split)
        elif karate:
            return method_to_call()
        else:
            return method_to_call(root='./data/'+str(collection)) 
    except:
        traceback.print_tb()
        if name:
            return method_to_call( name=name)
        elif split:
            return method_to_call(split=split)
        else:
            return method_to_call()         
        
    
def createDataset(x, edge_index):
    return Data(x=x, edge_index=edge_index)
    

def createDatasetFromNX(g, xlen, undirected=True):
    # get edge list
    edges = g.edges
    edge_list_1 = []
    edge_list_2 = []
    for e in edges:
        # node id must be an int
        edge_list_1.append(int(e[0])) 
        edge_list_2.append(int(e[1]))
        if undirected:
            edge_list_1.append(int(e[1])) 
            edge_list_2.append(int(e[0]))
            
        
    edge_index = torch.tensor([ edge_list_1,
                                edge_list_2], dtype=torch.long)
    
    # create single 1 feature for each node
    n = xlen
    x = [[1.0] for i in range(n)]
    x = torch.tensor(x, dtype=torch.float)
    
    return createDataset(x, edge_index)
                         
def createDatasetFromNXwithTarget(g,y,xlen, undirected=True):
    dataset =  createDatasetFromNX(g,xlen, undirected)
    y = torch.FloatTensor(y)
    dataset.y = y 
    return dataset

# %%
import json
from networkx.readwrite import json_graph
import random


def  edgeToNodeTransform(g,verif=False):
    """
    # transform:
        #  1-every edge is a node
        #  2.every edge that share a node creates a link between them
        #º 3- id_map with an ide for each "edge_node"
        #  3- class_map with edge-betwweennes and id
        
        
    1) create a new graph g2
    2) iter edge of g 
    2.1) and add as node in g2
    2.2) iter edges of g looking for node in original edge, 
         add them as nodes in g2 and add links in g2
        
    """
    g2 = nx.Graph()
    i=0
    for e in g.edges_iter():
        g2.add_node(i)
        g2.node[i]['old_edge']=e
        i+=1
        
        
    for n in g2.nodes():
        # now for each node in the old_edge
        # find other edges that are neighbors
        # and add the corresponding new edge in g2

        e = g2.node[n]['old_edge']
        for n2 in g2.nodes():
            if n==n2:
                continue
            e2 = g2.node[n2]['old_edge']
            if e2[0] == e[0] or e2[1] == e[0] \
               or e2[0] == e[1] or e2[1] == e[1]:
                g2.add_edge(n,n2)
                # this will add 2 times n,n2 and n2,n edges...
                # should we remove it?
        
    return g2

def createGraphSAGEDataset(g,dname,betweenness, undirected=True, graph_type=None):
    
    # compute its node and edge betweenness
    y =[]
    x=[]
    xlen=len(g.nodes())
    feats = []
    
    class_map = {}
    id_map ={}
    i = 0
    
    if betweenness == 'node':
        nx_betweenness = nx.betweenness_centrality(g)
        #y = [ v for k,v in nx_betweenness.items()]
        y = []
        for k,v in nx_betweenness.items():
            y.append(v)
            id_map[str(k)] = i
            class_map[str(k)] = v
            i+=1
    elif betweenness == 'classes':
        nx_betweenness = nx.betweenness_centrality(g)
        
        # discretize in 10 classes and assign 
        
        y = []
        for k,v in nx_betweenness.items():
            y.append(v)
            theclass = [0]*10
            #print(theclass)
            if v*1000 > 9.0:
                theclass[9]=1
            elif v*1000 > 8.0:
                theclass[8]=1
            elif v*1000 > 7.0:
                theclass[7]=1
            elif v*1000 > 6.0:
                theclass[6]=1
            elif v*1000 > 5.0:
                theclass[5]=1
            elif v*1000 > 4.0:
                theclass[4]=1
            elif v*1000 > 3.0:
                theclass[3]=1
            elif v*1000 > 2.0:
                theclass[2]=1
            elif v*1000 > 1.0:
                theclass[1]=1
            id_map[str(k)] = i
            class_map[str(k)] = theclass
            i+=1
        
    else:
        nx_edge_betweenness = nx.edge_betweenness_centrality(g)
        
        # this part needs a rethinking, edge_betweenness goest to edges
        #class_map[str(k)] = v
        # we would need to TRANSFORM the graph and then save the betweenness 
        # as a node betweenness
        g2 = edgeToNodeTransform(g)
        g = g2
        
        y = []
        
        # add degree as a feature
        degrees = g2.degree()
        
        for n in g2.nodes():
            id_map[str(n)] = n
            class_map[str(n)] = nx_edge_betweenness[g2.node[n]['old_edge']]
            y.append(class_map[str(n)])
            feats.append(degrees[n])
            
            
        feats = np.array(feats).reshape((-1,1))
        xlen=len(y)
        
    
    
    # add 'val' and 'test' attributes to all nodes
    for nd in g.nodes():
        # random uniform with 3 values
        node = g.node[nd]
        node['val']=0
        node['test']=0
        node['train']=0
        if graph_type is None:
            rand_elem = random.choice(['val','test','train'])
        elif graph_type in ['val','train','test']:
            rand_elem=graph_type
        node[rand_elem]=1
        
        
        
    
    
    # translate into a Networkx graph json object
    jg = json_graph.node_link_data(g)
    
    # and write to disk as a json object
    with open(dname+"-G.json", "w+") as write_file:
        json.dump(jg, write_file)
    
    # id_map
    with open(dname+"-id_map.json", "w+") as write_file:
        json.dump(id_map, write_file)
    
    # class_map
    with open(dname+"-class_map.json", "w+") as write_file:
        json.dump(class_map, write_file)
        
    # features feats array
    np.save(dname+'-feats.npy', feats)
    
    
    

# plan
# 1. get graph from PyTorch Geom
# 2. transform to nx (pyTorchGeometricDatasetToNx)
# 3. call createGraphSAGEDataset(ba,'ba_1000_5','edge') 
#      or createGraphSAGEDataset(ba,'ba_1000_5','node')


def processDatasetsSingleTF(dname, single_dataset):
    G = single_dataset.data
    print(G)
    g = pyTorchGeometricDatasetToNx(G,i)
    i+=1
    print(i)
    createGraphSAGEDataset(g,'./precomputed-graphSAGE-TF/'+dname+'_'+str(i)+'_eb','edge', undirected=False) 
    createGraphSAGEDataset(g,'./precomputed-graphSAGE-TF/'+dname+'_'+str(i)+'_nd','node') 

        
def processDatasetsTF(dname, dataset):
    # set size of batch to total size of graph here
    loader = DataLoader(dataset, shuffle=False)
    i = 0
    for G in loader:
        print(G)
        g = pyTorchGeometricDatasetToNx(G,i)
        i+=1
        print(i)
        createGraphSAGEDataset(g,'./precomputed-graphSAGE-TF/'+dname+'_'+str(i)+'_eb','edge', undirected=False) 
        createGraphSAGEDataset(g,'./precomputed-graphSAGE-TF/'+dname+'_'+str(i)+'_nd','node')

# %% [markdown]
# ## 2. GraphSAGE TF Random Graph datasets

# %% [markdown]
# ### Tests

# %%
# test graph transform
print("\ntest1")
G = nx.Graph()
G.add_path([0,1,2,3])
print(list([e for e in G.edges_iter()]))
G = edgeToNodeTransform(G)
print(list([e for e in G.edges_iter()]))

print("\ntest2")
G = nx.Graph()
G.add_path([0,1,2,3])

G.add_path([4,5,6])
G.add_edge(0,4)
G.add_edge(3,6)
print(list([e for e in G.edges_iter()]))
G = edgeToNodeTransform(G)
print(list([e for e in G.edges_iter()]))


print("\ntest3")
G = nx.Graph()
G.add_path([0,1,3])

G.add_path([4,5,6])
G.add_edge(0,4)
G.add_edge(3,6)

G.add_path([7,8,9])
G.add_edge(0,7)
G.add_edge(3,9)

print(list([e for e in G.edges_iter()]))
G = edgeToNodeTransform(G)
print("nodes",G.nodes(data=True))
print(list([e for e in G.edges_iter()]))
# Out:
# test1
# [(0, 1), (1, 2), (2, 3)]
# [(0, 1), (1, 2)]
#
# test2
# [(0, 1), (0, 4), (1, 2), (2, 3), (3, 6), (4, 5), (5, 6)]
# [(0, 1), (0, 2), (1, 5), (2, 3), (3, 4), (4, 6), (5, 6)]
#
# test3
# [(0, 1), (0, 4), (0, 7), (1, 3), (3, 6), (3, 9), (4, 5), (5, 6), (7, 8), (8, 9)]
# nodes [(0, {'old_edge': (0, 1)}), (1, {'old_edge': (0, 4)}), (2, {'old_edge': (0, 7)}), (3, {'old_edge': (1, 3)}), (4, {'old_edge': (3, 6)}), (5, {'old_edge': (3, 9)}), (6, {'old_edge': (4, 5)}), (7, {'old_edge': (5, 6)}), (8, {'old_edge': (7, 8)}), (9, {'old_edge': (8, 9)})]
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 6), (2, 8), (3, 4), (3, 5), (4, 5), (4, 7), (5, 9), (6, 7), (8, 9)]

# %%
er = nx.erdos_renyi_graph(100, 0.15)
ws = nx.watts_strogatz_graph(30, 3, 0.1)
ba = nx.barabasi_albert_graph(100, 5)
red = nx.random_lobster(100, 0.9, 0.9)

createGraphSAGEDataset(er,'./precomputed-graphSAGE-TF/er_100_0_15_eb','edge', undirected=False)
# Out:
# [23 28 31 23 32 27 29 28 24 28 33 24 30 28 22 20 27 25 23 20 19 27 30 23
#  25 29 29 23 31 25 32 27 23 28 28 26 26 27 20 25 24 22 22 31 28 26 24 24
#  24 22 27 29 19 15 28 29 32 36 37 35 32 30 29 30 26 33 29 38 27 33 37 35
#  31 28 26 28 34 29 33 35 25 25 30 36 34 25 31 26 28 26 31 28 30 26 27 29
#  27 32 29 28 31 31 30 35 26 34 30 31 28 24 27 31 28 28 32 29 34 26 26 26
#  29 29 23 30 20 25 30 22 22 25 36 33 31 31 28 33 27 29 33 29 29 36 27 31
#  29 28 23 34 37 30 28 29 36 34 31 24 22 26 30 30 28 34 26 34 36 30 23 30
#  28 35 29 33 35 29 31 36 34 35 33 34 29 27 24 23 28 34 29 25 21 32 29 24
#  25 22 22 26 24 24 19 25 26 21 29 28 31 30 32 29 31 28 30 26 31 35 36 30
#  24 25 26 25 31 28 30 29 29 23 32 24 27 31 33 35 31 37 35 38 33 35 34 35
#  29 35 37 20 24 30 26 23 24 25 27 26 31 30 23 31 29 27 28 23 32 28 23 30
#  23 25 26 30 29 25 22 18 27 22 16 21 17 35 35 37 34 36 33 28 34 36 38 30
#  35 30 34 37 41 38 31 37 28 33 33 30 26 30 26 28 32 36 38 35 32 38 36 33
#  34 27 34 31 35 32 33 35 33 36 33 35 35 33 31 24 27 28 26 30 26 24 21 35
#  28 33 37 37 34 39 33 29 33 34 30 36 35 31 36 34 33 26 32 28 23 28 24 35
#  29 27 31 27 28 34 29 31 31 27 26 26 29 30 31 29 29 31 30 31 26 31 29 27
#  29 30 23 31 24 30 25 30 25 31 25 33 25 30 37 29 30 32 27 29 33 31 34 29
#  31 25 34 30 31 37 32 27 32 28 33 35 34 34 28 30 29 26 24 26 24 25 27 20
#  17 22 22 27 28 26 27 25 21 25 31 25 31 26 19 16 22 19 17 19 29 23 25 27
#  27 27 27 25 22 24 25 22 24 28 32 33 26 32 36 32 29 30 30 34 36 30 27 28
#  25 26 30 26 29 32 25 30 31 30 25 30 30 33 32 32 30 33 25 27 30 27 34 29
#  27 23 33 27 27 25 29 25 24 38 36 33 32 34 35 37 34 41 31 38 34 31 27 28
#  26 26 28 30 28 32 34 31 28 30 38 32 34 27 27 29 29 25 24 17 22 22 23 24
#  24 25 21 26 26 28 23 23 22 22 28 30 24 27 23 19 27 25 32 36 34 26 25 22
#  26 26 32 29 28 25 24 25 24 19 19 35 26 36 26 31 33 27 33 26 25 32 27 28
#  28 23 29 29 23 31 33 31 33 35 29 38 39 31 35 33 30 23 26 24 30 32 26 19
#  23 19 26 28 26 30 31 28 32 23 26 30 32 30 26 26 23 29 21 23 28 28 33 31
#  23 31 30 34 32 31 27 25 36 26 26 33 26 33 33 29 31 35 25 21 26 35 37 41
#  31 40 32 34 23 26 22 24 25 31 35 29 27 25 17 20 26 28 31 30 28 38 36 37
#  29 35 27 33 33 33 30 30 26 27 32 27 31 21 22 31 32 39 32 30 33 37 30 24
#  29 32 34 23 25 22 33 36 38 27 29]
# [[23]
#  [28]
#  [31]
#  [23]
#  [32]
#  [27]
#  [29]
#  [28]
#  [24]
#  [28]
#  [33]
#  [24]
#  [30]
#  [28]
#  [22]
#  [20]
#  [27]
#  [25]
#  [23]
#  [20]
#  [19]
#  [27]
#  [30]
#  [23]
#  [25]
#  [29]
#  [29]
#  [23]
#  [31]
#  [25]
#  [32]
#  [27]
#  [23]
#  [28]
#  [28]
#  [26]
#  [26]
#  [27]
#  [20]
#  [25]
#  [24]
#  [22]
#  [22]
#  [31]
#  [28]
#  [26]
#  [24]
#  [24]
#  [24]
#  [22]
#  [27]
#  [29]
#  [19]
#  [15]
#  [28]
#  [29]
#  [32]
#  [36]
#  [37]
#  [35]
#  [32]
#  [30]
#  [29]
#  [30]
#  [26]
#  [33]
#  [29]
#  [38]
#  [27]
#  [33]
#  [37]
#  [35]
#  [31]
#  [28]
#  [26]
#  [28]
#  [34]
#  [29]
#  [33]
#  [35]
#  [25]
#  [25]
#  [30]
#  [36]
#  [34]
#  [25]
#  [31]
#  [26]
#  [28]
#  [26]
#  [31]
#  [28]
#  [30]
#  [26]
#  [27]
#  [29]
#  [27]
#  [32]
#  [29]
#  [28]
#  [31]
#  [31]
#  [30]
#  [35]
#  [26]
#  [34]
#  [30]
#  [31]
#  [28]
#  [24]
#  [27]
#  [31]
#  [28]
#  [28]
#  [32]
#  [29]
#  [34]
#  [26]
#  [26]
#  [26]
#  [29]
#  [29]
#  [23]
#  [30]
#  [20]
#  [25]
#  [30]
#  [22]
#  [22]
#  [25]
#  [36]
#  [33]
#  [31]
#  [31]
#  [28]
#  [33]
#  [27]
#  [29]
#  [33]
#  [29]
#  [29]
#  [36]
#  [27]
#  [31]
#  [29]
#  [28]
#  [23]
#  [34]
#  [37]
#  [30]
#  [28]
#  [29]
#  [36]
#  [34]
#  [31]
#  [24]
#  [22]
#  [26]
#  [30]
#  [30]
#  [28]
#  [34]
#  [26]
#  [34]
#  [36]
#  [30]
#  [23]
#  [30]
#  [28]
#  [35]
#  [29]
#  [33]
#  [35]
#  [29]
#  [31]
#  [36]
#  [34]
#  [35]
#  [33]
#  [34]
#  [29]
#  [27]
#  [24]
#  [23]
#  [28]
#  [34]
#  [29]
#  [25]
#  [21]
#  [32]
#  [29]
#  [24]
#  [25]
#  [22]
#  [22]
#  [26]
#  [24]
#  [24]
#  [19]
#  [25]
#  [26]
#  [21]
#  [29]
#  [28]
#  [31]
#  [30]
#  [32]
#  [29]
#  [31]
#  [28]
#  [30]
#  [26]
#  [31]
#  [35]
#  [36]
#  [30]
#  [24]
#  [25]
#  [26]
#  [25]
#  [31]
#  [28]
#  [30]
#  [29]
#  [29]
#  [23]
#  [32]
#  [24]
#  [27]
#  [31]
#  [33]
#  [35]
#  [31]
#  [37]
#  [35]
#  [38]
#  [33]
#  [35]
#  [34]
#  [35]
#  [29]
#  [35]
#  [37]
#  [20]
#  [24]
#  [30]
#  [26]
#  [23]
#  [24]
#  [25]
#  [27]
#  [26]
#  [31]
#  [30]
#  [23]
#  [31]
#  [29]
#  [27]
#  [28]
#  [23]
#  [32]
#  [28]
#  [23]
#  [30]
#  [23]
#  [25]
#  [26]
#  [30]
#  [29]
#  [25]
#  [22]
#  [18]
#  [27]
#  [22]
#  [16]
#  [21]
#  [17]
#  [35]
#  [35]
#  [37]
#  [34]
#  [36]
#  [33]
#  [28]
#  [34]
#  [36]
#  [38]
#  [30]
#  [35]
#  [30]
#  [34]
#  [37]
#  [41]
#  [38]
#  [31]
#  [37]
#  [28]
#  [33]
#  [33]
#  [30]
#  [26]
#  [30]
#  [26]
#  [28]
#  [32]
#  [36]
#  [38]
#  [35]
#  [32]
#  [38]
#  [36]
#  [33]
#  [34]
#  [27]
#  [34]
#  [31]
#  [35]
#  [32]
#  [33]
#  [35]
#  [33]
#  [36]
#  [33]
#  [35]
#  [35]
#  [33]
#  [31]
#  [24]
#  [27]
#  [28]
#  [26]
#  [30]
#  [26]
#  [24]
#  [21]
#  [35]
#  [28]
#  [33]
#  [37]
#  [37]
#  [34]
#  [39]
#  [33]
#  [29]
#  [33]
#  [34]
#  [30]
#  [36]
#  [35]
#  [31]
#  [36]
#  [34]
#  [33]
#  [26]
#  [32]
#  [28]
#  [23]
#  [28]
#  [24]
#  [35]
#  [29]
#  [27]
#  [31]
#  [27]
#  [28]
#  [34]
#  [29]
#  [31]
#  [31]
#  [27]
#  [26]
#  [26]
#  [29]
#  [30]
#  [31]
#  [29]
#  [29]
#  [31]
#  [30]
#  [31]
#  [26]
#  [31]
#  [29]
#  [27]
#  [29]
#  [30]
#  [23]
#  [31]
#  [24]
#  [30]
#  [25]
#  [30]
#  [25]
#  [31]
#  [25]
#  [33]
#  [25]
#  [30]
#  [37]
#  [29]
#  [30]
#  [32]
#  [27]
#  [29]
#  [33]
#  [31]
#  [34]
#  [29]
#  [31]
#  [25]
#  [34]
#  [30]
#  [31]
#  [37]
#  [32]
#  [27]
#  [32]
#  [28]
#  [33]
#  [35]
#  [34]
#  [34]
#  [28]
#  [30]
#  [29]
#  [26]
#  [24]
#  [26]
#  [24]
#  [25]
#  [27]
#  [20]
#  [17]
#  [22]
#  [22]
#  [27]
#  [28]
#  [26]
#  [27]
#  [25]
#  [21]
#  [25]
#  [31]
#  [25]
#  [31]
#  [26]
#  [19]
#  [16]
#  [22]
#  [19]
#  [17]
#  [19]
#  [29]
#  [23]
#  [25]
#  [27]
#  [27]
#  [27]
#  [27]
#  [25]
#  [22]
#  [24]
#  [25]
#  [22]
#  [24]
#  [28]
#  [32]
#  [33]
#  [26]
#  [32]
#  [36]
#  [32]
#  [29]
#  [30]
#  [30]
#  [34]
#  [36]
#  [30]
#  [27]
#  [28]
#  [25]
#  [26]
#  [30]
#  [26]
#  [29]
#  [32]
#  [25]
#  [30]
#  [31]
#  [30]
#  [25]
#  [30]
#  [30]
#  [33]
#  [32]
#  [32]
#  [30]
#  [33]
#  [25]
#  [27]
#  [30]
#  [27]
#  [34]
#  [29]
#  [27]
#  [23]
#  [33]
#  [27]
#  [27]
#  [25]
#  [29]
#  [25]
#  [24]
#  [38]
#  [36]
#  [33]
#  [32]
#  [34]
#  [35]
#  [37]
#  [34]
#  [41]
#  [31]
#  [38]
#  [34]
#  [31]
#  [27]
#  [28]
#  [26]
#  [26]
#  [28]
#  [30]
#  [28]
#  [32]
#  [34]
#  [31]
#  [28]
#  [30]
#  [38]
#  [32]
#  [34]
#  [27]
#  [27]
#  [29]
#  [29]
#  [25]
#  [24]
#  [17]
#  [22]
#  [22]
#  [23]
#  [24]
#  [24]
#  [25]
#  [21]
#  [26]
#  [26]
#  [28]
#  [23]
#  [23]
#  [22]
#  [22]
#  [28]
#  [30]
#  [24]
#  [27]
#  [23]
#  [19]
#  [27]
#  [25]
#  [32]
#  [36]
#  [34]
#  [26]
#  [25]
#  [22]
#  [26]
#  [26]
#  [32]
#  [29]
#  [28]
#  [25]
#  [24]
#  [25]
#  [24]
#  [19]
#  [19]
#  [35]
#  [26]
#  [36]
#  [26]
#  [31]
#  [33]
#  [27]
#  [33]
#  [26]
#  [25]
#  [32]
#  [27]
#  [28]
#  [28]
#  [23]
#  [29]
#  [29]
#  [23]
#  [31]
#  [33]
#  [31]
#  [33]
#  [35]
#  [29]
#  [38]
#  [39]
#  [31]
#  [35]
#  [33]
#  [30]
#  [23]
#  [26]
#  [24]
#  [30]
#  [32]
#  [26]
#  [19]
#  [23]
#  [19]
#  [26]
#  [28]
#  [26]
#  [30]
#  [31]
#  [28]
#  [32]
#  [23]
#  [26]
#  [30]
#  [32]
#  [30]
#  [26]
#  [26]
#  [23]
#  [29]
#  [21]
#  [23]
#  [28]
#  [28]
#  [33]
#  [31]
#  [23]
#  [31]
#  [30]
#  [34]
#  [32]
#  [31]
#  [27]
#  [25]
#  [36]
#  [26]
#  [26]
#  [33]
#  [26]
#  [33]
#  [33]
#  [29]
#  [31]
#  [35]
#  [25]
#  [21]
#  [26]
#  [35]
#  [37]
#  [41]
#  [31]
#  [40]
#  [32]
#  [34]
#  [23]
#  [26]
#  [22]
#  [24]
#  [25]
#  [31]
#  [35]
#  [29]
#  [27]
#  [25]
#  [17]
#  [20]
#  [26]
#  [28]
#  [31]
#  [30]
#  [28]
#  [38]
#  [36]
#  [37]
#  [29]
#  [35]
#  [27]
#  [33]
#  [33]
#  [33]
#  [30]
#  [30]
#  [26]
#  [27]
#  [32]
#  [27]
#  [31]
#  [21]
#  [22]
#  [31]
#  [32]
#  [39]
#  [32]
#  [30]
#  [33]
#  [37]
#  [30]
#  [24]
#  [29]
#  [32]
#  [34]
#  [23]
#  [25]
#  [22]
#  [33]
#  [36]
#  [38]
#  [27]
#  [29]]

# %%
er = nx.erdos_renyi_graph(100, 0.15)
createGraphSAGEDataset(er,'./precomputed-graphSAGE-TF/er_100_0_15_nb_discrete','classes', undirected=False)

# %% [markdown]
# ### Actual Random graph datasets

# %%
er = nx.erdos_renyi_graph(100, 0.15)
createGraphSAGEDataset(er,'er_100_0_15_nb','node')
er = nx.erdos_renyi_graph(100, 0.45)
createGraphSAGEDataset(er,'er_100_0_45_nb','node')
er = nx.erdos_renyi_graph(1000, 0.15)
createGraphSAGEDataset(er,'er_1000_0_15_nb','node')
er = nx.erdos_renyi_graph(1000, 0.45)
createGraphSAGEDataset(er,'er_1000_0_45_nb','node')


ws = nx.watts_strogatz_graph(30, 3, 0.1)
createGraphSAGEDataset(ws,'ws_30_3_0_1_nb','node')
ws = nx.watts_strogatz_graph(100, 3, 0.1)
createGraphSAGEDataset(ws,'ws_100_3_0_1_nb','node')
ws = nx.watts_strogatz_graph(1000, 3, 0.1)
createGraphSAGEDataset(ws,'ws_1000_3_0_1_nb','node')


ws = nx.watts_strogatz_graph(1000, 10, 0.1)
createGraphSAGEDataset(ws,'ws_1000_10_0_1_nb','node')


ba = nx.barabasi_albert_graph(100, 5)
createGraphSAGEDataset(ba,'ba_100_5_nb','node')
ba = nx.barabasi_albert_graph(1000, 5)
createGraphSAGEDataset(ba,'ba_1000_5_nb','node')



#er = nx.erdos_renyi_graph(4000, 0.15)
#createGraphSAGEDataset(er,'er_4000_0_15_nb','node')
#er = nx.erdos_renyi_graph(4000, 0.35)
#createGraphSAGEDataset(er,'er_4000_0_35_nb','node')
#ws = nx.watts_strogatz_graph(4000, 3, 0.1)
#createGraphSAGEDataset(ws,'ws_4000_3_0_1_nb','node')
#ws = nx.watts_strogatz_graph(4000, 20, 0.1)
#createGraphSAGEDataset(ws,'ws_4000_20_0_1_nb','node')
#ba = nx.barabasi_albert_graph(4000, 5)
#createGraphSAGEDataset(ba,'ba_4000_5_nb','node')

# %%
# repeat with edge betweenness
er = nx.erdos_renyi_graph(100, 0.15)
createGraphSAGEDataset(er,'er_100_0_15_eb','edge', undirected=False)
er = nx.erdos_renyi_graph(100, 0.45)
createGraphSAGEDataset(er,'er_100_0_45_eb','edge', undirected=False)
er = nx.erdos_renyi_graph(1000, 0.15)
createGraphSAGEDataset(er,'er_1000_0_15_eb','edge', undirected=False)
er = nx.erdos_renyi_graph(1000, 0.45)
createGraphSAGEDataset(er,'er_1000_0_45_eb','edge', undirected=False)


ws = nx.watts_strogatz_graph(30, 3, 0.1)
createGraphSAGEDataset(ws,'ws_30_3_0_1_eb','edge', undirected=False)
ws = nx.watts_strogatz_graph(100, 3, 0.1)
createGraphSAGEDataset(ws,'ws_100_3_0_1_eb','edge', undirected=False)
ws = nx.watts_strogatz_graph(1000, 3, 0.1)
createGraphSAGEDataset(ws,'ws_1000_3_0_1_eb','edge', undirected=False)


ws = nx.watts_strogatz_graph(1000, 10, 0.1)
createGraphSAGEDataset(ws,'ws_1000_10_0_1_eb','edge', undirected=False)


ba = nx.barabasi_albert_graph(100, 5)
createGraphSAGEDataset(ba,'ba_100_5_eb','edge', undirected=False)
ba = nx.barabasi_albert_graph(1000, 5)
createGraphSAGEDataset(ba,'ba_1000_5_eb','edge', undirected=False)


#er = nx.erdos_renyi_graph(4000, 0.15)
#createRandomGraphDataset(er,'er_4000_0_15_eb','edge')
#er = nx.erdos_renyi_graph(4000, 0.35)
#createRandomGraphDataset(er,'er_4000_0_35_eb','edge')
#ws = nx.watts_strogatz_graph(4000, 3, 0.1)
#createRandomGraphDataset(ws,'ws_4000_3_0_1_eb','edge')
#ws = nx.watts_strogatz_graph(4000, 20, 0.1)
#createRandomGraphDataset(ws,'ws_4000_20_0_1_eb','edge')
#ba = nx.barabasi_albert_graph(4000, 5)
#createRandomGraphDataset(ba,'ba_4000_5_eb','edge')

# %%
# graphs for the inductive setting

for i in range(20):
    er = nx.erdos_renyi_graph(100, 0.15)
    createGraphSAGEDataset(er,'ind_er_100_0_15_eb_i_'+str(i),'edge', undirected=False)
    er = nx.erdos_renyi_graph(100, 0.45)
    createGraphSAGEDataset(er,'ind_er_100_0_45_eb_i_'+str(i),'edge', undirected=False)
    #er = nx.erdos_renyi_graph(1000, 0.35)
    #createGraphSAGEDataset(er,'ind_er_1000_0_35_eb_i_'+str(i),'edge', undirected=False)

    ws = nx.watts_strogatz_graph(30, 3, 0.1)
    createGraphSAGEDataset(ws,'ind_ws_30_3_0_1_eb_i_'+str(i),'edge', undirected=False)
    ws = nx.watts_strogatz_graph(100, 3, 0.1)
    createGraphSAGEDataset(ws,'ind_ws_100_3_0_1_eb_i_'+str(i),'edge', undirected=False)
    #ws = nx.watts_strogatz_graph(1000, 3, 0.1)
    #createGraphSAGEDataset(ws,'ws_1000_3_0_1_eb','edge', undirected=False)
    #ws = nx.watts_strogatz_graph(1000, 10, 0.1)
    #createGraphSAGEDataset(ws,'ws_1000_10_0_1_eb_i_'+str(i),'edge', undirected=False)

    ba = nx.barabasi_albert_graph(100, 5)
    createGraphSAGEDataset(ba,'ind_ba_100_5_eb_i_'+str(i),'edge', undirected=False)
    #ba = nx.barabasi_albert_graph(1000, 5)
    #createGraphSAGEDataset(ba,'ba_1000_5_eb','edge', undirected=False)

# %% [markdown]
# ## 3. GraphSAGE TF Benchmark datasets

# %%
#KarateClub
#print("\nKarateClub")
#dname='KarateClub'
#dataset = torch_geometric.datasets.KarateClub()
#processDatasetsTF(dname, dataset)



#PROTEINS FROM TUDataset
print("\nTUDataset PROTEINS")
dname='TUDataset'
name='PROTEINS'
dataset = loadDataset(dname,name)
processDatasetsTF(dname+'_'+name, dataset)
# Out:
# TUDataset PROTEINS
# Downloading https://ls11-www.cs.uni-dortmund.de/people/morris/graphkerneldatasets/PROTEINS.zip
# Extracting data/TUDataset/PROTEINS.zip
# Batch(batch=[37], edge_index=[2, 168], x=[37, 3], y=[1])
# 1
# Batch(batch=[23], edge_index=[2, 102], x=[23, 3], y=[1])
# 2
# Batch(batch=[25], edge_index=[2, 92], x=[25, 3], y=[1])
# 3
# Batch(batch=[24], edge_index=[2, 90], x=[24, 3], y=[1])
# 4
# Batch(batch=[23], edge_index=[2, 90], x=[23, 3], y=[1])
# 5
# Batch(batch=[24], edge_index=[2, 92], x=[24, 3], y=[1])
# 6
# Batch(batch=[26], edge_index=[2, 118], x=[26, 3], y=[1])
# 7
# Batch(batch=[88], edge_index=[2, 266], x=[88, 3], y=[1])
# 8
# Batch(batch=[23], edge_index=[2, 78], x=[23, 3], y=[1])
# 9
# Batch(batch=[32], edge_index=[2, 106], x=[32, 3], y=[1])
# 10
# Batch(batch=[4], edge_index=[2, 12], x=[4, 3], y=[1])
# 11
# Batch(batch=[14], edge_index=[2, 56], x=[14, 3], y=[1])
# 12
# Batch(batch=[42], edge_index=[2, 150], x=[42, 3], y=[1])
# 13
# Batch(batch=[41], edge_index=[2, 146], x=[41, 3], y=[1])
# 14
# Batch(batch=[36], edge_index=[2, 128], x=[36, 3], y=[1])
# 15
# Batch(batch=[55], edge_index=[2, 194], x=[55, 3], y=[1])
# 16
# Batch(batch=[40], edge_index=[2, 190], x=[40, 3], y=[1])
# 17
# Batch(batch=[38], edge_index=[2, 182], x=[38, 3], y=[1])
# 18
# Batch(batch=[2], edge_index=[2, 2], x=[2, 3], y=[1])
# 19
# Batch(batch=[35], edge_index=[2, 140], x=[35, 3], y=[1])
# 20
# Batch(batch=[42], edge_index=[2, 180], x=[42, 3], y=[1])
# 21
# Batch(batch=[41], edge_index=[2, 180], x=[41, 3], y=[1])
# 22
# Batch(batch=[39], edge_index=[2, 162], x=[39, 3], y=[1])
# 23
# Batch(batch=[42], edge_index=[2, 184], x=[42, 3], y=[1])
# 24
# Batch(batch=[41], edge_index=[2, 176], x=[41, 3], y=[1])
# 25
# Batch(batch=[40], edge_index=[2, 170], x=[40, 3], y=[1])
# 26
# Batch(batch=[37], edge_index=[2, 166], x=[37, 3], y=[1])
# 27
# Batch(batch=[23], edge_index=[2, 98], x=[23, 3], y=[1])
# 28
# Batch(batch=[22], edge_index=[2, 94], x=[22, 3], y=[1])
# 29
# Batch(batch=[34], edge_index=[2, 132], x=[34, 3], y=[1])
# 30
# Batch(batch=[38], edge_index=[2, 162], x=[38, 3], y=[1])
# 31
# Batch(batch=[38], edge_index=[2, 158], x=[38, 3], y=[1])
# 32
# Batch(batch=[39], edge_index=[2, 164], x=[39, 3], y=[1])
# 33
# Batch(batch=[8], edge_index=[2, 28], x=[8, 3], y=[1])
# 34
# Batch(batch=[23], edge_index=[2, 88], x=[23, 3], y=[1])
# 35
# Batch(batch=[42], edge_index=[2, 162], x=[42, 3], y=[1])
# 36
# Batch(batch=[42], edge_index=[2, 160], x=[42, 3], y=[1])
# 37
# Batch(batch=[100], edge_index=[2, 32], x=[100, 3], y=[1])
# 38
# Batch(batch=[24], edge_index=[2, 86], x=[24, 3], y=[1])
# 39
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 40
# Batch(batch=[47], edge_index=[2, 190], x=[47, 3], y=[1])
# 41
# Batch(batch=[45], edge_index=[2, 194], x=[45, 3], y=[1])
# 42
# Batch(batch=[45], edge_index=[2, 190], x=[45, 3], y=[1])
# 43
# Batch(batch=[45], edge_index=[2, 190], x=[45, 3], y=[1])
# 44
# Batch(batch=[46], edge_index=[2, 194], x=[46, 3], y=[1])
# 45
# Batch(batch=[44], edge_index=[2, 190], x=[44, 3], y=[1])
# 46
# Batch(batch=[30], edge_index=[2, 102], x=[30, 3], y=[1])
# 47
# Batch(batch=[32], edge_index=[2, 114], x=[32, 3], y=[1])
# 48
# Batch(batch=[33], edge_index=[2, 128], x=[33, 3], y=[1])
# 49
# Batch(batch=[9], edge_index=[2, 30], x=[9, 3], y=[1])
# 50
# Batch(batch=[27], edge_index=[2, 94], x=[27, 3], y=[1])
# 51
# Batch(batch=[39], edge_index=[2, 170], x=[39, 3], y=[1])
# 52
# Batch(batch=[16], edge_index=[2, 62], x=[16, 3], y=[1])
# 53
# Batch(batch=[18], edge_index=[2, 62], x=[18, 3], y=[1])
# 54
# Batch(batch=[7], edge_index=[2, 24], x=[7, 3], y=[1])
# 55
# Batch(batch=[18], edge_index=[2, 74], x=[18, 3], y=[1])
# 56
# Batch(batch=[10], edge_index=[2, 36], x=[10, 3], y=[1])
# 57
# Batch(batch=[21], edge_index=[2, 100], x=[21, 3], y=[1])
# 58
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 59
# Batch(batch=[10], edge_index=[2, 36], x=[10, 3], y=[1])
# 60
# Batch(batch=[9], edge_index=[2, 32], x=[9, 3], y=[1])
# 61
# Batch(batch=[39], edge_index=[2, 140], x=[39, 3], y=[1])
# 62
# Batch(batch=[33], edge_index=[2, 110], x=[33, 3], y=[1])
# 63
# Batch(batch=[29], edge_index=[2, 98], x=[29, 3], y=[1])
# 64
# Batch(batch=[24], edge_index=[2, 78], x=[24, 3], y=[1])
# 65
# Batch(batch=[25], edge_index=[2, 86], x=[25, 3], y=[1])
# 66
# Batch(batch=[30], edge_index=[2, 108], x=[30, 3], y=[1])
# 67
# Batch(batch=[38], edge_index=[2, 150], x=[38, 3], y=[1])
# 68
# Batch(batch=[28], edge_index=[2, 110], x=[28, 3], y=[1])
# 69
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 70
# Batch(batch=[38], edge_index=[2, 176], x=[38, 3], y=[1])
# 71
# Batch(batch=[40], edge_index=[2, 140], x=[40, 3], y=[1])
# 72
# Batch(batch=[40], edge_index=[2, 174], x=[40, 3], y=[1])
# 73
# Batch(batch=[42], edge_index=[2, 188], x=[42, 3], y=[1])
# 74
# Batch(batch=[20], edge_index=[2, 72], x=[20, 3], y=[1])
# 75
# Batch(batch=[19], edge_index=[2, 70], x=[19, 3], y=[1])
# 76
# Batch(batch=[16], edge_index=[2, 56], x=[16, 3], y=[1])
# 77
# Batch(batch=[17], edge_index=[2, 58], x=[17, 3], y=[1])
# 78
# Batch(batch=[20], edge_index=[2, 80], x=[20, 3], y=[1])
# 79
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 80
# Batch(batch=[33], edge_index=[2, 138], x=[33, 3], y=[1])
# 81
# Batch(batch=[23], edge_index=[2, 88], x=[23, 3], y=[1])
# 82
# Batch(batch=[23], edge_index=[2, 84], x=[23, 3], y=[1])
# 83
# Batch(batch=[35], edge_index=[2, 148], x=[35, 3], y=[1])
# 84
# Batch(batch=[33], edge_index=[2, 136], x=[33, 3], y=[1])
# 85
# Batch(batch=[39], edge_index=[2, 138], x=[39, 3], y=[1])
# 86
# Batch(batch=[40], edge_index=[2, 146], x=[40, 3], y=[1])
# 87
# Batch(batch=[38], edge_index=[2, 182], x=[38, 3], y=[1])
# 88
# Batch(batch=[40], edge_index=[2, 188], x=[40, 3], y=[1])
# 89
# Batch(batch=[38], edge_index=[2, 132], x=[38, 3], y=[1])
# 90
# Batch(batch=[37], edge_index=[2, 158], x=[37, 3], y=[1])
# 91
# Batch(batch=[36], edge_index=[2, 154], x=[36, 3], y=[1])
# 92
# Batch(batch=[34], edge_index=[2, 112], x=[34, 3], y=[1])
# 93
# Batch(batch=[34], edge_index=[2, 134], x=[34, 3], y=[1])
# 94
# Batch(batch=[32], edge_index=[2, 128], x=[32, 3], y=[1])
# 95
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 96
# Batch(batch=[32], edge_index=[2, 130], x=[32, 3], y=[1])
# 97
# Batch(batch=[34], edge_index=[2, 134], x=[34, 3], y=[1])
# 98
# Batch(batch=[30], edge_index=[2, 116], x=[30, 3], y=[1])
# 99
# Batch(batch=[5], edge_index=[2, 18], x=[5, 3], y=[1])
# 100
# Batch(batch=[45], edge_index=[2, 176], x=[45, 3], y=[1])
# 101
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 102
# Batch(batch=[59], edge_index=[2, 230], x=[59, 3], y=[1])
# 103
# Batch(batch=[32], edge_index=[2, 128], x=[32, 3], y=[1])
# 104
# Batch(batch=[33], edge_index=[2, 138], x=[33, 3], y=[1])
# 105
# Batch(batch=[17], edge_index=[2, 60], x=[17, 3], y=[1])
# 106
# Batch(batch=[39], edge_index=[2, 166], x=[39, 3], y=[1])
# 107
# Batch(batch=[38], edge_index=[2, 164], x=[38, 3], y=[1])
# 108
# Batch(batch=[35], edge_index=[2, 140], x=[35, 3], y=[1])
# 109
# Batch(batch=[16], edge_index=[2, 58], x=[16, 3], y=[1])
# 110
# Batch(batch=[26], edge_index=[2, 98], x=[26, 3], y=[1])
# 111
# Batch(batch=[51], edge_index=[2, 190], x=[51, 3], y=[1])
# 112
# Batch(batch=[52], edge_index=[2, 196], x=[52, 3], y=[1])
# 113
# Batch(batch=[25], edge_index=[2, 94], x=[25, 3], y=[1])
# 114
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 115
# Batch(batch=[42], edge_index=[2, 148], x=[42, 3], y=[1])
# 116
# Batch(batch=[46], edge_index=[2, 180], x=[46, 3], y=[1])
# 117
# Batch(batch=[96], edge_index=[2, 242], x=[96, 3], y=[1])
# 118
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 119
# Batch(batch=[22], edge_index=[2, 92], x=[22, 3], y=[1])
# 120
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 121
# Batch(batch=[14], edge_index=[2, 58], x=[14, 3], y=[1])
# 122
# Batch(batch=[90], edge_index=[2, 254], x=[90, 3], y=[1])
# 123
# Batch(batch=[14], edge_index=[2, 62], x=[14, 3], y=[1])
# 124
# Batch(batch=[14], edge_index=[2, 66], x=[14, 3], y=[1])
# 125
# Batch(batch=[32], edge_index=[2, 94], x=[32, 3], y=[1])
# 126
# Batch(batch=[11], edge_index=[2, 46], x=[11, 3], y=[1])
# 127
# Batch(batch=[26], edge_index=[2, 74], x=[26, 3], y=[1])
# 128
# Batch(batch=[11], edge_index=[2, 40], x=[11, 3], y=[1])
# 129
# Batch(batch=[14], edge_index=[2, 50], x=[14, 3], y=[1])
# 130
# Batch(batch=[18], edge_index=[2, 70], x=[18, 3], y=[1])
# 131
# Batch(batch=[16], edge_index=[2, 64], x=[16, 3], y=[1])
# 132
# Batch(batch=[17], edge_index=[2, 68], x=[17, 3], y=[1])
# 133
# Batch(batch=[32], edge_index=[2, 102], x=[32, 3], y=[1])
# 134
# Batch(batch=[13], edge_index=[2, 52], x=[13, 3], y=[1])
# 135
# Batch(batch=[3], edge_index=[2, 6], x=[3, 3], y=[1])
# 136
# Batch(batch=[22], edge_index=[2, 80], x=[22, 3], y=[1])
# 137
# Batch(batch=[16], edge_index=[2, 72], x=[16, 3], y=[1])
# 138
# Batch(batch=[38], edge_index=[2, 164], x=[38, 3], y=[1])
# 139
# Batch(batch=[13], edge_index=[2, 56], x=[13, 3], y=[1])
# 140
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 141
# Batch(batch=[14], edge_index=[2, 58], x=[14, 3], y=[1])
# 142
# Batch(batch=[39], edge_index=[2, 122], x=[39, 3], y=[1])
# 143
# Batch(batch=[19], edge_index=[2, 70], x=[19, 3], y=[1])
# 144
# Batch(batch=[20], edge_index=[2, 78], x=[20, 3], y=[1])
# 145
# Batch(batch=[39], edge_index=[2, 174], x=[39, 3], y=[1])
# 146
# Batch(batch=[40], edge_index=[2, 168], x=[40, 3], y=[1])
# 147
# Batch(batch=[39], edge_index=[2, 160], x=[39, 3], y=[1])
# 148
# Batch(batch=[39], edge_index=[2, 164], x=[39, 3], y=[1])
# 149
# Batch(batch=[29], edge_index=[2, 82], x=[29, 3], y=[1])
# 150
# Batch(batch=[22], edge_index=[2, 80], x=[22, 3], y=[1])
# 151
# Batch(batch=[11], edge_index=[2, 44], x=[11, 3], y=[1])
# 152
# Batch(batch=[8], edge_index=[2, 32], x=[8, 3], y=[1])
# 153
# Batch(batch=[13], edge_index=[2, 44], x=[13, 3], y=[1])
# 154
# Batch(batch=[18], edge_index=[2, 66], x=[18, 3], y=[1])
# 155
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 156
# Batch(batch=[8], edge_index=[2, 30], x=[8, 3], y=[1])
# 157
# Batch(batch=[40], edge_index=[2, 126], x=[40, 3], y=[1])
# 158
# Batch(batch=[12], edge_index=[2, 50], x=[12, 3], y=[1])
# 159
# Batch(batch=[22], edge_index=[2, 96], x=[22, 3], y=[1])
# 160
# Batch(batch=[22], edge_index=[2, 84], x=[22, 3], y=[1])
# 161
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 162
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 163
# Batch(batch=[17], edge_index=[2, 72], x=[17, 3], y=[1])
# 164
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 165
# Batch(batch=[22], edge_index=[2, 72], x=[22, 3], y=[1])
# 166
# Batch(batch=[43], edge_index=[2, 188], x=[43, 3], y=[1])
# 167
# Batch(batch=[42], edge_index=[2, 168], x=[42, 3], y=[1])
# 168
# Batch(batch=[44], edge_index=[2, 188], x=[44, 3], y=[1])
# 169
# Batch(batch=[24], edge_index=[2, 82], x=[24, 3], y=[1])
# 170
# Batch(batch=[48], edge_index=[2, 198], x=[48, 3], y=[1])
# 171
# Batch(batch=[25], edge_index=[2, 92], x=[25, 3], y=[1])
# 172
# Batch(batch=[46], edge_index=[2, 192], x=[46, 3], y=[1])
# 173
# Batch(batch=[48], edge_index=[2, 196], x=[48, 3], y=[1])
# 174
# Batch(batch=[25], edge_index=[2, 86], x=[25, 3], y=[1])
# 175
# Batch(batch=[48], edge_index=[2, 192], x=[48, 3], y=[1])
# 176
# Batch(batch=[44], edge_index=[2, 192], x=[44, 3], y=[1])
# 177
# Batch(batch=[42], edge_index=[2, 176], x=[42, 3], y=[1])
# 178
# Batch(batch=[40], edge_index=[2, 118], x=[40, 3], y=[1])
# 179
# Batch(batch=[38], edge_index=[2, 120], x=[38, 3], y=[1])
# 180
# Batch(batch=[40], edge_index=[2, 162], x=[40, 3], y=[1])
# 181
# Batch(batch=[41], edge_index=[2, 172], x=[41, 3], y=[1])
# 182
# Batch(batch=[42], edge_index=[2, 188], x=[42, 3], y=[1])
# 183
# Batch(batch=[40], edge_index=[2, 182], x=[40, 3], y=[1])
# 184
# Batch(batch=[44], edge_index=[2, 190], x=[44, 3], y=[1])
# 185
# Batch(batch=[24], edge_index=[2, 80], x=[24, 3], y=[1])
# 186
# Batch(batch=[44], edge_index=[2, 188], x=[44, 3], y=[1])
# 187
# Batch(batch=[20], edge_index=[2, 78], x=[20, 3], y=[1])
# 188
# Batch(batch=[42], edge_index=[2, 190], x=[42, 3], y=[1])
# 189
# Batch(batch=[27], edge_index=[2, 98], x=[27, 3], y=[1])
# 190
# Batch(batch=[48], edge_index=[2, 192], x=[48, 3], y=[1])
# 191
# Batch(batch=[31], edge_index=[2, 132], x=[31, 3], y=[1])
# 192
# Batch(batch=[30], edge_index=[2, 120], x=[30, 3], y=[1])
# 193
# Batch(batch=[46], edge_index=[2, 200], x=[46, 3], y=[1])
# 194
# Batch(batch=[47], edge_index=[2, 184], x=[47, 3], y=[1])
# 195
# Batch(batch=[50], edge_index=[2, 172], x=[50, 3], y=[1])
# 196
# Batch(batch=[40], edge_index=[2, 154], x=[40, 3], y=[1])
# 197
# Batch(batch=[55], edge_index=[2, 154], x=[55, 3], y=[1])
# 198
# Batch(batch=[62], edge_index=[2, 216], x=[62, 3], y=[1])
# 199
# Batch(batch=[34], edge_index=[2, 144], x=[34, 3], y=[1])
# 200
# Batch(batch=[29], edge_index=[2, 106], x=[29, 3], y=[1])
# 201
# Batch(batch=[25], edge_index=[2, 90], x=[25, 3], y=[1])
# 202
# Batch(batch=[56], edge_index=[2, 200], x=[56, 3], y=[1])
# 203
# Batch(batch=[57], edge_index=[2, 210], x=[57, 3], y=[1])
# 204
# Batch(batch=[27], edge_index=[2, 122], x=[27, 3], y=[1])
# 205
# Batch(batch=[22], edge_index=[2, 86], x=[22, 3], y=[1])
# 206
# Batch(batch=[24], edge_index=[2, 86], x=[24, 3], y=[1])
# 207
# Batch(batch=[23], edge_index=[2, 100], x=[23, 3], y=[1])
# 208
# Batch(batch=[57], edge_index=[2, 202], x=[57, 3], y=[1])
# 209
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 210
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 211
# Batch(batch=[23], edge_index=[2, 94], x=[23, 3], y=[1])
# 212
# Batch(batch=[25], edge_index=[2, 110], x=[25, 3], y=[1])
# 213
# Batch(batch=[23], edge_index=[2, 102], x=[23, 3], y=[1])
# 214
# Batch(batch=[48], edge_index=[2, 208], x=[48, 3], y=[1])
# 215
# Batch(batch=[27], edge_index=[2, 94], x=[27, 3], y=[1])
# 216
# Batch(batch=[15], edge_index=[2, 68], x=[15, 3], y=[1])
# 217
# Batch(batch=[44], edge_index=[2, 194], x=[44, 3], y=[1])
# 218
# Batch(batch=[29], edge_index=[2, 128], x=[29, 3], y=[1])
# 219
# Batch(batch=[21], edge_index=[2, 82], x=[21, 3], y=[1])
# 220
# Batch(batch=[34], edge_index=[2, 126], x=[34, 3], y=[1])
# 221
# Batch(batch=[30], edge_index=[2, 114], x=[30, 3], y=[1])
# 222
# Batch(batch=[40], edge_index=[2, 158], x=[40, 3], y=[1])
# 223
# Batch(batch=[54], edge_index=[2, 210], x=[54, 3], y=[1])
# 224
# Batch(batch=[18], edge_index=[2, 70], x=[18, 3], y=[1])
# 225
# Batch(batch=[36], edge_index=[2, 148], x=[36, 3], y=[1])
# 226
# Batch(batch=[37], edge_index=[2, 162], x=[37, 3], y=[1])
# 227
# Batch(batch=[34], edge_index=[2, 152], x=[34, 3], y=[1])
# 228
# Batch(batch=[23], edge_index=[2, 100], x=[23, 3], y=[1])
# 229
# Batch(batch=[32], edge_index=[2, 136], x=[32, 3], y=[1])
# 230
# Batch(batch=[33], edge_index=[2, 152], x=[33, 3], y=[1])
# 231
# Batch(batch=[29], edge_index=[2, 130], x=[29, 3], y=[1])
# 232
# Batch(batch=[39], edge_index=[2, 142], x=[39, 3], y=[1])
# 233
# Batch(batch=[34], edge_index=[2, 140], x=[34, 3], y=[1])
# 234
# Batch(batch=[36], edge_index=[2, 142], x=[36, 3], y=[1])
# 235
# Batch(batch=[21], edge_index=[2, 70], x=[21, 3], y=[1])
# 236
# Batch(batch=[6], edge_index=[2, 22], x=[6, 3], y=[1])
# 237
# Batch(batch=[22], edge_index=[2, 100], x=[22, 3], y=[1])
# 238
# Batch(batch=[18], edge_index=[2, 80], x=[18, 3], y=[1])
# 239
# Batch(batch=[18], edge_index=[2, 82], x=[18, 3], y=[1])
# 240
# Batch(batch=[34], edge_index=[2, 128], x=[34, 3], y=[1])
# 241
# Batch(batch=[32], edge_index=[2, 122], x=[32, 3], y=[1])
# 242
# Batch(batch=[33], edge_index=[2, 124], x=[33, 3], y=[1])
# 243
# Batch(batch=[28], edge_index=[2, 124], x=[28, 3], y=[1])
# 244
# Batch(batch=[40], edge_index=[2, 176], x=[40, 3], y=[1])
# 245
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 246
# Batch(batch=[39], edge_index=[2, 116], x=[39, 3], y=[1])
# 247
# Batch(batch=[28], edge_index=[2, 96], x=[28, 3], y=[1])
# 248
# Batch(batch=[29], edge_index=[2, 104], x=[29, 3], y=[1])
# 249
# Batch(batch=[30], edge_index=[2, 134], x=[30, 3], y=[1])
# 250
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 251
# Batch(batch=[32], edge_index=[2, 120], x=[32, 3], y=[1])
# 252
# Batch(batch=[35], edge_index=[2, 132], x=[35, 3], y=[1])
# 253
# Batch(batch=[24], edge_index=[2, 80], x=[24, 3], y=[1])
# 254
# Batch(batch=[17], edge_index=[2, 60], x=[17, 3], y=[1])
# 255
# Batch(batch=[18], edge_index=[2, 66], x=[18, 3], y=[1])
# 256
# Batch(batch=[16], edge_index=[2, 58], x=[16, 3], y=[1])
# 257
# Batch(batch=[19], edge_index=[2, 72], x=[19, 3], y=[1])
# 258
# Batch(batch=[19], edge_index=[2, 70], x=[19, 3], y=[1])
# 259
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 260
# Batch(batch=[23], edge_index=[2, 104], x=[23, 3], y=[1])
# 261
# Batch(batch=[25], edge_index=[2, 102], x=[25, 3], y=[1])
# 262
# Batch(batch=[27], edge_index=[2, 120], x=[27, 3], y=[1])
# 263
# Batch(batch=[24], edge_index=[2, 96], x=[24, 3], y=[1])
# 264
# Batch(batch=[24], edge_index=[2, 98], x=[24, 3], y=[1])
# 265
# Batch(batch=[32], edge_index=[2, 122], x=[32, 3], y=[1])
# 266
# Batch(batch=[31], edge_index=[2, 118], x=[31, 3], y=[1])
# 267
# Batch(batch=[33], edge_index=[2, 142], x=[33, 3], y=[1])
# 268
# Batch(batch=[34], edge_index=[2, 146], x=[34, 3], y=[1])
# 269
# Batch(batch=[32], edge_index=[2, 120], x=[32, 3], y=[1])
# 270
# Batch(batch=[32], edge_index=[2, 140], x=[32, 3], y=[1])
# 271
# Batch(batch=[44], edge_index=[2, 156], x=[44, 3], y=[1])
# 272
# Batch(batch=[40], edge_index=[2, 168], x=[40, 3], y=[1])
# 273
# Batch(batch=[40], edge_index=[2, 146], x=[40, 3], y=[1])
# 274
# Batch(batch=[38], edge_index=[2, 122], x=[38, 3], y=[1])
# 275
# Batch(batch=[30], edge_index=[2, 112], x=[30, 3], y=[1])
# 276
# Batch(batch=[38], edge_index=[2, 140], x=[38, 3], y=[1])
# 277
# Batch(batch=[44], edge_index=[2, 170], x=[44, 3], y=[1])
# 278
# Batch(batch=[60], edge_index=[2, 214], x=[60, 3], y=[1])
# 279
# Batch(batch=[28], edge_index=[2, 102], x=[28, 3], y=[1])
# 280
# Batch(batch=[16], edge_index=[2, 64], x=[16, 3], y=[1])
# 281
# Batch(batch=[50], edge_index=[2, 172], x=[50, 3], y=[1])
# 282
# Batch(batch=[52], edge_index=[2, 174], x=[52, 3], y=[1])
# 283
# Batch(batch=[48], edge_index=[2, 156], x=[48, 3], y=[1])
# 284
# Batch(batch=[50], edge_index=[2, 168], x=[50, 3], y=[1])
# 285
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 286
# Batch(batch=[43], edge_index=[2, 166], x=[43, 3], y=[1])
# 287
# Batch(batch=[41], edge_index=[2, 158], x=[41, 3], y=[1])
# 288
# Batch(batch=[39], edge_index=[2, 160], x=[39, 3], y=[1])
# 289
# Batch(batch=[38], edge_index=[2, 148], x=[38, 3], y=[1])
# 290
# Batch(batch=[62], edge_index=[2, 208], x=[62, 3], y=[1])
# 291
# Batch(batch=[60], edge_index=[2, 200], x=[60, 3], y=[1])
# 292
# Batch(batch=[96], edge_index=[2, 218], x=[96, 3], y=[1])
# 293
# Batch(batch=[54], edge_index=[2, 198], x=[54, 3], y=[1])
# 294
# Batch(batch=[124], edge_index=[2, 278], x=[124, 3], y=[1])
# 295
# Batch(batch=[126], edge_index=[2, 282], x=[126, 3], y=[1])
# 296
# Batch(batch=[122], edge_index=[2, 298], x=[122, 3], y=[1])
# 297
# Batch(batch=[24], edge_index=[2, 102], x=[24, 3], y=[1])
# 298
# Batch(batch=[41], edge_index=[2, 148], x=[41, 3], y=[1])
# 299
# Batch(batch=[49], edge_index=[2, 186], x=[49, 3], y=[1])
# 300
# Batch(batch=[44], edge_index=[2, 178], x=[44, 3], y=[1])
# 301
# Batch(batch=[42], edge_index=[2, 168], x=[42, 3], y=[1])
# 302
# Batch(batch=[41], edge_index=[2, 166], x=[41, 3], y=[1])
# 303
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 304
# Batch(batch=[46], edge_index=[2, 186], x=[46, 3], y=[1])
# 305
# Batch(batch=[55], edge_index=[2, 196], x=[55, 3], y=[1])
# 306
# Batch(batch=[50], edge_index=[2, 184], x=[50, 3], y=[1])
# 307
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 308
# Batch(batch=[48], edge_index=[2, 188], x=[48, 3], y=[1])
# 309
# Batch(batch=[51], edge_index=[2, 198], x=[51, 3], y=[1])
# 310
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 311
# Batch(batch=[51], edge_index=[2, 178], x=[51, 3], y=[1])
# 312
# Batch(batch=[52], edge_index=[2, 192], x=[52, 3], y=[1])
# 313
# Batch(batch=[22], edge_index=[2, 76], x=[22, 3], y=[1])
# 314
# Batch(batch=[44], edge_index=[2, 184], x=[44, 3], y=[1])
# 315
# Batch(batch=[44], edge_index=[2, 180], x=[44, 3], y=[1])
# 316
# Batch(batch=[31], edge_index=[2, 128], x=[31, 3], y=[1])
# 317
# Batch(batch=[27], edge_index=[2, 106], x=[27, 3], y=[1])
# 318
# Batch(batch=[25], edge_index=[2, 90], x=[25, 3], y=[1])
# 319
# Batch(batch=[38], edge_index=[2, 106], x=[38, 3], y=[1])
# 320
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 321
# Batch(batch=[29], edge_index=[2, 114], x=[29, 3], y=[1])
# 322
# Batch(batch=[20], edge_index=[2, 74], x=[20, 3], y=[1])
# 323
# Batch(batch=[21], edge_index=[2, 74], x=[21, 3], y=[1])
# 324
# Batch(batch=[50], edge_index=[2, 196], x=[50, 3], y=[1])
# 325
# Batch(batch=[46], edge_index=[2, 192], x=[46, 3], y=[1])
# 326
# Batch(batch=[49], edge_index=[2, 188], x=[49, 3], y=[1])
# 327
# Batch(batch=[27], edge_index=[2, 98], x=[27, 3], y=[1])
# 328
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 329
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 330
# Batch(batch=[23], edge_index=[2, 96], x=[23, 3], y=[1])
# 331
# Batch(batch=[24], edge_index=[2, 102], x=[24, 3], y=[1])
# 332
# Batch(batch=[33], edge_index=[2, 122], x=[33, 3], y=[1])
# 333
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 334
# Batch(batch=[25], edge_index=[2, 102], x=[25, 3], y=[1])
# 335
# Batch(batch=[28], edge_index=[2, 104], x=[28, 3], y=[1])
# 336
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 337
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 338
# Batch(batch=[26], edge_index=[2, 98], x=[26, 3], y=[1])
# 339
# Batch(batch=[28], edge_index=[2, 98], x=[28, 3], y=[1])
# 340
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 341
# Batch(batch=[26], edge_index=[2, 98], x=[26, 3], y=[1])
# 342
# Batch(batch=[24], edge_index=[2, 90], x=[24, 3], y=[1])
# 343
# Batch(batch=[23], edge_index=[2, 78], x=[23, 3], y=[1])
# 344
# Batch(batch=[27], edge_index=[2, 116], x=[27, 3], y=[1])
# 345
# Batch(batch=[39], edge_index=[2, 134], x=[39, 3], y=[1])
# 346
# Batch(batch=[42], edge_index=[2, 174], x=[42, 3], y=[1])
# 347
# Batch(batch=[42], edge_index=[2, 170], x=[42, 3], y=[1])
# 348
# Batch(batch=[64], edge_index=[2, 236], x=[64, 3], y=[1])
# 349
# Batch(batch=[38], edge_index=[2, 142], x=[38, 3], y=[1])
# 350
# Batch(batch=[22], edge_index=[2, 84], x=[22, 3], y=[1])
# 351
# Batch(batch=[9], edge_index=[2, 16], x=[9, 3], y=[1])
# 352
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 353
# Batch(batch=[19], edge_index=[2, 84], x=[19, 3], y=[1])
# 354
# Batch(batch=[66], edge_index=[2, 224], x=[66, 3], y=[1])
# 355
# Batch(batch=[27], edge_index=[2, 112], x=[27, 3], y=[1])
# 356
# Batch(batch=[34], edge_index=[2, 124], x=[34, 3], y=[1])
# 357
# Batch(batch=[28], edge_index=[2, 112], x=[28, 3], y=[1])
# 358
# Batch(batch=[26], edge_index=[2, 92], x=[26, 3], y=[1])
# 359
# Batch(batch=[26], edge_index=[2, 108], x=[26, 3], y=[1])
# 360
# Batch(batch=[28], edge_index=[2, 118], x=[28, 3], y=[1])
# 361
# Batch(batch=[19], edge_index=[2, 82], x=[19, 3], y=[1])
# 362
# Batch(batch=[20], edge_index=[2, 92], x=[20, 3], y=[1])
# 363
# Batch(batch=[20], edge_index=[2, 98], x=[20, 3], y=[1])
# 364
# Batch(batch=[42], edge_index=[2, 150], x=[42, 3], y=[1])
# 365
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 366
# Batch(batch=[15], edge_index=[2, 50], x=[15, 3], y=[1])
# 367
# Batch(batch=[11], edge_index=[2, 38], x=[11, 3], y=[1])
# 368
# Batch(batch=[10], edge_index=[2, 34], x=[10, 3], y=[1])
# 369
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 370
# Batch(batch=[30], edge_index=[2, 104], x=[30, 3], y=[1])
# 371
# Batch(batch=[15], edge_index=[2, 52], x=[15, 3], y=[1])
# 372
# Batch(batch=[10], edge_index=[2, 40], x=[10, 3], y=[1])
# 373
# Batch(batch=[18], edge_index=[2, 68], x=[18, 3], y=[1])
# 374
# Batch(batch=[22], edge_index=[2, 80], x=[22, 3], y=[1])
# 375
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 376
# Batch(batch=[36], edge_index=[2, 140], x=[36, 3], y=[1])
# 377
# Batch(batch=[30], edge_index=[2, 102], x=[30, 3], y=[1])
# 378
# Batch(batch=[30], edge_index=[2, 104], x=[30, 3], y=[1])
# 379
# Batch(batch=[36], edge_index=[2, 122], x=[36, 3], y=[1])
# 380
# Batch(batch=[33], edge_index=[2, 116], x=[33, 3], y=[1])
# 381
# Batch(batch=[48], edge_index=[2, 188], x=[48, 3], y=[1])
# 382
# Batch(batch=[27], edge_index=[2, 104], x=[27, 3], y=[1])
# 383
# Batch(batch=[27], edge_index=[2, 108], x=[27, 3], y=[1])
# 384
# Batch(batch=[16], edge_index=[2, 58], x=[16, 3], y=[1])
# 385
# Batch(batch=[7], edge_index=[2, 28], x=[7, 3], y=[1])
# 386
# Batch(batch=[16], edge_index=[2, 56], x=[16, 3], y=[1])
# 387
# Batch(batch=[35], edge_index=[2, 128], x=[35, 3], y=[1])
# 388
# Batch(batch=[28], edge_index=[2, 110], x=[28, 3], y=[1])
# 389
# Batch(batch=[40], edge_index=[2, 162], x=[40, 3], y=[1])
# 390
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 391
# Batch(batch=[48], edge_index=[2, 178], x=[48, 3], y=[1])
# 392
# Batch(batch=[15], edge_index=[2, 56], x=[15, 3], y=[1])
# 393
# Batch(batch=[11], edge_index=[2, 44], x=[11, 3], y=[1])
# 394
# Batch(batch=[50], edge_index=[2, 196], x=[50, 3], y=[1])
# 395
# Batch(batch=[18], edge_index=[2, 70], x=[18, 3], y=[1])
# 396
# Batch(batch=[19], edge_index=[2, 78], x=[19, 3], y=[1])
# 397
# Batch(batch=[14], edge_index=[2, 46], x=[14, 3], y=[1])
# 398
# Batch(batch=[21], edge_index=[2, 86], x=[21, 3], y=[1])
# 399
# Batch(batch=[37], edge_index=[2, 116], x=[37, 3], y=[1])
# 400
# Batch(batch=[48], edge_index=[2, 194], x=[48, 3], y=[1])
# 401
# Batch(batch=[25], edge_index=[2, 102], x=[25, 3], y=[1])
# 402
# Batch(batch=[28], edge_index=[2, 114], x=[28, 3], y=[1])
# 403
# Batch(batch=[33], edge_index=[2, 112], x=[33, 3], y=[1])
# 404
# Batch(batch=[29], edge_index=[2, 100], x=[29, 3], y=[1])
# 405
# Batch(batch=[33], edge_index=[2, 128], x=[33, 3], y=[1])
# 406
# Batch(batch=[30], edge_index=[2, 120], x=[30, 3], y=[1])
# 407
# Batch(batch=[33], edge_index=[2, 132], x=[33, 3], y=[1])
# 408
# Batch(batch=[32], edge_index=[2, 120], x=[32, 3], y=[1])
# 409
# Batch(batch=[28], edge_index=[2, 124], x=[28, 3], y=[1])
# 410
# Batch(batch=[37], edge_index=[2, 138], x=[37, 3], y=[1])
# 411
# Batch(batch=[36], edge_index=[2, 136], x=[36, 3], y=[1])
# 412
# Batch(batch=[38], edge_index=[2, 158], x=[38, 3], y=[1])
# 413
# Batch(batch=[37], edge_index=[2, 146], x=[37, 3], y=[1])
# 414
# Batch(batch=[34], edge_index=[2, 152], x=[34, 3], y=[1])
# 415
# Batch(batch=[24], edge_index=[2, 92], x=[24, 3], y=[1])
# 416
# Batch(batch=[25], edge_index=[2, 94], x=[25, 3], y=[1])
# 417
# Batch(batch=[41], edge_index=[2, 152], x=[41, 3], y=[1])
# 418
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 419
# Batch(batch=[26], edge_index=[2, 94], x=[26, 3], y=[1])
# 420
# Batch(batch=[25], edge_index=[2, 98], x=[25, 3], y=[1])
# 421
# Batch(batch=[27], edge_index=[2, 114], x=[27, 3], y=[1])
# 422
# Batch(batch=[20], edge_index=[2, 76], x=[20, 3], y=[1])
# 423
# Batch(batch=[40], edge_index=[2, 132], x=[40, 3], y=[1])
# 424
# Batch(batch=[21], edge_index=[2, 78], x=[21, 3], y=[1])
# 425
# Batch(batch=[19], edge_index=[2, 66], x=[19, 3], y=[1])
# 426
# Batch(batch=[36], edge_index=[2, 128], x=[36, 3], y=[1])
# 427
# Batch(batch=[32], edge_index=[2, 114], x=[32, 3], y=[1])
# 428
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 429
# Batch(batch=[37], edge_index=[2, 114], x=[37, 3], y=[1])
# 430
# Batch(batch=[18], edge_index=[2, 74], x=[18, 3], y=[1])
# 431
# Batch(batch=[19], edge_index=[2, 78], x=[19, 3], y=[1])
# 432
# Batch(batch=[22], edge_index=[2, 92], x=[22, 3], y=[1])
# 433
# Batch(batch=[43], edge_index=[2, 140], x=[43, 3], y=[1])
# 434
# Batch(batch=[24], edge_index=[2, 92], x=[24, 3], y=[1])
# 435
# Batch(batch=[15], edge_index=[2, 66], x=[15, 3], y=[1])
# 436
# Batch(batch=[14], edge_index=[2, 46], x=[14, 3], y=[1])
# 437
# Batch(batch=[48], edge_index=[2, 198], x=[48, 3], y=[1])
# 438
# Batch(batch=[46], edge_index=[2, 198], x=[46, 3], y=[1])
# 439
# Batch(batch=[26], edge_index=[2, 100], x=[26, 3], y=[1])
# 440
# Batch(batch=[25], edge_index=[2, 112], x=[25, 3], y=[1])
# 441
# Batch(batch=[44], edge_index=[2, 190], x=[44, 3], y=[1])
# 442
# Batch(batch=[39], edge_index=[2, 152], x=[39, 3], y=[1])
# 443
# Batch(batch=[39], edge_index=[2, 158], x=[39, 3], y=[1])
# 444
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 445
# Batch(batch=[26], edge_index=[2, 116], x=[26, 3], y=[1])
# 446
# Batch(batch=[25], edge_index=[2, 112], x=[25, 3], y=[1])
# 447
# Batch(batch=[39], edge_index=[2, 146], x=[39, 3], y=[1])
# 448
# Batch(batch=[26], edge_index=[2, 114], x=[26, 3], y=[1])
# 449
# Batch(batch=[26], edge_index=[2, 116], x=[26, 3], y=[1])
# 450
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 451
# Batch(batch=[34], edge_index=[2, 108], x=[34, 3], y=[1])
# 452
# Batch(batch=[20], edge_index=[2, 90], x=[20, 3], y=[1])
# 453
# Batch(batch=[20], edge_index=[2, 78], x=[20, 3], y=[1])
# 454
# Batch(batch=[19], edge_index=[2, 74], x=[19, 3], y=[1])
# 455
# Batch(batch=[18], edge_index=[2, 68], x=[18, 3], y=[1])
# 456
# Batch(batch=[33], edge_index=[2, 84], x=[33, 3], y=[1])
# 457
# Batch(batch=[15], edge_index=[2, 58], x=[15, 3], y=[1])
# 458
# Batch(batch=[34], edge_index=[2, 154], x=[34, 3], y=[1])
# 459
# Batch(batch=[28], edge_index=[2, 130], x=[28, 3], y=[1])
# 460
# Batch(batch=[34], edge_index=[2, 158], x=[34, 3], y=[1])
# 461
# Batch(batch=[15], edge_index=[2, 60], x=[15, 3], y=[1])
# 462
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 463
# Batch(batch=[20], edge_index=[2, 90], x=[20, 3], y=[1])
# 464
# Batch(batch=[52], edge_index=[2, 198], x=[52, 3], y=[1])
# 465
# Batch(batch=[20], edge_index=[2, 76], x=[20, 3], y=[1])
# 466
# Batch(batch=[20], edge_index=[2, 82], x=[20, 3], y=[1])
# 467
# Batch(batch=[20], edge_index=[2, 74], x=[20, 3], y=[1])
# 468
# Batch(batch=[17], edge_index=[2, 60], x=[17, 3], y=[1])
# 469
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 470
# Batch(batch=[24], edge_index=[2, 74], x=[24, 3], y=[1])
# 471
# Batch(batch=[46], edge_index=[2, 186], x=[46, 3], y=[1])
# 472
# Batch(batch=[13], edge_index=[2, 52], x=[13, 3], y=[1])
# 473
# Batch(batch=[24], edge_index=[2, 90], x=[24, 3], y=[1])
# 474
# Batch(batch=[12], edge_index=[2, 46], x=[12, 3], y=[1])
# 475
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 476
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 477
# Batch(batch=[20], edge_index=[2, 76], x=[20, 3], y=[1])
# 478
# Batch(batch=[28], edge_index=[2, 98], x=[28, 3], y=[1])
# 479
# Batch(batch=[24], edge_index=[2, 76], x=[24, 3], y=[1])
# 480
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 481
# Batch(batch=[26], edge_index=[2, 88], x=[26, 3], y=[1])
# 482
# Batch(batch=[22], edge_index=[2, 92], x=[22, 3], y=[1])
# 483
# Batch(batch=[60], edge_index=[2, 160], x=[60, 3], y=[1])
# 484
# Batch(batch=[39], edge_index=[2, 144], x=[39, 3], y=[1])
# 485
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 486
# Batch(batch=[15], edge_index=[2, 54], x=[15, 3], y=[1])
# 487
# Batch(batch=[25], edge_index=[2, 84], x=[25, 3], y=[1])
# 488
# Batch(batch=[35], edge_index=[2, 122], x=[35, 3], y=[1])
# 489
# Batch(batch=[35], edge_index=[2, 134], x=[35, 3], y=[1])
# 490
# Batch(batch=[38], edge_index=[2, 140], x=[38, 3], y=[1])
# 491
# Batch(batch=[38], edge_index=[2, 158], x=[38, 3], y=[1])
# 492
# Batch(batch=[33], edge_index=[2, 136], x=[33, 3], y=[1])
# 493
# Batch(batch=[32], edge_index=[2, 122], x=[32, 3], y=[1])
# 494
# Batch(batch=[42], edge_index=[2, 154], x=[42, 3], y=[1])
# 495
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 496
# Batch(batch=[41], edge_index=[2, 156], x=[41, 3], y=[1])
# 497
# Batch(batch=[40], edge_index=[2, 144], x=[40, 3], y=[1])
# 498
# Batch(batch=[38], edge_index=[2, 152], x=[38, 3], y=[1])
# 499
# Batch(batch=[43], edge_index=[2, 196], x=[43, 3], y=[1])
# 500
# Batch(batch=[67], edge_index=[2, 160], x=[67, 3], y=[1])
# 501
# Batch(batch=[36], edge_index=[2, 146], x=[36, 3], y=[1])
# 502
# Batch(batch=[46], edge_index=[2, 166], x=[46, 3], y=[1])
# 503
# Batch(batch=[66], edge_index=[2, 240], x=[66, 3], y=[1])
# 504
# Batch(batch=[21], edge_index=[2, 86], x=[21, 3], y=[1])
# 505
# Batch(batch=[22], edge_index=[2, 98], x=[22, 3], y=[1])
# 506
# Batch(batch=[21], edge_index=[2, 92], x=[21, 3], y=[1])
# 507
# Batch(batch=[21], edge_index=[2, 96], x=[21, 3], y=[1])
# 508
# Batch(batch=[41], edge_index=[2, 176], x=[41, 3], y=[1])
# 509
# Batch(batch=[29], edge_index=[2, 130], x=[29, 3], y=[1])
# 510
# Batch(batch=[30], edge_index=[2, 134], x=[30, 3], y=[1])
# 511
# Batch(batch=[30], edge_index=[2, 136], x=[30, 3], y=[1])
# 512
# Batch(batch=[41], edge_index=[2, 184], x=[41, 3], y=[1])
# 513
# Batch(batch=[37], edge_index=[2, 176], x=[37, 3], y=[1])
# 514
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 515
# Batch(batch=[37], edge_index=[2, 142], x=[37, 3], y=[1])
# 516
# Batch(batch=[50], edge_index=[2, 178], x=[50, 3], y=[1])
# 517
# Batch(batch=[27], edge_index=[2, 112], x=[27, 3], y=[1])
# 518
# Batch(batch=[34], edge_index=[2, 154], x=[34, 3], y=[1])
# 519
# Batch(batch=[32], edge_index=[2, 148], x=[32, 3], y=[1])
# 520
# Batch(batch=[35], edge_index=[2, 158], x=[35, 3], y=[1])
# 521
# Batch(batch=[37], edge_index=[2, 164], x=[37, 3], y=[1])
# 522
# Batch(batch=[48], edge_index=[2, 222], x=[48, 3], y=[1])
# 523
# Batch(batch=[41], edge_index=[2, 148], x=[41, 3], y=[1])
# 524
# Batch(batch=[29], edge_index=[2, 132], x=[29, 3], y=[1])
# 525
# Batch(batch=[58], edge_index=[2, 220], x=[58, 3], y=[1])
# 526
# Batch(batch=[57], edge_index=[2, 214], x=[57, 3], y=[1])
# 527
# Batch(batch=[21], edge_index=[2, 106], x=[21, 3], y=[1])
# 528
# Batch(batch=[18], edge_index=[2, 86], x=[18, 3], y=[1])
# 529
# Batch(batch=[42], edge_index=[2, 166], x=[42, 3], y=[1])
# 530
# Batch(batch=[40], edge_index=[2, 164], x=[40, 3], y=[1])
# 531
# Batch(batch=[74], edge_index=[2, 240], x=[74, 3], y=[1])
# 532
# Batch(batch=[44], edge_index=[2, 170], x=[44, 3], y=[1])
# 533
# Batch(batch=[44], edge_index=[2, 198], x=[44, 3], y=[1])
# 534
# Batch(batch=[40], edge_index=[2, 168], x=[40, 3], y=[1])
# 535
# Batch(batch=[44], edge_index=[2, 184], x=[44, 3], y=[1])
# 536
# Batch(batch=[42], edge_index=[2, 178], x=[42, 3], y=[1])
# 537
# Batch(batch=[43], edge_index=[2, 176], x=[43, 3], y=[1])
# 538
# Batch(batch=[41], edge_index=[2, 184], x=[41, 3], y=[1])
# 539
# Batch(batch=[49], edge_index=[2, 184], x=[49, 3], y=[1])
# 540
# Batch(batch=[84], edge_index=[2, 152], x=[84, 3], y=[1])
# 541
# Batch(batch=[44], edge_index=[2, 202], x=[44, 3], y=[1])
# 542
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 543
# Batch(batch=[41], edge_index=[2, 158], x=[41, 3], y=[1])
# 544
# Batch(batch=[41], edge_index=[2, 154], x=[41, 3], y=[1])
# 545
# Batch(batch=[44], edge_index=[2, 164], x=[44, 3], y=[1])
# 546
# Batch(batch=[39], edge_index=[2, 164], x=[39, 3], y=[1])
# 547
# Batch(batch=[25], edge_index=[2, 90], x=[25, 3], y=[1])
# 548
# Batch(batch=[25], edge_index=[2, 94], x=[25, 3], y=[1])
# 549
# Batch(batch=[26], edge_index=[2, 90], x=[26, 3], y=[1])
# 550
# Batch(batch=[52], edge_index=[2, 196], x=[52, 3], y=[1])
# 551
# Batch(batch=[41], edge_index=[2, 172], x=[41, 3], y=[1])
# 552
# Batch(batch=[45], edge_index=[2, 164], x=[45, 3], y=[1])
# 553
# Batch(batch=[31], edge_index=[2, 128], x=[31, 3], y=[1])
# 554
# Batch(batch=[26], edge_index=[2, 92], x=[26, 3], y=[1])
# 555
# Batch(batch=[26], edge_index=[2, 96], x=[26, 3], y=[1])
# 556
# Batch(batch=[52], edge_index=[2, 198], x=[52, 3], y=[1])
# 557
# Batch(batch=[50], edge_index=[2, 186], x=[50, 3], y=[1])
# 558
# Batch(batch=[38], edge_index=[2, 134], x=[38, 3], y=[1])
# 559
# Batch(batch=[37], edge_index=[2, 134], x=[37, 3], y=[1])
# 560
# Batch(batch=[27], edge_index=[2, 104], x=[27, 3], y=[1])
# 561
# Batch(batch=[29], edge_index=[2, 110], x=[29, 3], y=[1])
# 562
# Batch(batch=[48], edge_index=[2, 160], x=[48, 3], y=[1])
# 563
# Batch(batch=[40], edge_index=[2, 148], x=[40, 3], y=[1])
# 564
# Batch(batch=[19], edge_index=[2, 68], x=[19, 3], y=[1])
# 565
# Batch(batch=[14], edge_index=[2, 66], x=[14, 3], y=[1])
# 566
# Batch(batch=[13], edge_index=[2, 62], x=[13, 3], y=[1])
# 567
# Batch(batch=[13], edge_index=[2, 68], x=[13, 3], y=[1])
# 568
# Batch(batch=[44], edge_index=[2, 170], x=[44, 3], y=[1])
# 569
# Batch(batch=[45], edge_index=[2, 156], x=[45, 3], y=[1])
# 570
# Batch(batch=[46], edge_index=[2, 164], x=[46, 3], y=[1])
# 571
# Batch(batch=[47], edge_index=[2, 158], x=[47, 3], y=[1])
# 572
# Batch(batch=[47], edge_index=[2, 164], x=[47, 3], y=[1])
# 573
# Batch(batch=[42], edge_index=[2, 180], x=[42, 3], y=[1])
# 574
# Batch(batch=[51], edge_index=[2, 220], x=[51, 3], y=[1])
# 575
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 576
# Batch(batch=[27], edge_index=[2, 104], x=[27, 3], y=[1])
# 577
# Batch(batch=[60], edge_index=[2, 206], x=[60, 3], y=[1])
# 578
# Batch(batch=[28], edge_index=[2, 106], x=[28, 3], y=[1])
# 579
# Batch(batch=[38], edge_index=[2, 150], x=[38, 3], y=[1])
# 580
# Batch(batch=[23], edge_index=[2, 106], x=[23, 3], y=[1])
# 581
# Batch(batch=[18], edge_index=[2, 74], x=[18, 3], y=[1])
# 582
# Batch(batch=[45], edge_index=[2, 194], x=[45, 3], y=[1])
# 583
# Batch(batch=[21], edge_index=[2, 90], x=[21, 3], y=[1])
# 584
# Batch(batch=[35], edge_index=[2, 142], x=[35, 3], y=[1])
# 585
# Batch(batch=[24], edge_index=[2, 102], x=[24, 3], y=[1])
# 586
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 587
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 588
# Batch(batch=[31], edge_index=[2, 124], x=[31, 3], y=[1])
# 589
# Batch(batch=[27], edge_index=[2, 112], x=[27, 3], y=[1])
# 590
# Batch(batch=[51], edge_index=[2, 196], x=[51, 3], y=[1])
# 591
# Batch(batch=[36], edge_index=[2, 156], x=[36, 3], y=[1])
# 592
# Batch(batch=[46], edge_index=[2, 144], x=[46, 3], y=[1])
# 593
# Batch(batch=[52], edge_index=[2, 228], x=[52, 3], y=[1])
# 594
# Batch(batch=[44], edge_index=[2, 180], x=[44, 3], y=[1])
# 595
# Batch(batch=[45], edge_index=[2, 182], x=[45, 3], y=[1])
# 596
# Batch(batch=[52], edge_index=[2, 232], x=[52, 3], y=[1])
# 597
# Batch(batch=[55], edge_index=[2, 200], x=[55, 3], y=[1])
# 598
# Batch(batch=[51], edge_index=[2, 190], x=[51, 3], y=[1])
# 599
# Batch(batch=[48], edge_index=[2, 156], x=[48, 3], y=[1])
# 600

# %%
#ENZYMES FROM TUDataset
print("\nTUDataset EnZYMES")
dname='TUDataset'
name='ENZYMES'
dataset = loadDataset(dname,name)
processDatasetsTF(dname+'_'+name, dataset)
# Out:
# TUDataset EnZYMES
# Downloading https://ls11-www.cs.uni-dortmund.de/people/morris/graphkerneldatasets/ENZYMES.zip
# Extracting data/TUDataset/ENZYMES.zip
# Batch(batch=[37], edge_index=[2, 168], x=[37, 3], y=[1])
# 1
# Batch(batch=[23], edge_index=[2, 102], x=[23, 3], y=[1])
# 2
# Batch(batch=[25], edge_index=[2, 92], x=[25, 3], y=[1])
# 3
# Batch(batch=[24], edge_index=[2, 90], x=[24, 3], y=[1])
# 4
# Batch(batch=[23], edge_index=[2, 90], x=[23, 3], y=[1])
# 5
# Batch(batch=[24], edge_index=[2, 92], x=[24, 3], y=[1])
# 6
# Batch(batch=[26], edge_index=[2, 118], x=[26, 3], y=[1])
# 7
# Batch(batch=[88], edge_index=[2, 266], x=[88, 3], y=[1])
# 8
# Batch(batch=[23], edge_index=[2, 78], x=[23, 3], y=[1])
# 9
# Batch(batch=[32], edge_index=[2, 106], x=[32, 3], y=[1])
# 10
# Batch(batch=[4], edge_index=[2, 12], x=[4, 3], y=[1])
# 11
# Batch(batch=[14], edge_index=[2, 56], x=[14, 3], y=[1])
# 12
# Batch(batch=[42], edge_index=[2, 150], x=[42, 3], y=[1])
# 13
# Batch(batch=[41], edge_index=[2, 146], x=[41, 3], y=[1])
# 14
# Batch(batch=[36], edge_index=[2, 128], x=[36, 3], y=[1])
# 15
# Batch(batch=[55], edge_index=[2, 194], x=[55, 3], y=[1])
# 16
# Batch(batch=[40], edge_index=[2, 190], x=[40, 3], y=[1])
# 17
# Batch(batch=[38], edge_index=[2, 182], x=[38, 3], y=[1])
# 18
# Batch(batch=[2], edge_index=[2, 2], x=[2, 3], y=[1])
# 19
# Batch(batch=[35], edge_index=[2, 140], x=[35, 3], y=[1])
# 20
# Batch(batch=[42], edge_index=[2, 180], x=[42, 3], y=[1])
# 21
# Batch(batch=[41], edge_index=[2, 180], x=[41, 3], y=[1])
# 22
# Batch(batch=[39], edge_index=[2, 162], x=[39, 3], y=[1])
# 23
# Batch(batch=[42], edge_index=[2, 184], x=[42, 3], y=[1])
# 24
# Batch(batch=[41], edge_index=[2, 176], x=[41, 3], y=[1])
# 25
# Batch(batch=[40], edge_index=[2, 170], x=[40, 3], y=[1])
# 26
# Batch(batch=[37], edge_index=[2, 166], x=[37, 3], y=[1])
# 27
# Batch(batch=[23], edge_index=[2, 98], x=[23, 3], y=[1])
# 28
# Batch(batch=[22], edge_index=[2, 94], x=[22, 3], y=[1])
# 29
# Batch(batch=[34], edge_index=[2, 132], x=[34, 3], y=[1])
# 30
# Batch(batch=[38], edge_index=[2, 162], x=[38, 3], y=[1])
# 31
# Batch(batch=[38], edge_index=[2, 158], x=[38, 3], y=[1])
# 32
# Batch(batch=[39], edge_index=[2, 164], x=[39, 3], y=[1])
# 33
# Batch(batch=[8], edge_index=[2, 28], x=[8, 3], y=[1])
# 34
# Batch(batch=[23], edge_index=[2, 88], x=[23, 3], y=[1])
# 35
# Batch(batch=[42], edge_index=[2, 162], x=[42, 3], y=[1])
# 36
# Batch(batch=[42], edge_index=[2, 160], x=[42, 3], y=[1])
# 37
# Batch(batch=[100], edge_index=[2, 32], x=[100, 3], y=[1])
# 38
# Batch(batch=[24], edge_index=[2, 86], x=[24, 3], y=[1])
# 39
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 40
# Batch(batch=[47], edge_index=[2, 190], x=[47, 3], y=[1])
# 41
# Batch(batch=[45], edge_index=[2, 194], x=[45, 3], y=[1])
# 42
# Batch(batch=[45], edge_index=[2, 190], x=[45, 3], y=[1])
# 43
# Batch(batch=[45], edge_index=[2, 190], x=[45, 3], y=[1])
# 44
# Batch(batch=[46], edge_index=[2, 194], x=[46, 3], y=[1])
# 45
# Batch(batch=[44], edge_index=[2, 190], x=[44, 3], y=[1])
# 46
# Batch(batch=[30], edge_index=[2, 102], x=[30, 3], y=[1])
# 47
# Batch(batch=[32], edge_index=[2, 114], x=[32, 3], y=[1])
# 48
# Batch(batch=[33], edge_index=[2, 128], x=[33, 3], y=[1])
# 49
# Batch(batch=[9], edge_index=[2, 30], x=[9, 3], y=[1])
# 50
# Batch(batch=[27], edge_index=[2, 94], x=[27, 3], y=[1])
# 51
# Batch(batch=[39], edge_index=[2, 170], x=[39, 3], y=[1])
# 52
# Batch(batch=[16], edge_index=[2, 62], x=[16, 3], y=[1])
# 53
# Batch(batch=[18], edge_index=[2, 62], x=[18, 3], y=[1])
# 54
# Batch(batch=[7], edge_index=[2, 24], x=[7, 3], y=[1])
# 55
# Batch(batch=[18], edge_index=[2, 74], x=[18, 3], y=[1])
# 56
# Batch(batch=[10], edge_index=[2, 36], x=[10, 3], y=[1])
# 57
# Batch(batch=[21], edge_index=[2, 100], x=[21, 3], y=[1])
# 58
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 59
# Batch(batch=[10], edge_index=[2, 36], x=[10, 3], y=[1])
# 60
# Batch(batch=[9], edge_index=[2, 32], x=[9, 3], y=[1])
# 61
# Batch(batch=[39], edge_index=[2, 140], x=[39, 3], y=[1])
# 62
# Batch(batch=[33], edge_index=[2, 110], x=[33, 3], y=[1])
# 63
# Batch(batch=[29], edge_index=[2, 98], x=[29, 3], y=[1])
# 64
# Batch(batch=[24], edge_index=[2, 78], x=[24, 3], y=[1])
# 65
# Batch(batch=[25], edge_index=[2, 86], x=[25, 3], y=[1])
# 66
# Batch(batch=[30], edge_index=[2, 108], x=[30, 3], y=[1])
# 67
# Batch(batch=[38], edge_index=[2, 150], x=[38, 3], y=[1])
# 68
# Batch(batch=[28], edge_index=[2, 110], x=[28, 3], y=[1])
# 69
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 70
# Batch(batch=[38], edge_index=[2, 176], x=[38, 3], y=[1])
# 71
# Batch(batch=[40], edge_index=[2, 140], x=[40, 3], y=[1])
# 72
# Batch(batch=[40], edge_index=[2, 174], x=[40, 3], y=[1])
# 73
# Batch(batch=[42], edge_index=[2, 188], x=[42, 3], y=[1])
# 74
# Batch(batch=[20], edge_index=[2, 72], x=[20, 3], y=[1])
# 75
# Batch(batch=[19], edge_index=[2, 70], x=[19, 3], y=[1])
# 76
# Batch(batch=[16], edge_index=[2, 56], x=[16, 3], y=[1])
# 77
# Batch(batch=[17], edge_index=[2, 58], x=[17, 3], y=[1])
# 78
# Batch(batch=[20], edge_index=[2, 80], x=[20, 3], y=[1])
# 79
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 80
# Batch(batch=[33], edge_index=[2, 138], x=[33, 3], y=[1])
# 81
# Batch(batch=[23], edge_index=[2, 88], x=[23, 3], y=[1])
# 82
# Batch(batch=[23], edge_index=[2, 84], x=[23, 3], y=[1])
# 83
# Batch(batch=[35], edge_index=[2, 148], x=[35, 3], y=[1])
# 84
# Batch(batch=[33], edge_index=[2, 136], x=[33, 3], y=[1])
# 85
# Batch(batch=[39], edge_index=[2, 138], x=[39, 3], y=[1])
# 86
# Batch(batch=[40], edge_index=[2, 146], x=[40, 3], y=[1])
# 87
# Batch(batch=[38], edge_index=[2, 182], x=[38, 3], y=[1])
# 88
# Batch(batch=[40], edge_index=[2, 188], x=[40, 3], y=[1])
# 89
# Batch(batch=[38], edge_index=[2, 132], x=[38, 3], y=[1])
# 90
# Batch(batch=[37], edge_index=[2, 158], x=[37, 3], y=[1])
# 91
# Batch(batch=[36], edge_index=[2, 154], x=[36, 3], y=[1])
# 92
# Batch(batch=[34], edge_index=[2, 112], x=[34, 3], y=[1])
# 93
# Batch(batch=[34], edge_index=[2, 134], x=[34, 3], y=[1])
# 94
# Batch(batch=[32], edge_index=[2, 128], x=[32, 3], y=[1])
# 95
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 96
# Batch(batch=[32], edge_index=[2, 130], x=[32, 3], y=[1])
# 97
# Batch(batch=[34], edge_index=[2, 134], x=[34, 3], y=[1])
# 98
# Batch(batch=[30], edge_index=[2, 116], x=[30, 3], y=[1])
# 99
# Batch(batch=[5], edge_index=[2, 18], x=[5, 3], y=[1])
# 100
# Batch(batch=[45], edge_index=[2, 176], x=[45, 3], y=[1])
# 101
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 102
# Batch(batch=[59], edge_index=[2, 230], x=[59, 3], y=[1])
# 103
# Batch(batch=[32], edge_index=[2, 128], x=[32, 3], y=[1])
# 104
# Batch(batch=[33], edge_index=[2, 138], x=[33, 3], y=[1])
# 105
# Batch(batch=[17], edge_index=[2, 60], x=[17, 3], y=[1])
# 106
# Batch(batch=[39], edge_index=[2, 166], x=[39, 3], y=[1])
# 107
# Batch(batch=[38], edge_index=[2, 164], x=[38, 3], y=[1])
# 108
# Batch(batch=[35], edge_index=[2, 140], x=[35, 3], y=[1])
# 109
# Batch(batch=[16], edge_index=[2, 58], x=[16, 3], y=[1])
# 110
# Batch(batch=[26], edge_index=[2, 98], x=[26, 3], y=[1])
# 111
# Batch(batch=[51], edge_index=[2, 190], x=[51, 3], y=[1])
# 112
# Batch(batch=[52], edge_index=[2, 196], x=[52, 3], y=[1])
# 113
# Batch(batch=[25], edge_index=[2, 94], x=[25, 3], y=[1])
# 114
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 115
# Batch(batch=[42], edge_index=[2, 148], x=[42, 3], y=[1])
# 116
# Batch(batch=[46], edge_index=[2, 180], x=[46, 3], y=[1])
# 117
# Batch(batch=[96], edge_index=[2, 242], x=[96, 3], y=[1])
# 118
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 119
# Batch(batch=[22], edge_index=[2, 92], x=[22, 3], y=[1])
# 120
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 121
# Batch(batch=[14], edge_index=[2, 58], x=[14, 3], y=[1])
# 122
# Batch(batch=[90], edge_index=[2, 254], x=[90, 3], y=[1])
# 123
# Batch(batch=[14], edge_index=[2, 62], x=[14, 3], y=[1])
# 124
# Batch(batch=[14], edge_index=[2, 66], x=[14, 3], y=[1])
# 125
# Batch(batch=[32], edge_index=[2, 94], x=[32, 3], y=[1])
# 126
# Batch(batch=[11], edge_index=[2, 46], x=[11, 3], y=[1])
# 127
# Batch(batch=[26], edge_index=[2, 74], x=[26, 3], y=[1])
# 128
# Batch(batch=[11], edge_index=[2, 40], x=[11, 3], y=[1])
# 129
# Batch(batch=[14], edge_index=[2, 50], x=[14, 3], y=[1])
# 130
# Batch(batch=[18], edge_index=[2, 70], x=[18, 3], y=[1])
# 131
# Batch(batch=[16], edge_index=[2, 64], x=[16, 3], y=[1])
# 132
# Batch(batch=[17], edge_index=[2, 68], x=[17, 3], y=[1])
# 133
# Batch(batch=[32], edge_index=[2, 102], x=[32, 3], y=[1])
# 134
# Batch(batch=[13], edge_index=[2, 52], x=[13, 3], y=[1])
# 135
# Batch(batch=[3], edge_index=[2, 6], x=[3, 3], y=[1])
# 136
# Batch(batch=[22], edge_index=[2, 80], x=[22, 3], y=[1])
# 137
# Batch(batch=[16], edge_index=[2, 72], x=[16, 3], y=[1])
# 138
# Batch(batch=[38], edge_index=[2, 164], x=[38, 3], y=[1])
# 139
# Batch(batch=[13], edge_index=[2, 56], x=[13, 3], y=[1])
# 140
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 141
# Batch(batch=[14], edge_index=[2, 58], x=[14, 3], y=[1])
# 142
# Batch(batch=[39], edge_index=[2, 122], x=[39, 3], y=[1])
# 143
# Batch(batch=[19], edge_index=[2, 70], x=[19, 3], y=[1])
# 144
# Batch(batch=[20], edge_index=[2, 78], x=[20, 3], y=[1])
# 145
# Batch(batch=[39], edge_index=[2, 174], x=[39, 3], y=[1])
# 146
# Batch(batch=[40], edge_index=[2, 168], x=[40, 3], y=[1])
# 147
# Batch(batch=[39], edge_index=[2, 160], x=[39, 3], y=[1])
# 148
# Batch(batch=[39], edge_index=[2, 164], x=[39, 3], y=[1])
# 149
# Batch(batch=[29], edge_index=[2, 82], x=[29, 3], y=[1])
# 150
# Batch(batch=[22], edge_index=[2, 80], x=[22, 3], y=[1])
# 151
# Batch(batch=[11], edge_index=[2, 44], x=[11, 3], y=[1])
# 152
# Batch(batch=[8], edge_index=[2, 32], x=[8, 3], y=[1])
# 153
# Batch(batch=[13], edge_index=[2, 44], x=[13, 3], y=[1])
# 154
# Batch(batch=[18], edge_index=[2, 66], x=[18, 3], y=[1])
# 155
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 156
# Batch(batch=[8], edge_index=[2, 30], x=[8, 3], y=[1])
# 157
# Batch(batch=[40], edge_index=[2, 126], x=[40, 3], y=[1])
# 158
# Batch(batch=[12], edge_index=[2, 50], x=[12, 3], y=[1])
# 159
# Batch(batch=[22], edge_index=[2, 96], x=[22, 3], y=[1])
# 160
# Batch(batch=[22], edge_index=[2, 84], x=[22, 3], y=[1])
# 161
# Batch(batch=[18], edge_index=[2, 64], x=[18, 3], y=[1])
# 162
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 163
# Batch(batch=[17], edge_index=[2, 72], x=[17, 3], y=[1])
# 164
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 165
# Batch(batch=[22], edge_index=[2, 72], x=[22, 3], y=[1])
# 166
# Batch(batch=[43], edge_index=[2, 188], x=[43, 3], y=[1])
# 167
# Batch(batch=[42], edge_index=[2, 168], x=[42, 3], y=[1])
# 168
# Batch(batch=[44], edge_index=[2, 188], x=[44, 3], y=[1])
# 169
# Batch(batch=[24], edge_index=[2, 82], x=[24, 3], y=[1])
# 170
# Batch(batch=[48], edge_index=[2, 198], x=[48, 3], y=[1])
# 171
# Batch(batch=[25], edge_index=[2, 92], x=[25, 3], y=[1])
# 172
# Batch(batch=[46], edge_index=[2, 192], x=[46, 3], y=[1])
# 173
# Batch(batch=[48], edge_index=[2, 196], x=[48, 3], y=[1])
# 174
# Batch(batch=[25], edge_index=[2, 86], x=[25, 3], y=[1])
# 175
# Batch(batch=[48], edge_index=[2, 192], x=[48, 3], y=[1])
# 176
# Batch(batch=[44], edge_index=[2, 192], x=[44, 3], y=[1])
# 177
# Batch(batch=[42], edge_index=[2, 176], x=[42, 3], y=[1])
# 178
# Batch(batch=[40], edge_index=[2, 118], x=[40, 3], y=[1])
# 179
# Batch(batch=[38], edge_index=[2, 120], x=[38, 3], y=[1])
# 180
# Batch(batch=[40], edge_index=[2, 162], x=[40, 3], y=[1])
# 181
# Batch(batch=[41], edge_index=[2, 172], x=[41, 3], y=[1])
# 182
# Batch(batch=[42], edge_index=[2, 188], x=[42, 3], y=[1])
# 183
# Batch(batch=[40], edge_index=[2, 182], x=[40, 3], y=[1])
# 184
# Batch(batch=[44], edge_index=[2, 190], x=[44, 3], y=[1])
# 185
# Batch(batch=[24], edge_index=[2, 80], x=[24, 3], y=[1])
# 186
# Batch(batch=[44], edge_index=[2, 188], x=[44, 3], y=[1])
# 187
# Batch(batch=[20], edge_index=[2, 78], x=[20, 3], y=[1])
# 188
# Batch(batch=[42], edge_index=[2, 190], x=[42, 3], y=[1])
# 189
# Batch(batch=[27], edge_index=[2, 98], x=[27, 3], y=[1])
# 190
# Batch(batch=[48], edge_index=[2, 192], x=[48, 3], y=[1])
# 191
# Batch(batch=[31], edge_index=[2, 132], x=[31, 3], y=[1])
# 192
# Batch(batch=[30], edge_index=[2, 120], x=[30, 3], y=[1])
# 193
# Batch(batch=[46], edge_index=[2, 200], x=[46, 3], y=[1])
# 194
# Batch(batch=[47], edge_index=[2, 184], x=[47, 3], y=[1])
# 195
# Batch(batch=[50], edge_index=[2, 172], x=[50, 3], y=[1])
# 196
# Batch(batch=[40], edge_index=[2, 154], x=[40, 3], y=[1])
# 197
# Batch(batch=[55], edge_index=[2, 154], x=[55, 3], y=[1])
# 198
# Batch(batch=[62], edge_index=[2, 216], x=[62, 3], y=[1])
# 199
# Batch(batch=[34], edge_index=[2, 144], x=[34, 3], y=[1])
# 200
# Batch(batch=[29], edge_index=[2, 106], x=[29, 3], y=[1])
# 201
# Batch(batch=[25], edge_index=[2, 90], x=[25, 3], y=[1])
# 202
# Batch(batch=[56], edge_index=[2, 200], x=[56, 3], y=[1])
# 203
# Batch(batch=[57], edge_index=[2, 210], x=[57, 3], y=[1])
# 204
# Batch(batch=[27], edge_index=[2, 122], x=[27, 3], y=[1])
# 205
# Batch(batch=[22], edge_index=[2, 86], x=[22, 3], y=[1])
# 206
# Batch(batch=[24], edge_index=[2, 86], x=[24, 3], y=[1])
# 207
# Batch(batch=[23], edge_index=[2, 100], x=[23, 3], y=[1])
# 208
# Batch(batch=[57], edge_index=[2, 202], x=[57, 3], y=[1])
# 209
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 210
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 211
# Batch(batch=[23], edge_index=[2, 94], x=[23, 3], y=[1])
# 212
# Batch(batch=[25], edge_index=[2, 110], x=[25, 3], y=[1])
# 213
# Batch(batch=[23], edge_index=[2, 102], x=[23, 3], y=[1])
# 214
# Batch(batch=[48], edge_index=[2, 208], x=[48, 3], y=[1])
# 215
# Batch(batch=[27], edge_index=[2, 94], x=[27, 3], y=[1])
# 216
# Batch(batch=[15], edge_index=[2, 68], x=[15, 3], y=[1])
# 217
# Batch(batch=[44], edge_index=[2, 194], x=[44, 3], y=[1])
# 218
# Batch(batch=[29], edge_index=[2, 128], x=[29, 3], y=[1])
# 219
# Batch(batch=[21], edge_index=[2, 82], x=[21, 3], y=[1])
# 220
# Batch(batch=[34], edge_index=[2, 126], x=[34, 3], y=[1])
# 221
# Batch(batch=[30], edge_index=[2, 114], x=[30, 3], y=[1])
# 222
# Batch(batch=[40], edge_index=[2, 158], x=[40, 3], y=[1])
# 223
# Batch(batch=[54], edge_index=[2, 210], x=[54, 3], y=[1])
# 224
# Batch(batch=[18], edge_index=[2, 70], x=[18, 3], y=[1])
# 225
# Batch(batch=[36], edge_index=[2, 148], x=[36, 3], y=[1])
# 226
# Batch(batch=[37], edge_index=[2, 162], x=[37, 3], y=[1])
# 227
# Batch(batch=[34], edge_index=[2, 152], x=[34, 3], y=[1])
# 228
# Batch(batch=[23], edge_index=[2, 100], x=[23, 3], y=[1])
# 229
# Batch(batch=[32], edge_index=[2, 136], x=[32, 3], y=[1])
# 230
# Batch(batch=[33], edge_index=[2, 152], x=[33, 3], y=[1])
# 231
# Batch(batch=[29], edge_index=[2, 130], x=[29, 3], y=[1])
# 232
# Batch(batch=[39], edge_index=[2, 142], x=[39, 3], y=[1])
# 233
# Batch(batch=[34], edge_index=[2, 140], x=[34, 3], y=[1])
# 234
# Batch(batch=[36], edge_index=[2, 142], x=[36, 3], y=[1])
# 235
# Batch(batch=[21], edge_index=[2, 70], x=[21, 3], y=[1])
# 236
# Batch(batch=[6], edge_index=[2, 22], x=[6, 3], y=[1])
# 237
# Batch(batch=[22], edge_index=[2, 100], x=[22, 3], y=[1])
# 238
# Batch(batch=[18], edge_index=[2, 80], x=[18, 3], y=[1])
# 239
# Batch(batch=[18], edge_index=[2, 82], x=[18, 3], y=[1])
# 240
# Batch(batch=[34], edge_index=[2, 128], x=[34, 3], y=[1])
# 241
# Batch(batch=[32], edge_index=[2, 122], x=[32, 3], y=[1])
# 242
# Batch(batch=[33], edge_index=[2, 124], x=[33, 3], y=[1])
# 243
# Batch(batch=[28], edge_index=[2, 124], x=[28, 3], y=[1])
# 244
# Batch(batch=[40], edge_index=[2, 176], x=[40, 3], y=[1])
# 245
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 246
# Batch(batch=[39], edge_index=[2, 116], x=[39, 3], y=[1])
# 247
# Batch(batch=[28], edge_index=[2, 96], x=[28, 3], y=[1])
# 248
# Batch(batch=[29], edge_index=[2, 104], x=[29, 3], y=[1])
# 249
# Batch(batch=[30], edge_index=[2, 134], x=[30, 3], y=[1])
# 250
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 251
# Batch(batch=[32], edge_index=[2, 120], x=[32, 3], y=[1])
# 252
# Batch(batch=[35], edge_index=[2, 132], x=[35, 3], y=[1])
# 253
# Batch(batch=[24], edge_index=[2, 80], x=[24, 3], y=[1])
# 254
# Batch(batch=[17], edge_index=[2, 60], x=[17, 3], y=[1])
# 255
# Batch(batch=[18], edge_index=[2, 66], x=[18, 3], y=[1])
# 256
# Batch(batch=[16], edge_index=[2, 58], x=[16, 3], y=[1])
# 257
# Batch(batch=[19], edge_index=[2, 72], x=[19, 3], y=[1])
# 258
# Batch(batch=[19], edge_index=[2, 70], x=[19, 3], y=[1])
# 259
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 260
# Batch(batch=[23], edge_index=[2, 104], x=[23, 3], y=[1])
# 261
# Batch(batch=[25], edge_index=[2, 102], x=[25, 3], y=[1])
# 262
# Batch(batch=[27], edge_index=[2, 120], x=[27, 3], y=[1])
# 263
# Batch(batch=[24], edge_index=[2, 96], x=[24, 3], y=[1])
# 264
# Batch(batch=[24], edge_index=[2, 98], x=[24, 3], y=[1])
# 265
# Batch(batch=[32], edge_index=[2, 122], x=[32, 3], y=[1])
# 266
# Batch(batch=[31], edge_index=[2, 118], x=[31, 3], y=[1])
# 267
# Batch(batch=[33], edge_index=[2, 142], x=[33, 3], y=[1])
# 268
# Batch(batch=[34], edge_index=[2, 146], x=[34, 3], y=[1])
# 269
# Batch(batch=[32], edge_index=[2, 120], x=[32, 3], y=[1])
# 270
# Batch(batch=[32], edge_index=[2, 140], x=[32, 3], y=[1])
# 271
# Batch(batch=[44], edge_index=[2, 156], x=[44, 3], y=[1])
# 272
# Batch(batch=[40], edge_index=[2, 168], x=[40, 3], y=[1])
# 273
# Batch(batch=[40], edge_index=[2, 146], x=[40, 3], y=[1])
# 274
# Batch(batch=[38], edge_index=[2, 122], x=[38, 3], y=[1])
# 275
# Batch(batch=[30], edge_index=[2, 112], x=[30, 3], y=[1])
# 276
# Batch(batch=[38], edge_index=[2, 140], x=[38, 3], y=[1])
# 277
# Batch(batch=[44], edge_index=[2, 170], x=[44, 3], y=[1])
# 278
# Batch(batch=[60], edge_index=[2, 214], x=[60, 3], y=[1])
# 279
# Batch(batch=[28], edge_index=[2, 102], x=[28, 3], y=[1])
# 280
# Batch(batch=[16], edge_index=[2, 64], x=[16, 3], y=[1])
# 281
# Batch(batch=[50], edge_index=[2, 172], x=[50, 3], y=[1])
# 282
# Batch(batch=[52], edge_index=[2, 174], x=[52, 3], y=[1])
# 283
# Batch(batch=[48], edge_index=[2, 156], x=[48, 3], y=[1])
# 284
# Batch(batch=[50], edge_index=[2, 168], x=[50, 3], y=[1])
# 285
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 286
# Batch(batch=[43], edge_index=[2, 166], x=[43, 3], y=[1])
# 287
# Batch(batch=[41], edge_index=[2, 158], x=[41, 3], y=[1])
# 288
# Batch(batch=[39], edge_index=[2, 160], x=[39, 3], y=[1])
# 289
# Batch(batch=[38], edge_index=[2, 148], x=[38, 3], y=[1])
# 290
# Batch(batch=[62], edge_index=[2, 208], x=[62, 3], y=[1])
# 291
# Batch(batch=[60], edge_index=[2, 200], x=[60, 3], y=[1])
# 292
# Batch(batch=[96], edge_index=[2, 218], x=[96, 3], y=[1])
# 293
# Batch(batch=[54], edge_index=[2, 198], x=[54, 3], y=[1])
# 294
# Batch(batch=[124], edge_index=[2, 278], x=[124, 3], y=[1])
# 295
# Batch(batch=[126], edge_index=[2, 282], x=[126, 3], y=[1])
# 296
# Batch(batch=[122], edge_index=[2, 298], x=[122, 3], y=[1])
# 297
# Batch(batch=[24], edge_index=[2, 102], x=[24, 3], y=[1])
# 298
# Batch(batch=[41], edge_index=[2, 148], x=[41, 3], y=[1])
# 299
# Batch(batch=[49], edge_index=[2, 186], x=[49, 3], y=[1])
# 300
# Batch(batch=[44], edge_index=[2, 178], x=[44, 3], y=[1])
# 301
# Batch(batch=[42], edge_index=[2, 168], x=[42, 3], y=[1])
# 302
# Batch(batch=[41], edge_index=[2, 166], x=[41, 3], y=[1])
# 303
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 304
# Batch(batch=[46], edge_index=[2, 186], x=[46, 3], y=[1])
# 305
# Batch(batch=[55], edge_index=[2, 196], x=[55, 3], y=[1])
# 306
# Batch(batch=[50], edge_index=[2, 184], x=[50, 3], y=[1])
# 307
# Batch(batch=[42], edge_index=[2, 164], x=[42, 3], y=[1])
# 308
# Batch(batch=[48], edge_index=[2, 188], x=[48, 3], y=[1])
# 309
# Batch(batch=[51], edge_index=[2, 198], x=[51, 3], y=[1])
# 310
# Batch(batch=[24], edge_index=[2, 100], x=[24, 3], y=[1])
# 311
# Batch(batch=[51], edge_index=[2, 178], x=[51, 3], y=[1])
# 312
# Batch(batch=[52], edge_index=[2, 192], x=[52, 3], y=[1])
# 313
# Batch(batch=[22], edge_index=[2, 76], x=[22, 3], y=[1])
# 314
# Batch(batch=[44], edge_index=[2, 184], x=[44, 3], y=[1])
# 315
# Batch(batch=[44], edge_index=[2, 180], x=[44, 3], y=[1])
# 316
# Batch(batch=[31], edge_index=[2, 128], x=[31, 3], y=[1])
# 317
# Batch(batch=[27], edge_index=[2, 106], x=[27, 3], y=[1])
# 318
# Batch(batch=[25], edge_index=[2, 90], x=[25, 3], y=[1])
# 319
# Batch(batch=[38], edge_index=[2, 106], x=[38, 3], y=[1])
# 320
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 321
# Batch(batch=[29], edge_index=[2, 114], x=[29, 3], y=[1])
# 322
# Batch(batch=[20], edge_index=[2, 74], x=[20, 3], y=[1])
# 323
# Batch(batch=[21], edge_index=[2, 74], x=[21, 3], y=[1])
# 324
# Batch(batch=[50], edge_index=[2, 196], x=[50, 3], y=[1])
# 325
# Batch(batch=[46], edge_index=[2, 192], x=[46, 3], y=[1])
# 326
# Batch(batch=[49], edge_index=[2, 188], x=[49, 3], y=[1])
# 327
# Batch(batch=[27], edge_index=[2, 98], x=[27, 3], y=[1])
# 328
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 329
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 330
# Batch(batch=[23], edge_index=[2, 96], x=[23, 3], y=[1])
# 331
# Batch(batch=[24], edge_index=[2, 102], x=[24, 3], y=[1])
# 332
# Batch(batch=[33], edge_index=[2, 122], x=[33, 3], y=[1])
# 333
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 334
# Batch(batch=[25], edge_index=[2, 102], x=[25, 3], y=[1])
# 335
# Batch(batch=[28], edge_index=[2, 104], x=[28, 3], y=[1])
# 336
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 337
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 338
# Batch(batch=[26], edge_index=[2, 98], x=[26, 3], y=[1])
# 339
# Batch(batch=[28], edge_index=[2, 98], x=[28, 3], y=[1])
# 340
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 341
# Batch(batch=[26], edge_index=[2, 98], x=[26, 3], y=[1])
# 342
# Batch(batch=[24], edge_index=[2, 90], x=[24, 3], y=[1])
# 343
# Batch(batch=[23], edge_index=[2, 78], x=[23, 3], y=[1])
# 344
# Batch(batch=[27], edge_index=[2, 116], x=[27, 3], y=[1])
# 345
# Batch(batch=[39], edge_index=[2, 134], x=[39, 3], y=[1])
# 346
# Batch(batch=[42], edge_index=[2, 174], x=[42, 3], y=[1])
# 347
# Batch(batch=[42], edge_index=[2, 170], x=[42, 3], y=[1])
# 348
# Batch(batch=[64], edge_index=[2, 236], x=[64, 3], y=[1])
# 349
# Batch(batch=[38], edge_index=[2, 142], x=[38, 3], y=[1])
# 350
# Batch(batch=[22], edge_index=[2, 84], x=[22, 3], y=[1])
# 351
# Batch(batch=[9], edge_index=[2, 16], x=[9, 3], y=[1])
# 352
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 353
# Batch(batch=[19], edge_index=[2, 84], x=[19, 3], y=[1])
# 354
# Batch(batch=[66], edge_index=[2, 224], x=[66, 3], y=[1])
# 355
# Batch(batch=[27], edge_index=[2, 112], x=[27, 3], y=[1])
# 356
# Batch(batch=[34], edge_index=[2, 124], x=[34, 3], y=[1])
# 357
# Batch(batch=[28], edge_index=[2, 112], x=[28, 3], y=[1])
# 358
# Batch(batch=[26], edge_index=[2, 92], x=[26, 3], y=[1])
# 359
# Batch(batch=[26], edge_index=[2, 108], x=[26, 3], y=[1])
# 360
# Batch(batch=[28], edge_index=[2, 118], x=[28, 3], y=[1])
# 361
# Batch(batch=[19], edge_index=[2, 82], x=[19, 3], y=[1])
# 362
# Batch(batch=[20], edge_index=[2, 92], x=[20, 3], y=[1])
# 363
# Batch(batch=[20], edge_index=[2, 98], x=[20, 3], y=[1])
# 364
# Batch(batch=[42], edge_index=[2, 150], x=[42, 3], y=[1])
# 365
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 366
# Batch(batch=[15], edge_index=[2, 50], x=[15, 3], y=[1])
# 367
# Batch(batch=[11], edge_index=[2, 38], x=[11, 3], y=[1])
# 368
# Batch(batch=[10], edge_index=[2, 34], x=[10, 3], y=[1])
# 369
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 370
# Batch(batch=[30], edge_index=[2, 104], x=[30, 3], y=[1])
# 371
# Batch(batch=[15], edge_index=[2, 52], x=[15, 3], y=[1])
# 372
# Batch(batch=[10], edge_index=[2, 40], x=[10, 3], y=[1])
# 373
# Batch(batch=[18], edge_index=[2, 68], x=[18, 3], y=[1])
# 374
# Batch(batch=[22], edge_index=[2, 80], x=[22, 3], y=[1])
# 375
# Batch(batch=[12], edge_index=[2, 44], x=[12, 3], y=[1])
# 376
# Batch(batch=[36], edge_index=[2, 140], x=[36, 3], y=[1])
# 377
# Batch(batch=[30], edge_index=[2, 102], x=[30, 3], y=[1])
# 378
# Batch(batch=[30], edge_index=[2, 104], x=[30, 3], y=[1])
# 379
# Batch(batch=[36], edge_index=[2, 122], x=[36, 3], y=[1])
# 380
# Batch(batch=[33], edge_index=[2, 116], x=[33, 3], y=[1])
# 381
# Batch(batch=[48], edge_index=[2, 188], x=[48, 3], y=[1])
# 382
# Batch(batch=[27], edge_index=[2, 104], x=[27, 3], y=[1])
# 383
# Batch(batch=[27], edge_index=[2, 108], x=[27, 3], y=[1])
# 384
# Batch(batch=[16], edge_index=[2, 58], x=[16, 3], y=[1])
# 385
# Batch(batch=[7], edge_index=[2, 28], x=[7, 3], y=[1])
# 386
# Batch(batch=[16], edge_index=[2, 56], x=[16, 3], y=[1])
# 387
# Batch(batch=[35], edge_index=[2, 128], x=[35, 3], y=[1])
# 388
# Batch(batch=[28], edge_index=[2, 110], x=[28, 3], y=[1])
# 389
# Batch(batch=[40], edge_index=[2, 162], x=[40, 3], y=[1])
# 390
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 391
# Batch(batch=[48], edge_index=[2, 178], x=[48, 3], y=[1])
# 392
# Batch(batch=[15], edge_index=[2, 56], x=[15, 3], y=[1])
# 393
# Batch(batch=[11], edge_index=[2, 44], x=[11, 3], y=[1])
# 394
# Batch(batch=[50], edge_index=[2, 196], x=[50, 3], y=[1])
# 395
# Batch(batch=[18], edge_index=[2, 70], x=[18, 3], y=[1])
# 396
# Batch(batch=[19], edge_index=[2, 78], x=[19, 3], y=[1])
# 397
# Batch(batch=[14], edge_index=[2, 46], x=[14, 3], y=[1])
# 398
# Batch(batch=[21], edge_index=[2, 86], x=[21, 3], y=[1])
# 399
# Batch(batch=[37], edge_index=[2, 116], x=[37, 3], y=[1])
# 400
# Batch(batch=[48], edge_index=[2, 194], x=[48, 3], y=[1])
# 401
# Batch(batch=[25], edge_index=[2, 102], x=[25, 3], y=[1])
# 402
# Batch(batch=[28], edge_index=[2, 114], x=[28, 3], y=[1])
# 403
# Batch(batch=[33], edge_index=[2, 112], x=[33, 3], y=[1])
# 404
# Batch(batch=[29], edge_index=[2, 100], x=[29, 3], y=[1])
# 405
# Batch(batch=[33], edge_index=[2, 128], x=[33, 3], y=[1])
# 406
# Batch(batch=[30], edge_index=[2, 120], x=[30, 3], y=[1])
# 407
# Batch(batch=[33], edge_index=[2, 132], x=[33, 3], y=[1])
# 408
# Batch(batch=[32], edge_index=[2, 120], x=[32, 3], y=[1])
# 409
# Batch(batch=[28], edge_index=[2, 124], x=[28, 3], y=[1])
# 410
# Batch(batch=[37], edge_index=[2, 138], x=[37, 3], y=[1])
# 411
# Batch(batch=[36], edge_index=[2, 136], x=[36, 3], y=[1])
# 412
# Batch(batch=[38], edge_index=[2, 158], x=[38, 3], y=[1])
# 413
# Batch(batch=[37], edge_index=[2, 146], x=[37, 3], y=[1])
# 414
# Batch(batch=[34], edge_index=[2, 152], x=[34, 3], y=[1])
# 415
# Batch(batch=[24], edge_index=[2, 92], x=[24, 3], y=[1])
# 416
# Batch(batch=[25], edge_index=[2, 94], x=[25, 3], y=[1])
# 417
# Batch(batch=[41], edge_index=[2, 152], x=[41, 3], y=[1])
# 418
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 419
# Batch(batch=[26], edge_index=[2, 94], x=[26, 3], y=[1])
# 420
# Batch(batch=[25], edge_index=[2, 98], x=[25, 3], y=[1])
# 421
# Batch(batch=[27], edge_index=[2, 114], x=[27, 3], y=[1])
# 422
# Batch(batch=[20], edge_index=[2, 76], x=[20, 3], y=[1])
# 423
# Batch(batch=[40], edge_index=[2, 132], x=[40, 3], y=[1])
# 424
# Batch(batch=[21], edge_index=[2, 78], x=[21, 3], y=[1])
# 425
# Batch(batch=[19], edge_index=[2, 66], x=[19, 3], y=[1])
# 426
# Batch(batch=[36], edge_index=[2, 128], x=[36, 3], y=[1])
# 427
# Batch(batch=[32], edge_index=[2, 114], x=[32, 3], y=[1])
# 428
# Batch(batch=[28], edge_index=[2, 108], x=[28, 3], y=[1])
# 429
# Batch(batch=[37], edge_index=[2, 114], x=[37, 3], y=[1])
# 430
# Batch(batch=[18], edge_index=[2, 74], x=[18, 3], y=[1])
# 431
# Batch(batch=[19], edge_index=[2, 78], x=[19, 3], y=[1])
# 432
# Batch(batch=[22], edge_index=[2, 92], x=[22, 3], y=[1])
# 433
# Batch(batch=[43], edge_index=[2, 140], x=[43, 3], y=[1])
# 434
# Batch(batch=[24], edge_index=[2, 92], x=[24, 3], y=[1])
# 435
# Batch(batch=[15], edge_index=[2, 66], x=[15, 3], y=[1])
# 436
# Batch(batch=[14], edge_index=[2, 46], x=[14, 3], y=[1])
# 437
# Batch(batch=[48], edge_index=[2, 198], x=[48, 3], y=[1])
# 438
# Batch(batch=[46], edge_index=[2, 198], x=[46, 3], y=[1])
# 439
# Batch(batch=[26], edge_index=[2, 100], x=[26, 3], y=[1])
# 440
# Batch(batch=[25], edge_index=[2, 112], x=[25, 3], y=[1])
# 441
# Batch(batch=[44], edge_index=[2, 190], x=[44, 3], y=[1])
# 442
# Batch(batch=[39], edge_index=[2, 152], x=[39, 3], y=[1])
# 443
# Batch(batch=[39], edge_index=[2, 158], x=[39, 3], y=[1])
# 444
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 445
# Batch(batch=[26], edge_index=[2, 116], x=[26, 3], y=[1])
# 446
# Batch(batch=[25], edge_index=[2, 112], x=[25, 3], y=[1])
# 447
# Batch(batch=[39], edge_index=[2, 146], x=[39, 3], y=[1])
# 448
# Batch(batch=[26], edge_index=[2, 114], x=[26, 3], y=[1])
# 449
# Batch(batch=[26], edge_index=[2, 116], x=[26, 3], y=[1])
# 450
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 451
# Batch(batch=[34], edge_index=[2, 108], x=[34, 3], y=[1])
# 452
# Batch(batch=[20], edge_index=[2, 90], x=[20, 3], y=[1])
# 453
# Batch(batch=[20], edge_index=[2, 78], x=[20, 3], y=[1])
# 454
# Batch(batch=[19], edge_index=[2, 74], x=[19, 3], y=[1])
# 455
# Batch(batch=[18], edge_index=[2, 68], x=[18, 3], y=[1])
# 456
# Batch(batch=[33], edge_index=[2, 84], x=[33, 3], y=[1])
# 457
# Batch(batch=[15], edge_index=[2, 58], x=[15, 3], y=[1])
# 458
# Batch(batch=[34], edge_index=[2, 154], x=[34, 3], y=[1])
# 459
# Batch(batch=[28], edge_index=[2, 130], x=[28, 3], y=[1])
# 460
# Batch(batch=[34], edge_index=[2, 158], x=[34, 3], y=[1])
# 461
# Batch(batch=[15], edge_index=[2, 60], x=[15, 3], y=[1])
# 462
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 463
# Batch(batch=[20], edge_index=[2, 90], x=[20, 3], y=[1])
# 464
# Batch(batch=[52], edge_index=[2, 198], x=[52, 3], y=[1])
# 465
# Batch(batch=[20], edge_index=[2, 76], x=[20, 3], y=[1])
# 466
# Batch(batch=[20], edge_index=[2, 82], x=[20, 3], y=[1])
# 467
# Batch(batch=[20], edge_index=[2, 74], x=[20, 3], y=[1])
# 468
# Batch(batch=[17], edge_index=[2, 60], x=[17, 3], y=[1])
# 469
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 470
# Batch(batch=[24], edge_index=[2, 74], x=[24, 3], y=[1])
# 471
# Batch(batch=[46], edge_index=[2, 186], x=[46, 3], y=[1])
# 472
# Batch(batch=[13], edge_index=[2, 52], x=[13, 3], y=[1])
# 473
# Batch(batch=[24], edge_index=[2, 90], x=[24, 3], y=[1])
# 474
# Batch(batch=[12], edge_index=[2, 46], x=[12, 3], y=[1])
# 475
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 476
# Batch(batch=[14], edge_index=[2, 52], x=[14, 3], y=[1])
# 477
# Batch(batch=[20], edge_index=[2, 76], x=[20, 3], y=[1])
# 478
# Batch(batch=[28], edge_index=[2, 98], x=[28, 3], y=[1])
# 479
# Batch(batch=[24], edge_index=[2, 76], x=[24, 3], y=[1])
# 480
# Batch(batch=[12], edge_index=[2, 48], x=[12, 3], y=[1])
# 481
# Batch(batch=[26], edge_index=[2, 88], x=[26, 3], y=[1])
# 482
# Batch(batch=[22], edge_index=[2, 92], x=[22, 3], y=[1])
# 483
# Batch(batch=[60], edge_index=[2, 160], x=[60, 3], y=[1])
# 484
# Batch(batch=[39], edge_index=[2, 144], x=[39, 3], y=[1])
# 485
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 486
# Batch(batch=[15], edge_index=[2, 54], x=[15, 3], y=[1])
# 487
# Batch(batch=[25], edge_index=[2, 84], x=[25, 3], y=[1])
# 488
# Batch(batch=[35], edge_index=[2, 122], x=[35, 3], y=[1])
# 489
# Batch(batch=[35], edge_index=[2, 134], x=[35, 3], y=[1])
# 490
# Batch(batch=[38], edge_index=[2, 140], x=[38, 3], y=[1])
# 491
# Batch(batch=[38], edge_index=[2, 158], x=[38, 3], y=[1])
# 492
# Batch(batch=[33], edge_index=[2, 136], x=[33, 3], y=[1])
# 493
# Batch(batch=[32], edge_index=[2, 122], x=[32, 3], y=[1])
# 494
# Batch(batch=[42], edge_index=[2, 154], x=[42, 3], y=[1])
# 495
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 496
# Batch(batch=[41], edge_index=[2, 156], x=[41, 3], y=[1])
# 497
# Batch(batch=[40], edge_index=[2, 144], x=[40, 3], y=[1])
# 498
# Batch(batch=[38], edge_index=[2, 152], x=[38, 3], y=[1])
# 499
# Batch(batch=[43], edge_index=[2, 196], x=[43, 3], y=[1])
# 500
# Batch(batch=[67], edge_index=[2, 160], x=[67, 3], y=[1])
# 501
# Batch(batch=[36], edge_index=[2, 146], x=[36, 3], y=[1])
# 502
# Batch(batch=[46], edge_index=[2, 166], x=[46, 3], y=[1])
# 503
# Batch(batch=[66], edge_index=[2, 240], x=[66, 3], y=[1])
# 504
# Batch(batch=[21], edge_index=[2, 86], x=[21, 3], y=[1])
# 505
# Batch(batch=[22], edge_index=[2, 98], x=[22, 3], y=[1])
# 506
# Batch(batch=[21], edge_index=[2, 92], x=[21, 3], y=[1])
# 507
# Batch(batch=[21], edge_index=[2, 96], x=[21, 3], y=[1])
# 508
# Batch(batch=[41], edge_index=[2, 176], x=[41, 3], y=[1])
# 509
# Batch(batch=[29], edge_index=[2, 130], x=[29, 3], y=[1])
# 510
# Batch(batch=[30], edge_index=[2, 134], x=[30, 3], y=[1])
# 511
# Batch(batch=[30], edge_index=[2, 136], x=[30, 3], y=[1])
# 512
# Batch(batch=[41], edge_index=[2, 184], x=[41, 3], y=[1])
# 513
# Batch(batch=[37], edge_index=[2, 176], x=[37, 3], y=[1])
# 514
# Batch(batch=[26], edge_index=[2, 102], x=[26, 3], y=[1])
# 515
# Batch(batch=[37], edge_index=[2, 142], x=[37, 3], y=[1])
# 516
# Batch(batch=[50], edge_index=[2, 178], x=[50, 3], y=[1])
# 517
# Batch(batch=[27], edge_index=[2, 112], x=[27, 3], y=[1])
# 518
# Batch(batch=[34], edge_index=[2, 154], x=[34, 3], y=[1])
# 519
# Batch(batch=[32], edge_index=[2, 148], x=[32, 3], y=[1])
# 520
# Batch(batch=[35], edge_index=[2, 158], x=[35, 3], y=[1])
# 521
# Batch(batch=[37], edge_index=[2, 164], x=[37, 3], y=[1])
# 522
# Batch(batch=[48], edge_index=[2, 222], x=[48, 3], y=[1])
# 523
# Batch(batch=[41], edge_index=[2, 148], x=[41, 3], y=[1])
# 524
# Batch(batch=[29], edge_index=[2, 132], x=[29, 3], y=[1])
# 525
# Batch(batch=[58], edge_index=[2, 220], x=[58, 3], y=[1])
# 526
# Batch(batch=[57], edge_index=[2, 214], x=[57, 3], y=[1])
# 527
# Batch(batch=[21], edge_index=[2, 106], x=[21, 3], y=[1])
# 528
# Batch(batch=[18], edge_index=[2, 86], x=[18, 3], y=[1])
# 529
# Batch(batch=[42], edge_index=[2, 166], x=[42, 3], y=[1])
# 530
# Batch(batch=[40], edge_index=[2, 164], x=[40, 3], y=[1])
# 531
# Batch(batch=[74], edge_index=[2, 240], x=[74, 3], y=[1])
# 532
# Batch(batch=[44], edge_index=[2, 170], x=[44, 3], y=[1])
# 533
# Batch(batch=[44], edge_index=[2, 198], x=[44, 3], y=[1])
# 534
# Batch(batch=[40], edge_index=[2, 168], x=[40, 3], y=[1])
# 535
# Batch(batch=[44], edge_index=[2, 184], x=[44, 3], y=[1])
# 536
# Batch(batch=[42], edge_index=[2, 178], x=[42, 3], y=[1])
# 537
# Batch(batch=[43], edge_index=[2, 176], x=[43, 3], y=[1])
# 538
# Batch(batch=[41], edge_index=[2, 184], x=[41, 3], y=[1])
# 539
# Batch(batch=[49], edge_index=[2, 184], x=[49, 3], y=[1])
# 540
# Batch(batch=[84], edge_index=[2, 152], x=[84, 3], y=[1])
# 541
# Batch(batch=[44], edge_index=[2, 202], x=[44, 3], y=[1])
# 542
# Batch(batch=[42], edge_index=[2, 152], x=[42, 3], y=[1])
# 543
# Batch(batch=[41], edge_index=[2, 158], x=[41, 3], y=[1])
# 544
# Batch(batch=[41], edge_index=[2, 154], x=[41, 3], y=[1])
# 545
# Batch(batch=[44], edge_index=[2, 164], x=[44, 3], y=[1])
# 546
# Batch(batch=[39], edge_index=[2, 164], x=[39, 3], y=[1])
# 547
# Batch(batch=[25], edge_index=[2, 90], x=[25, 3], y=[1])
# 548
# Batch(batch=[25], edge_index=[2, 94], x=[25, 3], y=[1])
# 549
# Batch(batch=[26], edge_index=[2, 90], x=[26, 3], y=[1])
# 550
# Batch(batch=[52], edge_index=[2, 196], x=[52, 3], y=[1])
# 551
# Batch(batch=[41], edge_index=[2, 172], x=[41, 3], y=[1])
# 552
# Batch(batch=[45], edge_index=[2, 164], x=[45, 3], y=[1])
# 553
# Batch(batch=[31], edge_index=[2, 128], x=[31, 3], y=[1])
# 554
# Batch(batch=[26], edge_index=[2, 92], x=[26, 3], y=[1])
# 555
# Batch(batch=[26], edge_index=[2, 96], x=[26, 3], y=[1])
# 556
# Batch(batch=[52], edge_index=[2, 198], x=[52, 3], y=[1])
# 557
# Batch(batch=[50], edge_index=[2, 186], x=[50, 3], y=[1])
# 558
# Batch(batch=[38], edge_index=[2, 134], x=[38, 3], y=[1])
# 559
# Batch(batch=[37], edge_index=[2, 134], x=[37, 3], y=[1])
# 560
# Batch(batch=[27], edge_index=[2, 104], x=[27, 3], y=[1])
# 561
# Batch(batch=[29], edge_index=[2, 110], x=[29, 3], y=[1])
# 562
# Batch(batch=[48], edge_index=[2, 160], x=[48, 3], y=[1])
# 563
# Batch(batch=[40], edge_index=[2, 148], x=[40, 3], y=[1])
# 564
# Batch(batch=[19], edge_index=[2, 68], x=[19, 3], y=[1])
# 565
# Batch(batch=[14], edge_index=[2, 66], x=[14, 3], y=[1])
# 566
# Batch(batch=[13], edge_index=[2, 62], x=[13, 3], y=[1])
# 567
# Batch(batch=[13], edge_index=[2, 68], x=[13, 3], y=[1])
# 568
# Batch(batch=[44], edge_index=[2, 170], x=[44, 3], y=[1])
# 569
# Batch(batch=[45], edge_index=[2, 156], x=[45, 3], y=[1])
# 570
# Batch(batch=[46], edge_index=[2, 164], x=[46, 3], y=[1])
# 571
# Batch(batch=[47], edge_index=[2, 158], x=[47, 3], y=[1])
# 572
# Batch(batch=[47], edge_index=[2, 164], x=[47, 3], y=[1])
# 573
# Batch(batch=[42], edge_index=[2, 180], x=[42, 3], y=[1])
# 574
# Batch(batch=[51], edge_index=[2, 220], x=[51, 3], y=[1])
# 575
# Batch(batch=[27], edge_index=[2, 102], x=[27, 3], y=[1])
# 576
# Batch(batch=[27], edge_index=[2, 104], x=[27, 3], y=[1])
# 577
# Batch(batch=[60], edge_index=[2, 206], x=[60, 3], y=[1])
# 578
# Batch(batch=[28], edge_index=[2, 106], x=[28, 3], y=[1])
# 579
# Batch(batch=[38], edge_index=[2, 150], x=[38, 3], y=[1])
# 580
# Batch(batch=[23], edge_index=[2, 106], x=[23, 3], y=[1])
# 581
# Batch(batch=[18], edge_index=[2, 74], x=[18, 3], y=[1])
# 582
# Batch(batch=[45], edge_index=[2, 194], x=[45, 3], y=[1])
# 583
# Batch(batch=[21], edge_index=[2, 90], x=[21, 3], y=[1])
# 584
# Batch(batch=[35], edge_index=[2, 142], x=[35, 3], y=[1])
# 585
# Batch(batch=[24], edge_index=[2, 102], x=[24, 3], y=[1])
# 586
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 587
# Batch(batch=[21], edge_index=[2, 84], x=[21, 3], y=[1])
# 588
# Batch(batch=[31], edge_index=[2, 124], x=[31, 3], y=[1])
# 589
# Batch(batch=[27], edge_index=[2, 112], x=[27, 3], y=[1])
# 590
# Batch(batch=[51], edge_index=[2, 196], x=[51, 3], y=[1])
# 591
# Batch(batch=[36], edge_index=[2, 156], x=[36, 3], y=[1])
# 592
# Batch(batch=[46], edge_index=[2, 144], x=[46, 3], y=[1])
# 593
# Batch(batch=[52], edge_index=[2, 228], x=[52, 3], y=[1])
# 594
# Batch(batch=[44], edge_index=[2, 180], x=[44, 3], y=[1])
# 595
# Batch(batch=[45], edge_index=[2, 182], x=[45, 3], y=[1])
# 596
# Batch(batch=[52], edge_index=[2, 232], x=[52, 3], y=[1])
# 597
# Batch(batch=[55], edge_index=[2, 200], x=[55, 3], y=[1])
# 598
# Batch(batch=[51], edge_index=[2, 190], x=[51, 3], y=[1])
# 599
# Batch(batch=[48], edge_index=[2, 156], x=[48, 3], y=[1])
# 600

# %%
#---------------------------------------------------------------------


#MUTAG
#print("\n MUTAG")
#dname='Entities'
#name='MUTAG'
#dataset = loadDataset(dname,name)
#processDatasetsTF(dname+'_'+name,dataset)



#PPI
#print("\PPI PPI")
#dname='PPI'
#dataset = loadDataset(dname)
#processDatasetsTF(dname,dataset)



  


#PROTEINS FROM TUDataset
print("\nTUDataset PROTEINS")
dname='TUDataset'
name='PROTEINS'
dataset = loadDataset(dname,name)
processDatasetsTF(dname+'_'+name, dataset)

#QM7b
print("\QM7B QM7B")
dataset = loadDataset('QM7b')
processDatasetsTF(dname,dataset)

# Planetoid Cora
print("\n Planetoid Cora")
dname='Planetoid'
name='Cora'
dataset = loadDataset(dname,name)
processDatasetsTF(dname+'_'+name,dataset)
