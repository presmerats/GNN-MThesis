# %%
# local python tests
from pprint import pprint
from igraph import *
import igraph.test
import pickle
import os
import numpy as np
from scipy.sparse import csr_matrix
import collections
import copy
from random import randint





"""

    %%%%%%%%%%%%%%%%%%%%%%%%%%% gcn tests %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    x  feature vectors
    tx feature vectors for test (unlabeled)
    allx feature vectors for all

    y  label vectors       numpy.ndarray
    ty test label vectors  numpy.ndarray
    ally  test label of all

    graph : adjacency matrix (dict of lists)
    test.index: node id list for tests?


    steps
    1) inspect ind.citeseer.x/tx/y/ty/allx/ally/test.index

    2) build those files from code

    3) call learning algorithm
        cd src/notebooks
        python gcn_tests_input.py&&  cp ind.* ../gcn/gcn/gcn/data
        cd src/gcn/gcn/gcn
        python train.py --dataset t1


    4) look at embedding result

"""


def pickleToDisk(myobj, filepath):
    pickle.dump(myobj, open(filepath, "wb"))


def printGraphObject(filepath):


    myobject = os.path.basename(filepath)
    print("\n\n*************** "+myobject+" ********************")
    y = pickle.load(open(filepath,'rb'))
    print(type(y))
    if type(y) ==  type([]) or type(y) == type(np.ndarray([])):
        
        print(len(y))
        pprint(y[:min(3,len(y)-1)])
    elif type(y) == type({}) or type(y)==type(collections.defaultdict()):
        pprint(y.keys()[:min(3,len(y)-1)])
        pprint(y[y.keys()[0]])
        pprint(y[y.keys()[1]])
        pprint(y[y.keys()[20]])
        pprint(y[y.keys()[3000]])

    else:
        
        pprint(y.shape)
        pprint(y[0,:min(3,y.shape[1]-1)].toarray())
        pprint(y[0,0].shape)
        pprint(type(y[0,0]))
        pprint(y[0,0])

def readListFile(filepath):
    myobject = os.path.basename(filepath)
    print("\n\n*************** "+myobject+" ********************")
    

    testInstances =[]
    with open(filepath, 'rb') as f:
        for line in f.readlines():
            testInstances.append(int(line))

    pprint(testInstances[:min(3,len(testInstances)-1)])


def inspectData():

    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.y')
    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.ty')
    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.x')
    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.tx')
    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.graph')
    readListFile('../gcn/gcn/gcn/data/ind.citeseer.test.index')
    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.allx')
    printGraphObject('../gcn/gcn/gcn/data/ind.citeseer.ally')


def discretize(elements):
    """ create a binary array for each of the 10 ranges of values between 0 and 1"""
    orig = np.array(elements)
    results = []
    
    themax = np.amax(orig)
    themin = np.amin(orig)
    step = (themax - themin )/ 10.0
    
    for i in range(10):
        print(i) 
        if i<9:
            print(orig)
            print(themin + step*i)
            print(themin + step*(i+1))
            range1 = np.bitwise_and(orig >= themin + step*i , orig <= themin + step*(i+1))
        else:
            range1 = orig >= themin + step*i
        print(range1)
        results.append(range1) 
        
    result = np.transpose(np.asarray(results))
    print(result.shape)
    pprint(result)
    return result


def generateData(suffix, n_node=1000, n_test=200, n_train=300 ):
    
    

    #igraph.test.run_tests()

    # generation
    #g = Graph.Tree(127, 2)
    #g = Graph.GRG(100, 0.2)
    #g = Graph.Erdos_Renyi(100, 0.2)
    #g = Graph.Watts_Strogatz(1, 100, 4, 0.5 )
    g = Graph.Barabasi(n_node)
    summary(g)

    # graph metrics
    # pprint(g.degree([2,3,6,99]))
    # pprint(g.edge_betweenness())
    # pprint(g.pagerank())
    #pprint(g.get_adjacency())
    #pprint(dir(g))
    


    # test.index
    testList = [] 
    with open(suffix+'.test.index','wb') as f:
        while len(testList) < n_test:
            j = randint(0, n_node-1)
            #verify it is not alerady there
            try:
                pos = testList.index(j)
            except:
                testList.append(j)
            f.write(str.encode(str(j)+"\n"))


    # adjacency dict (graph)
    i = 0
    A = g.get_adjlist()
    graphAdj = {}
    for node in A:
        graphAdj[i] = node
        i+=1
    pickleToDisk(graphAdj, suffix+".graph")

    
    xFeatures = np.ones(n_node)
    # allx is for labeled and unlabeled training samples
    allx  = copy.deepcopy([xFeatures[i] for i in range(n_node) if i not in testList])
    # x is for labeled training samples only
    x = copy.deepcopy(allx[:-500])
    #tx = copy.deepcopy(xFeatures[range(n_node-n_test, n_node)])
    tx = [xFeatures[i] for i in testList]
    

    
    allx = csr_matrix(allx)
    allx = np.transpose(allx)
    pickleToDisk(allx, suffix+".allx")
    x = csr_matrix(x)
    x = np.transpose(x)
    pickleToDisk(x, suffix+".x")
    tx = csr_matrix(tx)
    tx = np.transpose(tx)
    pickleToDisk(tx, suffix+".tx")

    print(x.shape)
    print(tx.shape)
    print(allx.shape)
    


    # labels (ally,y , ty)
    prs = discretize(g.pagerank())

    

    # labels of x, and empty labels of unlabeled training samples
    prs_all = copy.deepcopy([prs[i] for i in range(n_node) if i not in testList])
    # labels of the labeled training samples
    prs_train = copy.deepcopy(prs_all[:-500])
    prs_test = copy.deepcopy([prs[i] for i in testList])
    #testList.extend(validationList)
    #finalList = testList
    #prs_train = [ prs[i] for i in range(prs.shape[0]) if i not in finalList ]

    ally = np.array(prs_all)
    y = np.array(prs_train)  
    ty = np.array(prs_test)


    pickleToDisk(ally, suffix+".ally")
    pickleToDisk(y, suffix+".y")
    pickleToDisk(ty, suffix+".ty")
    
    print(y.shape)
    print(ty.shape)
    print(ally.shape)
    pprint(ally)
    

    # run training on those files

# %%
generateData(suffix="ind.t3",n_node=4000, n_train=700, n_test=300)
# !mv ind.* ./data/
# Out:
# IGRAPH U--- 4000 3999 --
# (3200, 1)
# (300, 1)
# (3700, 1)
# 0
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.00012419010535320567
# 0.002569572879116258
# [False  True  True ...  True  True  True]
# 1
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.002569572879116258
# 0.005014955652879311
# [False False False ... False False False]
# 2
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.005014955652879311
# 0.007460338426642363
# [False False False ... False False False]
# 3
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.007460338426642363
# 0.009905721200405415
# [False False False ... False False False]
# 4
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.009905721200405415
# 0.012351103974168469
# [False False False ... False False False]
# 5
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.012351103974168469
# 0.01479648674793152
# [False False False ... False False False]
# 6
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.01479648674793152
# 0.017241869521694573
# [False False False ... False False False]
# 7
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.017241869521694573
# 0.019687252295457626
# [False False False ... False False False]
# 8
# [0.02457802 0.00101988 0.00142194 ... 0.00014971 0.00014745 0.00013078]
# 0.019687252295457626
# 0.02213263506922068
# [False False False ... False False False]
# 9
# [ True False False ... False False False]
# (4000, 10)
# array([[False, False, False, ..., False, False,  True],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False]])
# (3200, 10)
# (300, 10)
# (3700, 10)
# array([[False, False, False, ..., False, False,  True],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False]])

# %%
def plot2DEmbedding(filepath, labelspath):
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    import matplotlib.lines as mlines
    import matplotlib.cm as cm
    # %matplotlib inline

    # read embedding labels file
    labels = np.zeros((1,1))
    with open(labelspath,"r") as f:
        size = len(f.readlines())
        labels = np.zeros((size,1))

    # read embedding file
    with open(filepath,"r") as f:
        size = len(f.readlines())

        
    # read embedding labels file
    embeddings = {}
    with open(labelspath,"r") as f:
        i=0
        for label in f.readlines():
            #print(line)
            vals = label.split()
            label_int = 0
            for j in range(len(vals)):
                label_int += float(vals[j])*j
            labels[i]=int(label_int)
            i=i+1
            
        labels_list = [ lab[0] for lab in labels.tolist()]
        for j in set(labels_list):
            embeddings[j]=np.empty((0,2))
            
        with open(filepath,"r") as f2:
            i = 0
            for line in f2.readlines():
                #print(line)
                d1,d2 = line.split()
                key = int(labels_list[i])
                embedding = embeddings[key]
                
                embeddings[key] = np.append(embedding, [[float(d1), float(d2)]], axis=0)
                #embedding[i,0]=float(d1)
                #embedding[i,1]=float(d2)
                i=i+1
        
        # separate embedding by label
        
        plt.subplot(1, 2, 1)
        color_labels = [int(k % 23) for k in set(labels_list) ]
        colors = cm.rainbow(np.linspace(0, 1, len(color_labels)))
        for colref,col in zip(colors, color_labels) :
            #print(col)
            #print([[col]*embeddings[col].shape[0]])
            #print(embeddings[col].shape[0])
            plt.scatter(embeddings[col][:,0], embeddings[col][:,1], c=[colref]*embeddings[col].shape[0], label=str(col))
        #col=0
        #plt.scatter(embeddings[col][:,0], embeddings[col][:,1], c=str(col), label=str(col))
        plt.suptitle('Embedding')
        plt.xlabel('dim 1')
        plt.ylabel('dim 2')
        plt.legend()
        
        
        # histogram of labels
        plt.subplot(1, 2, 2)
        plt.hist(labels_list,bins=list(set(labels_list)), color='blue')
        plt.xlabel('classes')
        plt.ylabel('counts')
        plt.subplots_adjust(wspace=0.5)
        
        plt.show()

# %%
!~/.pyenv/shims/python  train.py --dataset t3
plot2DEmbedding("embedding","embedding_labels")
# Out:
# len(y): 3200
# labels shape:
# (4000, 10)
# len(idx_train) 3200
# len(idx_val) 500
# len(idx_test) 310
# features after row normalize and tuple
# (array([[   0,    0],
#        [   1,    0],
#        [   2,    0],
#        ...,
#        [3997,    0],
#        [3998,    0],
#        [3999,    0]], dtype=int32),
#  array([1., 1., 1., ..., 1., 1., 1.]),
#  (4000, 1))
# WARNING:tensorflow:From /media/disk/home/pau/Projectes/CSN-proj/src/gcn/gcn_mod/gcn/metrics.py:6: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2019-01-22 18:08:38.763463: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Epoch: 0001 train_loss= 2.40099 train_acc= 0.04969 val_loss= 2.33902 val_acc= 0.00000 time= 0.03709
# Epoch: 0002 train_loss= 2.36194 train_acc= 0.04688 val_loss= 2.31081 val_acc= 0.00000 time= 0.00980
# Epoch: 0003 train_loss= 2.32908 train_acc= 0.03687 val_loss= 2.28798 val_acc= 0.00000 time= 0.00988
# Epoch: 0004 train_loss= 2.29433 train_acc= 0.04156 val_loss= 2.26881 val_acc= 0.00000 time= 0.00978
# Epoch: 0005 train_loss= 2.27985 train_acc= 0.04406 val_loss= 2.25078 val_acc= 0.00000 time= 0.00960
# Epoch: 0006 train_loss= 2.26160 train_acc= 0.03937 val_loss= 2.23187 val_acc= 0.00000 time= 0.01019
# Epoch: 0007 train_loss= 2.23928 train_acc= 0.03625 val_loss= 2.21077 val_acc= 0.00000 time= 0.01219
# Epoch: 0008 train_loss= 2.22257 train_acc= 0.03875 val_loss= 2.18678 val_acc= 0.00000 time= 0.01036
# Epoch: 0009 train_loss= 2.19772 train_acc= 0.04969 val_loss= 2.15932 val_acc= 0.00000 time= 0.01010
# Epoch: 0010 train_loss= 2.16974 train_acc= 0.03687 val_loss= 2.12793 val_acc= 0.00000 time= 0.01007
# Epoch: 0011 train_loss= 2.14426 train_acc= 0.04188 val_loss= 2.09206 val_acc= 0.00000 time= 0.01027
# Epoch: 0012 train_loss= 2.10135 train_acc= 0.04062 val_loss= 2.05125 val_acc= 0.00000 time= 0.01107
# Epoch: 0013 train_loss= 2.06866 train_acc= 0.03937 val_loss= 2.00493 val_acc= 0.00000 time= 0.00958
# Epoch: 0014 train_loss= 2.04512 train_acc= 0.03156 val_loss= 1.95269 val_acc= 0.00000 time= 0.00970
# Epoch: 0015 train_loss= 1.98102 train_acc= 0.04781 val_loss= 1.89408 val_acc= 0.00000 time= 0.00941
# Epoch: 0016 train_loss= 1.92873 train_acc= 0.03562 val_loss= 1.82852 val_acc= 0.00000 time= 0.01009
# Epoch: 0017 train_loss= 1.86315 train_acc= 0.04281 val_loss= 1.75557 val_acc= 0.00000 time= 0.01162
# Epoch: 0018 train_loss= 1.81425 train_acc= 0.04938 val_loss= 1.67487 val_acc= 0.00000 time= 0.01006
# Epoch: 0019 train_loss= 1.74645 train_acc= 0.03844 val_loss= 1.58608 val_acc= 0.00000 time= 0.00975
# Epoch: 0020 train_loss= 1.66747 train_acc= 0.22500 val_loss= 1.48910 val_acc= 1.00000 time= 0.00971
# Epoch: 0021 train_loss= 1.57923 train_acc= 0.59312 val_loss= 1.38382 val_acc= 1.00000 time= 0.01062
# Epoch: 0022 train_loss= 1.49604 train_acc= 0.83094 val_loss= 1.27054 val_acc= 1.00000 time= 0.01140
# Epoch: 0023 train_loss= 1.33357 train_acc= 0.86844 val_loss= 1.14991 val_acc= 1.00000 time= 0.00996
# Epoch: 0024 train_loss= 1.28780 train_acc= 0.86437 val_loss= 1.02318 val_acc= 1.00000 time= 0.00962
# Epoch: 0025 train_loss= 1.20682 train_acc= 0.99500 val_loss= 0.89242 val_acc= 1.00000 time= 0.00958
# Epoch: 0026 train_loss= 1.04651 train_acc= 0.99500 val_loss= 0.76028 val_acc= 1.00000 time= 0.01149
# Epoch: 0027 train_loss= 0.95587 train_acc= 0.99594 val_loss= 0.63061 val_acc= 1.00000 time= 0.01071
# Epoch: 0028 train_loss= 0.89857 train_acc= 0.99500 val_loss= 0.50744 val_acc= 1.00000 time= 0.00977
# Epoch: 0029 train_loss= 0.82010 train_acc= 0.99563 val_loss= 0.39510 val_acc= 1.00000 time= 0.01019
# Epoch: 0030 train_loss= 0.66912 train_acc= 0.99500 val_loss= 0.29730 val_acc= 1.00000 time= 0.00955
# Epoch: 0031 train_loss= 0.64403 train_acc= 0.99594 val_loss= 0.21617 val_acc= 1.00000 time= 0.01172
# Epoch: 0032 train_loss= 0.60494 train_acc= 0.99563 val_loss= 0.15223 val_acc= 1.00000 time= 0.01197
# Epoch: 0033 train_loss= 0.52766 train_acc= 0.99594 val_loss= 0.10410 val_acc= 1.00000 time= 0.00965
# Epoch: 0034 train_loss= 0.50668 train_acc= 0.99563 val_loss= 0.06946 val_acc= 1.00000 time= 0.00950
# Epoch: 0035 train_loss= 0.50094 train_acc= 0.99594 val_loss= 0.04536 val_acc= 1.00000 time= 0.00948
# Epoch: 0036 train_loss= 0.44275 train_acc= 0.99594 val_loss= 0.02920 val_acc= 1.00000 time= 0.01235
# Epoch: 0037 train_loss= 0.42553 train_acc= 0.99594 val_loss= 0.01867 val_acc= 1.00000 time= 0.01023
# Epoch: 0038 train_loss= 0.37246 train_acc= 0.99594 val_loss= 0.01201 val_acc= 1.00000 time= 0.00971
# Epoch: 0039 train_loss= 0.38887 train_acc= 0.99594 val_loss= 0.00779 val_acc= 1.00000 time= 0.00933
# Epoch: 0040 train_loss= 0.35345 train_acc= 0.99594 val_loss= 0.00520 val_acc= 1.00000 time= 0.00948
# Epoch: 0041 train_loss= 0.37762 train_acc= 0.99594 val_loss= 0.00360 val_acc= 1.00000 time= 0.01121
# Epoch: 0042 train_loss= 0.35993 train_acc= 0.99594 val_loss= 0.00261 val_acc= 1.00000 time= 0.01006
# Epoch: 0043 train_loss= 0.33789 train_acc= 0.99594 val_loss= 0.00200 val_acc= 1.00000 time= 0.00932
# Epoch: 0044 train_loss= 0.39611 train_acc= 0.99594 val_loss= 0.00161 val_acc= 1.00000 time= 0.00927
# Epoch: 0045 train_loss= 0.34934 train_acc= 0.99594 val_loss= 0.00137 val_acc= 1.00000 time= 0.00975
# Epoch: 0046 train_loss= 0.33891 train_acc= 0.99594 val_loss= 0.00122 val_acc= 1.00000 time= 0.01072
# Epoch: 0047 train_loss= 0.34689 train_acc= 0.99594 val_loss= 0.00112 val_acc= 1.00000 time= 0.01002
# Epoch: 0048 train_loss= 0.34729 train_acc= 0.99594 val_loss= 0.00105 val_acc= 1.00000 time= 0.00947
# Epoch: 0049 train_loss= 0.34453 train_acc= 0.99594 val_loss= 0.00101 val_acc= 1.00000 time= 0.00943
# Epoch: 0050 train_loss= 0.39436 train_acc= 0.99594 val_loss= 0.00098 val_acc= 1.00000 time= 0.01033
# Epoch: 0051 train_loss= 0.30563 train_acc= 0.99594 val_loss= 0.00096 val_acc= 1.00000 time= 0.01075
# Epoch: 0052 train_loss= 0.32770 train_acc= 0.99594 val_loss= 0.00094 val_acc= 1.00000 time= 0.01025
# Epoch: 0053 train_loss= 0.31860 train_acc= 0.99594 val_loss= 0.00093 val_acc= 1.00000 time= 0.00995
# Epoch: 0054 train_loss= 0.32601 train_acc= 0.99594 val_loss= 0.00092 val_acc= 1.00000 time= 0.00940
# Epoch: 0055 train_loss= 0.35307 train_acc= 0.99594 val_loss= 0.00092 val_acc= 1.00000 time= 0.01060
# Epoch: 0056 train_loss= 0.32897 train_acc= 0.99594 val_loss= 0.00091 val_acc= 1.00000 time= 0.01077
# Epoch: 0057 train_loss= 0.31962 train_acc= 0.99594 val_loss= 0.00091 val_acc= 1.00000 time= 0.01039
# Epoch: 0058 train_loss= 0.33183 train_acc= 0.99594 val_loss= 0.00090 val_acc= 1.00000 time= 0.00993
# Epoch: 0059 train_loss= 0.32908 train_acc= 0.99594 val_loss= 0.00090 val_acc= 1.00000 time= 0.00928
# Epoch: 0060 train_loss= 0.34684 train_acc= 0.99594 val_loss= 0.00090 val_acc= 1.00000 time= 0.00978
# Epoch: 0061 train_loss= 0.31726 train_acc= 0.99594 val_loss= 0.00090 val_acc= 1.00000 time= 0.01200
# Epoch: 0062 train_loss= 0.32188 train_acc= 0.99594 val_loss= 0.00090 val_acc= 1.00000 time= 0.00982
# Epoch: 0063 train_loss= 0.32679 train_acc= 0.99594 val_loss= 0.00091 val_acc= 1.00000 time= 0.00981
# Epoch: 0064 train_loss= 0.31717 train_acc= 0.99594 val_loss= 0.00092 val_acc= 1.00000 time= 0.00965
# Early stopping...
# Optimization Finished!
# Test set results: cost= 0.04679 accuracy= 0.99667 time= 0.00370
# y_test.shape
# (4000, 10)
# test_mask.shape
# (4000,)
#  total embedding size:  4000

# %%
!~/.pyenv/shims/python  train.py --dataset cora
plot2DEmbedding("embedding","embedding_labels")
# Out:
# len(y): 140
# labels shape:
# (2708, 7)
# len(idx_train) 140
# len(idx_val) 500
# len(idx_test) 1000
# features after row normalize and tuple
# (array([[   0, 1274],
#        [   0, 1247],
#        [   0, 1194],
#        ...,
#        [2707,  329],
#        [2707,  186],
#        [2707,   19]], dtype=int32),
#  array([0.11111111, 0.11111111, 0.11111111, ..., 0.07692308, 0.07692308,
#        0.07692308], dtype=float32),
#  (2708, 1433))
# WARNING:tensorflow:From /media/disk/home/pau/Projectes/CSN-proj/src/gcn/gcn_mod/gcn/metrics.py:6: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2019-01-22 17:47:29.192341: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Epoch: 0001 train_loss= 1.95369 train_acc= 0.17857 val_loss= 1.94959 val_acc= 0.19600 time= 0.04680
# Epoch: 0002 train_loss= 1.94921 train_acc= 0.22857 val_loss= 1.94556 val_acc= 0.25000 time= 0.01932
# Epoch: 0003 train_loss= 1.94375 train_acc= 0.25714 val_loss= 1.94130 val_acc= 0.26600 time= 0.01835
# Epoch: 0004 train_loss= 1.93951 train_acc= 0.22143 val_loss= 1.93656 val_acc= 0.27000 time= 0.01906
# Epoch: 0005 train_loss= 1.93176 train_acc= 0.26429 val_loss= 1.93142 val_acc= 0.27600 time= 0.01827
# Epoch: 0006 train_loss= 1.92502 train_acc= 0.26429 val_loss= 1.92582 val_acc= 0.28800 time= 0.01857
# Epoch: 0007 train_loss= 1.91947 train_acc= 0.26429 val_loss= 1.91962 val_acc= 0.29400 time= 0.01999
# Epoch: 0008 train_loss= 1.90527 train_acc= 0.28571 val_loss= 1.91259 val_acc= 0.30000 time= 0.01905
# Epoch: 0009 train_loss= 1.90319 train_acc= 0.26429 val_loss= 1.90475 val_acc= 0.30000 time= 0.02176
# Epoch: 0010 train_loss= 1.88612 train_acc= 0.27143 val_loss= 1.89592 val_acc= 0.30400 time= 0.01973
# Epoch: 0011 train_loss= 1.87968 train_acc= 0.30714 val_loss= 1.88595 val_acc= 0.30800 time= 0.01826
# Epoch: 0012 train_loss= 1.87549 train_acc= 0.25714 val_loss= 1.87492 val_acc= 0.31200 time= 0.02162
# Epoch: 0013 train_loss= 1.85802 train_acc= 0.27143 val_loss= 1.86275 val_acc= 0.31600 time= 0.01765
# Epoch: 0014 train_loss= 1.83655 train_acc= 0.27857 val_loss= 1.84932 val_acc= 0.31400 time= 0.01875
# Epoch: 0015 train_loss= 1.82313 train_acc= 0.26429 val_loss= 1.83487 val_acc= 0.31600 time= 0.01959
# Epoch: 0016 train_loss= 1.81615 train_acc= 0.30000 val_loss= 1.81921 val_acc= 0.32800 time= 0.01808
# Epoch: 0017 train_loss= 1.76850 train_acc= 0.28571 val_loss= 1.80243 val_acc= 0.32400 time= 0.02071
# Epoch: 0018 train_loss= 1.76992 train_acc= 0.29286 val_loss= 1.78469 val_acc= 0.32200 time= 0.01902
# Epoch: 0019 train_loss= 1.76787 train_acc= 0.29286 val_loss= 1.76595 val_acc= 0.32400 time= 0.01814
# Epoch: 0020 train_loss= 1.74701 train_acc= 0.30000 val_loss= 1.74612 val_acc= 0.33000 time= 0.01899
# Epoch: 0021 train_loss= 1.70119 train_acc= 0.29286 val_loss= 1.72515 val_acc= 0.32600 time= 0.01811
# Epoch: 0022 train_loss= 1.67643 train_acc= 0.32143 val_loss= 1.70351 val_acc= 0.32200 time= 0.01787
# Epoch: 0023 train_loss= 1.64302 train_acc= 0.33571 val_loss= 1.68135 val_acc= 0.32600 time= 0.02064
# Epoch: 0024 train_loss= 1.68050 train_acc= 0.29286 val_loss= 1.65940 val_acc= 0.32400 time= 0.01812
# Epoch: 0025 train_loss= 1.62081 train_acc= 0.30714 val_loss= 1.63768 val_acc= 0.32600 time= 0.01969
# Epoch: 0026 train_loss= 1.58796 train_acc= 0.31429 val_loss= 1.61674 val_acc= 0.32800 time= 0.01858
# Epoch: 0027 train_loss= 1.60783 train_acc= 0.28571 val_loss= 1.59668 val_acc= 0.33200 time= 0.01745
# Epoch: 0028 train_loss= 1.55734 train_acc= 0.35714 val_loss= 1.57728 val_acc= 0.33200 time= 0.02001
# Epoch: 0029 train_loss= 1.53634 train_acc= 0.31429 val_loss= 1.55883 val_acc= 0.33200 time= 0.01912
# Epoch: 0030 train_loss= 1.53152 train_acc= 0.33571 val_loss= 1.54148 val_acc= 0.33600 time= 0.02025
# Epoch: 0031 train_loss= 1.48951 train_acc= 0.30714 val_loss= 1.52507 val_acc= 0.33600 time= 0.01995
# Epoch: 0032 train_loss= 1.51346 train_acc= 0.30714 val_loss= 1.50947 val_acc= 0.34400 time= 0.01862
# Epoch: 0033 train_loss= 1.47774 train_acc= 0.34286 val_loss= 1.49471 val_acc= 0.34800 time= 0.02030
# Epoch: 0034 train_loss= 1.49114 train_acc= 0.34286 val_loss= 1.48132 val_acc= 0.35000 time= 0.01789
# Epoch: 0035 train_loss= 1.46085 train_acc= 0.31429 val_loss= 1.46899 val_acc= 0.35400 time= 0.01807
# Epoch: 0036 train_loss= 1.45599 train_acc= 0.36429 val_loss= 1.45690 val_acc= 0.36000 time= 0.02012
# Epoch: 0037 train_loss= 1.40535 train_acc= 0.35714 val_loss= 1.44363 val_acc= 0.36000 time= 0.01774
# Epoch: 0038 train_loss= 1.47875 train_acc= 0.35000 val_loss= 1.43247 val_acc= 0.36600 time= 0.01840
# Epoch: 0039 train_loss= 1.38573 train_acc= 0.39286 val_loss= 1.42188 val_acc= 0.36800 time= 0.02019
# Epoch: 0040 train_loss= 1.37480 train_acc= 0.38571 val_loss= 1.41103 val_acc= 0.36800 time= 0.01819
# Epoch: 0041 train_loss= 1.37847 train_acc= 0.36429 val_loss= 1.40098 val_acc= 0.37000 time= 0.01858
# Epoch: 0042 train_loss= 1.37917 train_acc= 0.42857 val_loss= 1.39279 val_acc= 0.39200 time= 0.01841
# Epoch: 0043 train_loss= 1.35797 train_acc= 0.38571 val_loss= 1.38634 val_acc= 0.41800 time= 0.01792
# Epoch: 0044 train_loss= 1.37528 train_acc= 0.40000 val_loss= 1.38038 val_acc= 0.41400 time= 0.01838
# Epoch: 0045 train_loss= 1.32314 train_acc= 0.40000 val_loss= 1.37092 val_acc= 0.42200 time= 0.01836
# Epoch: 0046 train_loss= 1.23770 train_acc= 0.43571 val_loss= 1.36257 val_acc= 0.43200 time= 0.01891
# Epoch: 0047 train_loss= 1.27809 train_acc= 0.40000 val_loss= 1.35307 val_acc= 0.44000 time= 0.01958
# Epoch: 0048 train_loss= 1.31789 train_acc= 0.42857 val_loss= 1.34353 val_acc= 0.44400 time= 0.01827
# Epoch: 0049 train_loss= 1.24131 train_acc= 0.47857 val_loss= 1.33493 val_acc= 0.46000 time= 0.01805
# Epoch: 0050 train_loss= 1.25496 train_acc= 0.42143 val_loss= 1.32762 val_acc= 0.46400 time= 0.01942
# Epoch: 0051 train_loss= 1.21900 train_acc= 0.50000 val_loss= 1.31945 val_acc= 0.47600 time= 0.01827
# Epoch: 0052 train_loss= 1.25635 train_acc= 0.44286 val_loss= 1.31175 val_acc= 0.49000 time= 0.01986
# Epoch: 0053 train_loss= 1.20935 train_acc= 0.42857 val_loss= 1.30395 val_acc= 0.50200 time= 0.01803
# Epoch: 0054 train_loss= 1.19416 train_acc= 0.54286 val_loss= 1.29537 val_acc= 0.51600 time= 0.01762
# Epoch: 0055 train_loss= 1.23380 train_acc= 0.45714 val_loss= 1.28695 val_acc= 0.53000 time= 0.01968
# Epoch: 0056 train_loss= 1.12606 train_acc= 0.60000 val_loss= 1.27787 val_acc= 0.53600 time= 0.01892
# Epoch: 0057 train_loss= 1.17065 train_acc= 0.53571 val_loss= 1.27092 val_acc= 0.55200 time= 0.01820
# Epoch: 0058 train_loss= 1.10761 train_acc= 0.58571 val_loss= 1.26259 val_acc= 0.56400 time= 0.01979
# Epoch: 0059 train_loss= 1.16406 train_acc= 0.57857 val_loss= 1.25128 val_acc= 0.57000 time= 0.01800
# Epoch: 0060 train_loss= 1.14564 train_acc= 0.57143 val_loss= 1.24129 val_acc= 0.57800 time= 0.01863
# Epoch: 0061 train_loss= 1.11760 train_acc= 0.61429 val_loss= 1.23227 val_acc= 0.59400 time= 0.01952
# Epoch: 0062 train_loss= 1.10711 train_acc= 0.54286 val_loss= 1.22476 val_acc= 0.60800 time= 0.01780
# Epoch: 0063 train_loss= 1.14884 train_acc= 0.58571 val_loss= 1.21843 val_acc= 0.61600 time= 0.01943
# Epoch: 0064 train_loss= 1.12463 train_acc= 0.57857 val_loss= 1.21317 val_acc= 0.64400 time= 0.01781
# Epoch: 0065 train_loss= 1.05123 train_acc= 0.65714 val_loss= 1.20802 val_acc= 0.64400 time= 0.01814
# Epoch: 0066 train_loss= 1.09774 train_acc= 0.62857 val_loss= 1.20044 val_acc= 0.65000 time= 0.01871
# Epoch: 0067 train_loss= 1.12759 train_acc= 0.60000 val_loss= 1.19363 val_acc= 0.65400 time= 0.01827
# Epoch: 0068 train_loss= 1.02748 train_acc= 0.71429 val_loss= 1.18427 val_acc= 0.65200 time= 0.01870
# Epoch: 0069 train_loss= 1.13527 train_acc= 0.58571 val_loss= 1.17472 val_acc= 0.65600 time= 0.02022
# Epoch: 0070 train_loss= 1.09586 train_acc= 0.65714 val_loss= 1.16718 val_acc= 0.64400 time= 0.01952
# Epoch: 0071 train_loss= 1.00209 train_acc= 0.63571 val_loss= 1.16038 val_acc= 0.64600 time= 0.01997
# Epoch: 0072 train_loss= 1.05120 train_acc= 0.64286 val_loss= 1.15422 val_acc= 0.66200 time= 0.01857
# Epoch: 0073 train_loss= 1.13352 train_acc= 0.66429 val_loss= 1.14714 val_acc= 0.66600 time= 0.01888
# Epoch: 0074 train_loss= 1.01581 train_acc= 0.62857 val_loss= 1.14444 val_acc= 0.65800 time= 0.01975
# Epoch: 0075 train_loss= 0.99083 train_acc= 0.62143 val_loss= 1.14228 val_acc= 0.66200 time= 0.01823
# Epoch: 0076 train_loss= 1.05695 train_acc= 0.60000 val_loss= 1.14428 val_acc= 0.66000 time= 0.01950
# Epoch: 0077 train_loss= 1.06611 train_acc= 0.62857 val_loss= 1.14551 val_acc= 0.65200 time= 0.01783
# Epoch: 0078 train_loss= 1.04987 train_acc= 0.62143 val_loss= 1.14293 val_acc= 0.65200 time= 0.01806
# Epoch: 0079 train_loss= 0.93315 train_acc= 0.70000 val_loss= 1.13907 val_acc= 0.65200 time= 0.02060
# Epoch: 0080 train_loss= 0.92226 train_acc= 0.75000 val_loss= 1.13974 val_acc= 0.64400 time= 0.01830
# Epoch: 0081 train_loss= 1.02945 train_acc= 0.61429 val_loss= 1.14003 val_acc= 0.64400 time= 0.01984
# Epoch: 0082 train_loss= 0.93219 train_acc= 0.70000 val_loss= 1.14038 val_acc= 0.64400 time= 0.02053
# Epoch: 0083 train_loss= 0.89969 train_acc= 0.72143 val_loss= 1.13858 val_acc= 0.63800 time= 0.01989
# Epoch: 0084 train_loss= 0.92550 train_acc= 0.71429 val_loss= 1.13948 val_acc= 0.64200 time= 0.01894
# Epoch: 0085 train_loss= 0.96616 train_acc= 0.70714 val_loss= 1.13364 val_acc= 0.64000 time= 0.01877
# Epoch: 0086 train_loss= 0.96750 train_acc= 0.64286 val_loss= 1.12843 val_acc= 0.63800 time= 0.02079
# Epoch: 0087 train_loss= 0.92896 train_acc= 0.65714 val_loss= 1.12707 val_acc= 0.63800 time= 0.01971
# Epoch: 0088 train_loss= 0.94086 train_acc= 0.69286 val_loss= 1.12712 val_acc= 0.63800 time= 0.01795
# Epoch: 0089 train_loss= 0.91465 train_acc= 0.68571 val_loss= 1.13078 val_acc= 0.63400 time= 0.01930
# Epoch: 0090 train_loss= 0.91973 train_acc= 0.64286 val_loss= 1.13394 val_acc= 0.63000 time= 0.01803
# Epoch: 0091 train_loss= 0.90283 train_acc= 0.67857 val_loss= 1.13664 val_acc= 0.62400 time= 0.01793
# Early stopping...
# Optimization Finished!
# Test set results: cost= 1.17974 accuracy= 0.61000 time= 0.00926
# y_test.shape
# (2708, 7)
# test_mask.shape
# (2708,)
#  total embedding size:  2708

# %%
!~/.pyenv/shims/python  train.py --dataset cora
plot2DEmbedding("embedding","embedding_labels")
# Out:
# len(y): 140
# labels shape:
# (2708, 7)
# len(idx_train) 140
# len(idx_val) 500
# len(idx_test) 1000
# features after row normalize and tuple
# (array([[   0, 1274],
#        [   0, 1247],
#        [   0, 1194],
#        ...,
#        [2707,  329],
#        [2707,  186],
#        [2707,   19]], dtype=int32),
#  array([0.11111111, 0.11111111, 0.11111111, ..., 0.07692308, 0.07692308,
#        0.07692308], dtype=float32),
#  (2708, 1433))
# WARNING:tensorflow:From /media/disk/home/pau/Projectes/CSN-proj/src/gcn/gcn_mod/gcn/metrics.py:6: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2019-01-22 17:48:23.378992: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Epoch: 0001 train_loss= 1.95369 train_acc= 0.17857 val_loss= 1.94959 val_acc= 0.19600 time= 0.04856
# Epoch: 0002 train_loss= 1.94921 train_acc= 0.22857 val_loss= 1.94556 val_acc= 0.25000 time= 0.01970
# Epoch: 0003 train_loss= 1.94375 train_acc= 0.25714 val_loss= 1.94130 val_acc= 0.26600 time= 0.01971
# Epoch: 0004 train_loss= 1.93951 train_acc= 0.22143 val_loss= 1.93656 val_acc= 0.27000 time= 0.02266
# Epoch: 0005 train_loss= 1.93176 train_acc= 0.26429 val_loss= 1.93142 val_acc= 0.27600 time= 0.01823
# Epoch: 0006 train_loss= 1.92502 train_acc= 0.26429 val_loss= 1.92582 val_acc= 0.28800 time= 0.01829
# Epoch: 0007 train_loss= 1.91947 train_acc= 0.26429 val_loss= 1.91962 val_acc= 0.29400 time= 0.01968
# Epoch: 0008 train_loss= 1.90527 train_acc= 0.28571 val_loss= 1.91259 val_acc= 0.30000 time= 0.01961
# Epoch: 0009 train_loss= 1.90319 train_acc= 0.26429 val_loss= 1.90475 val_acc= 0.30000 time= 0.02046
# Epoch: 0010 train_loss= 1.88612 train_acc= 0.27143 val_loss= 1.89592 val_acc= 0.30400 time= 0.01899
# Epoch: 0011 train_loss= 1.87968 train_acc= 0.30714 val_loss= 1.88595 val_acc= 0.30800 time= 0.01827
# Epoch: 0012 train_loss= 1.87549 train_acc= 0.25714 val_loss= 1.87492 val_acc= 0.31200 time= 0.01876
# Epoch: 0013 train_loss= 1.85802 train_acc= 0.27143 val_loss= 1.86275 val_acc= 0.31600 time= 0.02080
# Epoch: 0014 train_loss= 1.83655 train_acc= 0.27857 val_loss= 1.84932 val_acc= 0.31400 time= 0.01881
# Epoch: 0015 train_loss= 1.82313 train_acc= 0.26429 val_loss= 1.83487 val_acc= 0.31600 time= 0.02044
# Epoch: 0016 train_loss= 1.81615 train_acc= 0.30000 val_loss= 1.81921 val_acc= 0.32800 time= 0.01912
# Epoch: 0017 train_loss= 1.76850 train_acc= 0.28571 val_loss= 1.80243 val_acc= 0.32400 time= 0.01818
# Epoch: 0018 train_loss= 1.76992 train_acc= 0.29286 val_loss= 1.78469 val_acc= 0.32200 time= 0.01974
# Epoch: 0019 train_loss= 1.76787 train_acc= 0.29286 val_loss= 1.76595 val_acc= 0.32400 time= 0.02041
# Epoch: 0020 train_loss= 1.74701 train_acc= 0.30000 val_loss= 1.74612 val_acc= 0.33000 time= 0.02078
# Epoch: 0021 train_loss= 1.70119 train_acc= 0.29286 val_loss= 1.72515 val_acc= 0.32600 time= 0.01964
# Epoch: 0022 train_loss= 1.67643 train_acc= 0.32143 val_loss= 1.70351 val_acc= 0.32200 time= 0.01997
# Epoch: 0023 train_loss= 1.64302 train_acc= 0.33571 val_loss= 1.68135 val_acc= 0.32600 time= 0.01965
# Epoch: 0024 train_loss= 1.68050 train_acc= 0.29286 val_loss= 1.65940 val_acc= 0.32400 time= 0.01891
# Epoch: 0025 train_loss= 1.62081 train_acc= 0.30714 val_loss= 1.63768 val_acc= 0.32600 time= 0.01965
# Epoch: 0026 train_loss= 1.58796 train_acc= 0.31429 val_loss= 1.61674 val_acc= 0.32800 time= 0.01828
# Epoch: 0027 train_loss= 1.60783 train_acc= 0.28571 val_loss= 1.59668 val_acc= 0.33200 time= 0.02127
# Epoch: 0028 train_loss= 1.55734 train_acc= 0.35714 val_loss= 1.57728 val_acc= 0.33200 time= 0.01842
# Epoch: 0029 train_loss= 1.53634 train_acc= 0.31429 val_loss= 1.55883 val_acc= 0.33200 time= 0.01998
# Epoch: 0030 train_loss= 1.53152 train_acc= 0.33571 val_loss= 1.54148 val_acc= 0.33600 time= 0.02042
# Epoch: 0031 train_loss= 1.48951 train_acc= 0.30714 val_loss= 1.52507 val_acc= 0.33600 time= 0.01889
# Epoch: 0032 train_loss= 1.51346 train_acc= 0.30714 val_loss= 1.50947 val_acc= 0.34400 time= 0.02049
# Epoch: 0033 train_loss= 1.47774 train_acc= 0.34286 val_loss= 1.49471 val_acc= 0.34800 time= 0.01898
# Epoch: 0034 train_loss= 1.49114 train_acc= 0.34286 val_loss= 1.48132 val_acc= 0.35000 time= 0.01916
# Epoch: 0035 train_loss= 1.46085 train_acc= 0.31429 val_loss= 1.46899 val_acc= 0.35400 time= 0.02004
# Epoch: 0036 train_loss= 1.45599 train_acc= 0.36429 val_loss= 1.45690 val_acc= 0.36000 time= 0.01891
# Epoch: 0037 train_loss= 1.40535 train_acc= 0.35714 val_loss= 1.44363 val_acc= 0.36000 time= 0.01828
# Epoch: 0038 train_loss= 1.47875 train_acc= 0.35000 val_loss= 1.43247 val_acc= 0.36600 time= 0.01942
# Epoch: 0039 train_loss= 1.38573 train_acc= 0.39286 val_loss= 1.42188 val_acc= 0.36800 time= 0.01827
# Epoch: 0040 train_loss= 1.37480 train_acc= 0.38571 val_loss= 1.41103 val_acc= 0.36800 time= 0.01873
# Epoch: 0041 train_loss= 1.37847 train_acc= 0.36429 val_loss= 1.40098 val_acc= 0.37000 time= 0.01944
# Epoch: 0042 train_loss= 1.37917 train_acc= 0.42857 val_loss= 1.39279 val_acc= 0.39200 time= 0.01966
# Epoch: 0043 train_loss= 1.35797 train_acc= 0.38571 val_loss= 1.38634 val_acc= 0.41800 time= 0.02412
# Epoch: 0044 train_loss= 1.37528 train_acc= 0.40000 val_loss= 1.38038 val_acc= 0.41400 time= 0.01851
# Epoch: 0045 train_loss= 1.32314 train_acc= 0.40000 val_loss= 1.37092 val_acc= 0.42200 time= 0.01903
# Epoch: 0046 train_loss= 1.23770 train_acc= 0.43571 val_loss= 1.36257 val_acc= 0.43200 time= 0.01981
# Epoch: 0047 train_loss= 1.27809 train_acc= 0.40000 val_loss= 1.35307 val_acc= 0.44000 time= 0.01950
# Epoch: 0048 train_loss= 1.31789 train_acc= 0.42857 val_loss= 1.34353 val_acc= 0.44400 time= 0.02020
# Epoch: 0049 train_loss= 1.24131 train_acc= 0.47857 val_loss= 1.33493 val_acc= 0.46000 time= 0.01929
# Epoch: 0050 train_loss= 1.25496 train_acc= 0.42143 val_loss= 1.32762 val_acc= 0.46400 time= 0.01906
# Epoch: 0051 train_loss= 1.21900 train_acc= 0.50000 val_loss= 1.31945 val_acc= 0.47600 time= 0.02133
# Epoch: 0052 train_loss= 1.25635 train_acc= 0.44286 val_loss= 1.31175 val_acc= 0.49000 time= 0.01850
# Epoch: 0053 train_loss= 1.20935 train_acc= 0.42857 val_loss= 1.30395 val_acc= 0.50200 time= 0.02078
# Epoch: 0054 train_loss= 1.19416 train_acc= 0.54286 val_loss= 1.29537 val_acc= 0.51600 time= 0.01885
# Epoch: 0055 train_loss= 1.23380 train_acc= 0.45714 val_loss= 1.28695 val_acc= 0.53000 time= 0.01941
# Epoch: 0056 train_loss= 1.12606 train_acc= 0.60000 val_loss= 1.27787 val_acc= 0.53600 time= 0.01966
# Epoch: 0057 train_loss= 1.17065 train_acc= 0.53571 val_loss= 1.27092 val_acc= 0.55200 time= 0.01881
# Epoch: 0058 train_loss= 1.10761 train_acc= 0.58571 val_loss= 1.26259 val_acc= 0.56400 time= 0.02111
# Epoch: 0059 train_loss= 1.16406 train_acc= 0.57857 val_loss= 1.25128 val_acc= 0.57000 time= 0.01891
# Epoch: 0060 train_loss= 1.14564 train_acc= 0.57143 val_loss= 1.24129 val_acc= 0.57800 time= 0.01855
# Epoch: 0061 train_loss= 1.11760 train_acc= 0.61429 val_loss= 1.23227 val_acc= 0.59400 time= 0.02102
# Epoch: 0062 train_loss= 1.10711 train_acc= 0.54286 val_loss= 1.22476 val_acc= 0.60800 time= 0.01852
# Epoch: 0063 train_loss= 1.14884 train_acc= 0.58571 val_loss= 1.21843 val_acc= 0.61600 time= 0.02049
# Epoch: 0064 train_loss= 1.12463 train_acc= 0.57857 val_loss= 1.21317 val_acc= 0.64400 time= 0.01905
# Epoch: 0065 train_loss= 1.05123 train_acc= 0.65714 val_loss= 1.20802 val_acc= 0.64400 time= 0.01816
# Epoch: 0066 train_loss= 1.09774 train_acc= 0.62857 val_loss= 1.20044 val_acc= 0.65000 time= 0.01887
# Epoch: 0067 train_loss= 1.12759 train_acc= 0.60000 val_loss= 1.19363 val_acc= 0.65400 time= 0.01913
# Epoch: 0068 train_loss= 1.02748 train_acc= 0.71429 val_loss= 1.18427 val_acc= 0.65200 time= 0.01935
# Epoch: 0069 train_loss= 1.13527 train_acc= 0.58571 val_loss= 1.17472 val_acc= 0.65600 time= 0.01924
# Epoch: 0070 train_loss= 1.09586 train_acc= 0.65714 val_loss= 1.16718 val_acc= 0.64400 time= 0.01856
# Epoch: 0071 train_loss= 1.00209 train_acc= 0.63571 val_loss= 1.16038 val_acc= 0.64600 time= 0.01875
# Epoch: 0072 train_loss= 1.05120 train_acc= 0.64286 val_loss= 1.15422 val_acc= 0.66200 time= 0.02058
# Epoch: 0073 train_loss= 1.13352 train_acc= 0.66429 val_loss= 1.14714 val_acc= 0.66600 time= 0.01904
# Epoch: 0074 train_loss= 1.01581 train_acc= 0.62857 val_loss= 1.14444 val_acc= 0.65800 time= 0.02029
# Epoch: 0075 train_loss= 0.99083 train_acc= 0.62143 val_loss= 1.14228 val_acc= 0.66200 time= 0.01905
# Epoch: 0076 train_loss= 1.05695 train_acc= 0.60000 val_loss= 1.14428 val_acc= 0.66000 time= 0.01826
# Epoch: 0077 train_loss= 1.06611 train_acc= 0.62857 val_loss= 1.14551 val_acc= 0.65200 time= 0.01922
# Epoch: 0078 train_loss= 1.04987 train_acc= 0.62143 val_loss= 1.14293 val_acc= 0.65200 time= 0.01890
# Epoch: 0079 train_loss= 0.93315 train_acc= 0.70000 val_loss= 1.13907 val_acc= 0.65200 time= 0.02052
# Epoch: 0080 train_loss= 0.92226 train_acc= 0.75000 val_loss= 1.13974 val_acc= 0.64400 time= 0.01862
# Epoch: 0081 train_loss= 1.02945 train_acc= 0.61429 val_loss= 1.14003 val_acc= 0.64400 time= 0.01876
# Epoch: 0082 train_loss= 0.93219 train_acc= 0.70000 val_loss= 1.14038 val_acc= 0.64400 time= 0.01928
# Epoch: 0083 train_loss= 0.89969 train_acc= 0.72143 val_loss= 1.13858 val_acc= 0.63800 time= 0.01845
# Epoch: 0084 train_loss= 0.92550 train_acc= 0.71429 val_loss= 1.13948 val_acc= 0.64200 time= 0.01818
# Epoch: 0085 train_loss= 0.96616 train_acc= 0.70714 val_loss= 1.13364 val_acc= 0.64000 time= 0.01862
# Epoch: 0086 train_loss= 0.96750 train_acc= 0.64286 val_loss= 1.12843 val_acc= 0.63800 time= 0.01838
# Epoch: 0087 train_loss= 0.92896 train_acc= 0.65714 val_loss= 1.12707 val_acc= 0.63800 time= 0.01953
# Epoch: 0088 train_loss= 0.94086 train_acc= 0.69286 val_loss= 1.12712 val_acc= 0.63800 time= 0.01826
# Epoch: 0089 train_loss= 0.91465 train_acc= 0.68571 val_loss= 1.13078 val_acc= 0.63400 time= 0.01814
# Epoch: 0090 train_loss= 0.91973 train_acc= 0.64286 val_loss= 1.13394 val_acc= 0.63000 time= 0.01991
# Epoch: 0091 train_loss= 0.90283 train_acc= 0.67857 val_loss= 1.13664 val_acc= 0.62400 time= 0.01827
# Early stopping...
# Optimization Finished!
# Test set results: cost= 1.17974 accuracy= 0.61000 time= 0.00850
# y_test.shape
# (2708, 7)
# test_mask.shape
# (2708,)
#  total embedding size:  2708
